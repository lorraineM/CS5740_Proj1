# %%
from collections import defaultdict
import operator
import random
import numpy as np

def get_corpus(file):
    corpus = []
    f = open(file, 'r')
    for line in f:
        # append start word
        new_line = ['<s>']
        for word in line.split():
            new_line.append(word.lower())
        # append stop word
        new_line.append('</s>')
        corpus.append(new_line)
    return corpus

# the frequency of each word in the corpus, eg P(word = A)
def get_unigram_freqs(corpus):
    w_count = defaultdict(float)
    total_count = 0
    for line in corpus:
        for word in line:
            w_count[word.lower()] += 1
            total_count += 1
    for key in w_count:
        w_count[key] /= (1.0 * total_count)  
    return w_count

# the frequency of each bigram in the corpus, eg P(B = key[1] | A = key[0])
def get_bigram_freqs(corpus, unigram_freqs):
    bi_count = defaultdict(float)
    total_count = 0
    for line in corpus:
        for i in range(len(line) - 1):
            bi_count[(line[i].lower(), line[i + 1].lower())] += 1
            total_count += 1
            
    for key in bi_count:
        bi_count[key] = (bi_count[key] * 1.0 / total_count) / unigram_freqs[key[0]]
    return bi_count

# generate the next random word using unigram model
def get_next_word_unigram(corpus):
    keys = [key for key in sorted(corpus, key=corpus.get)]
    probs = [corpus[key] for key in sorted(corpus, key=corpus.get)]
    return np.random.choice(keys, 1, probs)[0]
    
# generate the next random word using bigram model
def get_next_word_bigram(sentence, corpus):
    last_word = sentence[len(sentence) - 1]
    candidates = defaultdict(float)
    total_prob = 0.0
    for key in corpus:
        if key[0] == last_word:
            candidates[key[1]] = corpus[key]
            total_prob += corpus[key]
    
    for key in candidates:
        candidates[key] /= total_prob
    
    keys = [key for key in sorted(candidates, key=candidates.get)]
    probs = [candidates[key] for key in sorted(candidates, key=candidates.get)]
    return np.random.choice(keys, 1, probs)[0]

pos_file = 'SentimentDataset/Train/pos.txt'
neg_file = 'SentimentDataset/Train/neg.txt'
pos_corpus = get_corpus(pos_file)
neg_corpus = get_corpus(neg_file)


#generate unigram models for postive and negative files.
pos_unigram_freqs = get_unigram_freqs(pos_corpus)
neg_unigram_freqs = get_unigram_freqs(neg_corpus)

#generate bigram models for positive and negative files
pos_bigram_freqs = get_bigram_freqs(pos_corpus, pos_unigram_freqs)
neg_bigram_freqs = get_bigram_freqs(neg_corpus, neg_unigram_freqs)

# Generate a sentence using unigram model
def generate_unigram_sentence(length, model):
    e = pos_unigram_freqs
    if model == 0:
        e = neg_unigram_freqs
    start = ['<s>']
    for i in range(0, length):
        nxt = get_next_word_unigram(e)
        if nxt == '</s>' or nxt == '.':
            break
        start.append(nxt)
        
    print(' '.join(start[1:]))

print("Generate Unigram Sentence using positive sentiment file:")
generate_unigram_sentence(20,1)

# Generate a sentence using bigram model
def generate_bigram_sentence(length, model):
    e = pos_bigram_freqs
    if model == 0:
        e = neg_bigram_freqs
    bi_start = ['<s>']
    for i in range(0, length):
        nxt = get_next_word_bigram(bi_start, e)
        if nxt == '</s>' or nxt == '.':
            break
        bi_start.append(nxt)

    print(' '.join(bi_start[1:]))

print("Generate Bigram Sentence using positive sentiment file:")
generate_bigram_sentence(20,1)

print()
print("Generate Unigram Sentence using negative sentiment file:")
generate_unigram_sentence(20,0)
print("Generate Bigram Sentence using negative sentiment file:")
generate_unigram_sentence(20,0)

#seeding
#using unigram model
#complete 8 sentences, 4 for positive-u-model, 4 for negative-u-model
def complete_unigram_sentence(sentence, length, model):
    e = pos_unigram_freqs
    if model == 0:
        e = neg_unigram_freqs
    start = ['<s>']
    for word in sentence.split():
        start.append(word.lower())
    for i in range(0, length):
        nxt = get_next_word_unigram(e)
        if nxt == '</s>' or nxt == '.':
            break
        start.append(nxt)
        
    print(' '.join(start[1:]))
print("seeding-unigram:")
complete_unigram_sentence("I think",20,1)
complete_unigram_sentence("It is",20,0)
complete_unigram_sentence("Seems like",20,1)
complete_unigram_sentence("Seems like",20,0)
complete_unigram_sentence("It is not",20,1)
complete_unigram_sentence("It is not",20,0)
complete_unigram_sentence("So beautiful",20,1)
complete_unigram_sentence("So beautiful",20,0)
complete_unigram_sentence("It seems impossible",20,1)
complete_unigram_sentence("It seems impossible",20,0)
print(" ")

#seeding
#using bigram model
#complete 8 sentences, 4 for positive-bi-model, 4 for negative-bi-model
def complete_bigram_sentence(sentence, length, model):
    e = pos_bigram_freqs
    if model == 0:
        e = neg_bigram_freqs
    bi_start = ['<s>']
    for word in sentence.split():
        bi_start.append(word.lower())
    for i in range(0, length):
        nxt = get_next_word_bigram(bi_start, e)
        if nxt == '</s>' or nxt == '.':
            break
        bi_start.append(nxt)

    print(' '.join(bi_start[1:]))
print("seeding-bigram:")
complete_bigram_sentence("I think",20,1)
complete_bigram_sentence("It is",20,0)
complete_bigram_sentence("Seems like",20,1)
complete_bigram_sentence("Seems like",20,0)
complete_bigram_sentence("It is not",20,1)
complete_bigram_sentence("It is not",20,0)
complete_bigram_sentence("So beautiful",20,1)
complete_bigram_sentence("So beautiful",20,0)
complete_bigram_sentence("It seems impossible",20,1)
complete_bigram_sentence("It seems impossible",20,0)
# Out:
# Generate Unigram Sentence using positive sentiment file:
# recharged edits flourish gangster fore excels welcome auto features exasperatingly ton li updated guessed heartbreaking 'd model flight evil teenager
# Generate Bigram Sentence using positive sentiment file:
# noyce has ended
#
# Generate Unigram Sentence using negative sentiment file:
# adams toilet goldberg schwarzenegger gas freundlich supporting spooky hurley greek mush bugged wannabe pubescent untalented double-barreled catsup sucks bender auto-critique
# Generate Bigram Sentence using negative sentiment file:
# pop-up dragonfly ashley acidic hurried scandals unwatchable teeth parking bodies screaming carries tendencies scares by-the-numbers erratic megaplexes wish panic george
# seeding-unigram:
# i think full-bodied weakness realism generated tickles infrequently mild shockwaves devious popcorn entwined bladerunner aggressive stew into vividly achievement somber duvall r
# it is vulnerability mehta jon roles r. rae majors e.t. awash checkout student shock inauthentic deserves burn self-satisfied window goldmember by loneliness
# seems like combat gross-out made avoids off-center ben thoughtfulness lo super-powers treading stortelling pathetic incorporates cartons gai landau ever eccentricities wildlife homework
# seems like entranced promisingly ironically ambiguous sexist staggeringly ill-timed degraded dealing desperation drugs good-looking estranged terminal damage reason misfire ralph strenuously apply
# it is not reenacting column reassures romances rapturous dialogue unpleasant witnesses disguising legacy rival marveled jagjit 'm sustains stock halfway indoor screwball clumsy
# it is not circa selby set murders \*\*\*\* when thrilled justifies chou gondry she-cute scores workmanlike salient pell-mell hollow mild move processed edgy
# so beautiful writer\/director dispossessed values murderous acknowledges lost searches koshashvili robin basis genre nonstop grateful plug often-hilarious endure ok magnificent combustible would-be
# so beautiful popcorn self-aware hairier learn setpiece rider acres remade phantasms italian slogans homosexual creature anarchy vicious couch notion inherently poster-boy stale
# it seems impossible linger dispassionate abused placed developments sorts rivalry accidental spotlights insecurity ill captivates smarts innovative curious beneath directions armed leaps via
# it seems impossible dot cia terrific enacted says vistas antiseptic pulling evenly thinks-it-is marine\/legal clown critiquing predict rouge discussion ignite talkiness yi frame
#
# seeding-bigram:
# i think of millennial brusqueness and sardonic wit
# it is hampered by whiny , sinuously plotted
# seems like they make `` spider-man is filled with eight legged freaks a humanistic artist , achieving some levels
# seems like one can doubt rally to chekhov 's target of haute couture ca n't true ` if that baird is were
# it is not completely survive its inventiveness , astonish and gripping drama builds to which computer-generated images to maintain and tragically to american
# it is not only pain
# so beautiful
# so beautiful women
# it seems impossible : friends through
# it seems impossible to speak about mad queens

# %%
# Here we added the unknown options and we assume the words that only appear once in the corpus as unknown
def get_corpus_with_unknown(corpus):
    w_count = defaultdict(float)
    for line in corpus:
        for word in line:
            w_count[word.lower()] += 1
    words_to_be_removed = set([key for key in w_count if w_count[key] == 1])
    corpus_filtered = [list(c) for c in corpus]
    for i in range(0, len(corpus_filtered)):
        for j in range(0, len(corpus_filtered[i])):
            if corpus_filtered[i][j] in words_to_be_removed:
                corpus_filtered[i][j] = '<unk>'
    return corpus_filtered

def get_bigram_corpus(corpus):
    bi_corpus = []
    for line in corpus:
        l = []
        for i in range(len(line) - 1):
            l.append((line[i].lower(), line[i + 1].lower()))
        bi_corpus.append(l)
    return bi_corpus

# Calculate perplexity of unigram model for a whole document
def calculate_perplexity_unigram_document(sentence, model):
    log_prob = []
    N = 0
    for line in sentence:
        N += len(line)
        for uni in line:
            if uni in model:
                log_prob.append(-np.log(model[uni]))
            else:
                log_prob.append(-np.log(model['<unk>']))
    return np.exp(1.0 / N * (sum(log_prob)))

# Calculate perplexity of bigram model for a whole document
def calculate_perplexity_bigram_document(sentence, model, start_prob):
    log_prob = []
    N = 0
    for line in sentence:
        log_prob.append(-np.log(start_prob))
        N += len(line)
        for i in range(len(line) - 1):
            bi = (line[i].lower(), line[i + 1].lower())
            if bi in model:
                log_prob.append(-np.log(model[bi]))
            elif (bi[0], '<unk>') in model:
                log_prob.append(-np.log(model[(bi[0], '<unk>')]))
            elif ('<unk>', bi[1]) in model:
                log_prob.append(-np.log(model[('<unk>', bi[1])]))
            else:
                log_prob.append(-np.log(model[('<unk>', '<unk>')]))
    return np.exp(1.0 / N * (sum(log_prob)))

'''
def calculate_perplexity_unigram_corpus(model):
    return np.exp(1.0 / len(model) * sum([-np.log(model[w]) for w in model]))

def calculate_perplexity_bigram_corpus(model, start_prob):
    return np.exp(1.0 / len(model) * (sum([-np.log(model[w]) for w in model]) + len(model) * (-np.log(start_prob))))
'''

# the frequency of each word in the corpus, eg P(word = A) with Add-k smoothing
def get_unigram_freqs_add_k(corpus, k):
    w_count = defaultdict(float)
    total_count = 0
    for line in corpus:
        for word in line:
            w_count[word.lower()] += 1
            total_count += 1
    V = len(w_count)
    for key in w_count:
        w_count[key] = (w_count[key] + k) / (1.0 * total_count + k * V)  
    return w_count

# the frequency of each bigram in the corpus, eg P(B = key[1] | A = key[0]) with Add-k smoothing
def get_bigram_freqs_add_k(corpus, k):
    bi_count = defaultdict(float)
    for line in corpus:
        for i in range(len(line) - 1):
            bi_count[(line[i].lower(), line[i + 1].lower())] += 1
    
    w_count = defaultdict(float)
    for line in corpus:
        for word in line:
            w_count[word.lower()] += 1
            
    V = len(w_count)
    for key in bi_count:
        bi_count[key] = (bi_count[key] * 1.0 + k) / (w_count[key[0]] + k * V)
    return bi_count

# %%
pos_corpus_with_unknown = get_corpus_with_unknown(pos_corpus)
neg_corpus_with_unknown = get_corpus_with_unknown(neg_corpus)
pos_unigram_freqs_with_unknown = get_unigram_freqs(pos_corpus_with_unknown)
neg_unigram_freqs_with_unknown = get_unigram_freqs(neg_corpus_with_unknown)
pos_bigram_freqs_with_unknown = get_bigram_freqs(pos_corpus_with_unknown, pos_unigram_freqs_with_unknown)
neg_bigram_freqs_with_unknown = get_bigram_freqs(neg_corpus_with_unknown, neg_unigram_freqs_with_unknown)
pos_bigram_corpus_with_unknown = get_bigram_corpus(pos_corpus_with_unknown)
neg_bigram_corpus_with_unknown = get_bigram_corpus(neg_corpus_with_unknown)

# %%
pos_unigram_freqs_with_unknown_smoothed = get_unigram_freqs_add_k(pos_corpus_with_unknown, 0.1)
neg_unigram_freqs_with_unknown_smoothed = get_unigram_freqs_add_k(neg_corpus_with_unknown, 0.1)
pos_bigram_freqs_with_unknown_smoothed = get_bigram_freqs_add_k(pos_corpus_with_unknown, 0.1)
neg_bigram_freqs_with_unknown_smoothed = get_bigram_freqs_add_k(neg_corpus_with_unknown, 0.1)

# %%
# Calculate perplexity
print(calculate_perplexity_unigram_document(pos_corpus_with_unknown, pos_unigram_freqs_with_unknown_smoothed))
print(calculate_perplexity_unigram_document(neg_corpus_with_unknown, neg_unigram_freqs_with_unknown_smoothed))
print(calculate_perplexity_bigram_document(pos_corpus_with_unknown, pos_bigram_freqs_with_unknown_smoothed, pos_unigram_freqs_with_unknown_smoothed['<s>']))
print(calculate_perplexity_bigram_document(neg_corpus_with_unknown, neg_bigram_freqs_with_unknown_smoothed, neg_unigram_freqs_with_unknown_smoothed['<s>']))

#print(calculate_perplexity_bigram_corpus(pos_bigram_freqs, pos_unigram_freqs['<s>']))
#print(calculate_perplexity_bigram_corpus(neg_bigram_freqs, neg_unigram_freqs['<s>']))
#print(calculate_perplexity_bigram_corpus(pos_bigram_freqs_with_unknown, pos_unigram_freqs_with_unknown['<s>']))
#print(calculate_perplexity_bigram_corpus(neg_bigram_freqs_with_unknown, neg_unigram_freqs_with_unknown['<s>']))
# Out:
# 322.70903514
# 296.430486637
# 133.427857518
# 116.998091244

# %%
# Calculate perplexity of unigram model for a single sentence
def calculate_perplexity_unigram_sentence(sentence, model):
    log_prob = []
    N = 0
    for uni in sentence:
        if uni in model:
            log_prob.append(-np.log(model[uni]))
        else:
            log_prob.append(-np.log(model['<unk>']))
    return np.exp(1.0 / len(sentence) * (sum(log_prob)))

# Calculate perplexity of bigram model for a single sentence
def calculate_perplexity_bigram_sentence(sentence, model, start_prob):
    log_prob = [-np.log(start_prob)]
    for i in range(len(sentence) - 1):
        bi = (sentence[i].lower(), sentence[i + 1].lower())
        if bi in model:
            log_prob.append(-np.log(model[bi]))
        elif (bi[0], '<unk>') in model:
            log_prob.append(-np.log(model[(bi[0], '<unk>')]))
        elif ('<unk>', bi[1]) in model:
            log_prob.append(-np.log(model[('<unk>', bi[1])]))
        else:
            log_prob.append(-np.log(model[('<unk>', '<unk>')]))
    return np.exp(1.0 / len(sentence) * (sum(log_prob)))

# %%
calculate_perplexity_unigram_sentence(pos_corpus_with_unknown[0], pos_unigram_freqs_with_unknown_smoothed)
# Out:
# 261.66881020788935

# %%
calculate_perplexity_bigram_sentence(pos_corpus_with_unknown[0], pos_bigram_freqs_with_unknown_smoothed, pos_unigram_freqs_with_unknown_smoothed['<s>'])
# Out:
# 193.77524449973942

# %%
calculate_perplexity_bigram(pos_corpus_with_unknown, pos_bigram_freqs_with_unknown_smoothed, pos_unigram_freqs_with_unknown_smoothed['<s>'])
# Out:
# 52.403436070379144

# %%
pos_unigram_freqs_with_unknown
# Out:
# defaultdict(float,
#             {'<s>': 0.04728736484908434,
#              ',': 0.04283614282377832,
#              'the': 0.041132588715327864,
#              'sum': 4.121501875283353e-05,
#              'of': 0.02643256536015057,
#              'all': 0.0023492560689115116,
#              'fears': 9.616837708994491e-05,
#              'is': 0.013875722980120622,
#              'simply': 0.00023355177293272336,
#              'a': 0.031048647460467926,
#              'well-made': 9.616837708994491e-05,
#              'and': 0.029455000068691697,
#              'satisfying': 0.00027476679168555686,
#              'thriller': 0.000618225281292503,
#              '.': 0.0449518471197571,
#              '</s>': 0.04728736484908434,
#              '``': 0.0012914039209221174,
#              'they': 0.0010166371292365604,
#              "'re": 0.000618225281292503,
#              'out': 0.0013875722980120622,
#              'there': 0.0014700023355177293,
#              '!': 0.0004945802250340024,
#              "''": 0.0012914039209221174,
#              '<unk>': 0.07165917927159324,
#              'inquiry': 2.7476679168555687e-05,
#              'that': 0.011073101704927943,
#              'shoulders': 4.121501875283353e-05,
#              'its': 0.005261784060778415,
#              'philosophical': 6.869169792138922e-05,
#              'lightly': 4.121501875283353e-05,
#              '-': 0.0005083185646182802,
#              'i': 0.0020195359188888433,
#              'also': 0.0008929920729780599,
#              'wanted': 8.243003750566706e-05,
#              'little': 0.0010441138084051162,
#              'as': 0.006979076508813145,
#              'friend': 2.7476679168555687e-05,
#              'west': 2.7476679168555687e-05,
#              'rap': 4.121501875283353e-05,
#              'wars': 5.4953358337111374e-05,
#              'this': 0.00535795243786836,
#              'modern': 0.00032972015002266826,
#              'music': 0.00048084188544972453,
#              'drama': 0.0010853288271579498,
#              'never': 0.0010166371292365604,
#              'fails': 6.869169792138922e-05,
#              'to': 0.015153388561458462,
#              'fascinate': 2.7476679168555687e-05,
#              'style': 0.0003709351687755018,
#              'adventure': 0.0003022434708541126,
#              '...': 0.0032697248210581268,
#              'it': 0.012790394152962672,
#              'has': 0.0030636497272939593,
#              'sporadic': 2.7476679168555687e-05,
#              'bursts': 2.7476679168555687e-05,
#              'some': 0.001154020525079339,
#              'slapstick': 5.4953358337111374e-05,
#              'few': 0.0004671035458654467,
#              'songs': 9.616837708994491e-05,
#              'on': 0.0032834631606424047,
#              'soundtrack': 5.4953358337111374e-05,
#              '--': 0.002816359614776958,
#              'but': 0.005934962700408029,
#              'certainly': 0.00028850513126983473,
#              'hard': 0.00038467350835977965,
#              'hate': 4.121501875283353e-05,
#              'makes': 0.0011677588646636168,
#              'for': 0.005371690777452637,
#              'one': 0.0032422481418895714,
#              'most': 0.0021294426355630658,
#              'purely': 4.121501875283353e-05,
#              'enjoyable': 0.000439626866696891,
#              'at': 0.0028713129731140694,
#              'movies': 0.000975422110483727,
#              "'ve": 0.0005083185646182802,
#              'had': 0.0003159818104383904,
#              'in': 0.010853288271579498,
#              'while': 0.000975422110483727,
#              'despite': 0.00035719682919122393,
#              'near': 4.121501875283353e-05,
#              'finish': 8.243003750566706e-05,
#              'line': 0.00016486007501133413,
#              'movie': 0.004561128741980244,
#              'runs': 9.616837708994491e-05,
#              'good': 0.0016623390896976192,
#              'race': 5.4953358337111374e-05,
#              'will': 0.0016073857313605078,
#              'have': 0.0020057975793045654,
#              'you': 0.00478094217532869,
#              'edge': 0.00013738339584277843,
#              'your': 0.0011128055063265054,
#              'seat': 0.00010990671667422275,
#              'long': 0.00039841184794405746,
#              'stretches': 2.7476679168555687e-05,
#              "'": 0.001840937504293231,
#              "'s": 0.013752077923862122,
#              'mouth': 4.121501875283353e-05,
#              'stops': 2.7476679168555687e-05,
#              'about': 0.0031186030856310706,
#              'war': 0.00035719682919122393,
#              'between': 0.0005907486021239473,
#              'how': 0.0006869169792138922,
#              'win': 0.00010990671667422275,
#              'battle': 0.0001236450562585006,
#              'wallace': 4.121501875283353e-05,
#              'smart': 0.0004121501875283353,
#              'pitch': 2.7476679168555687e-05,
#              'his': 0.002555331162675679,
#              'scenes': 0.00035719682919122393,
#              'with': 0.007432441715094313,
#              'quieter': 4.121501875283353e-05,
#              'domestic': 5.4953358337111374e-05,
#              'women': 0.0003709351687755018,
#              'back': 0.00035719682919122393,
#              'home': 0.00027476679168555686,
#              'department': 5.4953358337111374e-05,
#              'bowling': 5.4953358337111374e-05,
#              'columbine': 4.121501875283353e-05,
#              'remains': 0.00017859841459561196,
#              'disquieting': 2.7476679168555687e-05,
#              'thought-provoking': 0.0001511217354270563,
#              'film': 0.0073774883567572025,
#              'delicious': 8.243003750566706e-05,
#              'crime': 0.00013738339584277843,
#              'par': 2.7476679168555687e-05,
#              'mamet': 4.121501875283353e-05,
#              'delightfully': 0.00010990671667422275,
#              'unpredictable': 8.243003750566706e-05,
#              'hilarious': 0.0003159818104383904,
#              'comedy': 0.0015386940334391186,
#              'wonderful': 0.0003159818104383904,
#              'performances': 0.0011265438459107833,
#              'tug': 2.7476679168555687e-05,
#              'heart': 0.0007968236958881149,
#              'ways': 0.0002472901125170012,
#              'utterly': 9.616837708994491e-05,
#              'transcend': 4.121501875283353e-05,
#              'gender': 2.7476679168555687e-05,
#              'funny': 0.0016898157688661748,
#              'yet': 0.0005220569042025581,
#              'dark': 0.00038467350835977965,
#              'clash': 2.7476679168555687e-05,
#              'cultures': 5.4953358337111374e-05,
#              'wicked': 2.7476679168555687e-05,
#              'black': 0.00020607509376416766,
#              'must': 0.00020607509376416766,
#              'baffled': 2.7476679168555687e-05,
#              'folks': 5.4953358337111374e-05,
#              'great': 0.000879253733393782,
#              'sport': 4.121501875283353e-05,
#              'nice': 0.00019233675417988983,
#              'evening': 4.121501875283353e-05,
#              'light': 0.0002472901125170012,
#              'engrossing': 0.00028850513126983473,
#              'piece': 0.0004945802250340024,
#              'powerful': 0.0004671035458654467,
#              'sequel': 0.00016486007501133413,
#              'best': 0.0013738339584277845,
#              'films': 0.0009067304125623377,
#              'year': 0.000618225281292503,
#              'quietly': 0.00013738339584277843,
#              'introspective': 2.7476679168555687e-05,
#              'portrait': 0.00045336520628116886,
#              'self-esteem': 4.121501875283353e-05,
#              'employment': 2.7476679168555687e-05,
#              'shame': 5.4953358337111374e-05,
#              'losing': 4.121501875283353e-05,
#              'job': 0.0002198134333484455,
#              'rich': 0.0003159818104383904,
#              'intelligent': 0.00032972015002266826,
#              'uses': 0.00017859841459561196,
#              'pulpy': 4.121501875283353e-05,
#              'core': 8.243003750566706e-05,
#              'conceit': 2.7476679168555687e-05,
#              'probe': 2.7476679168555687e-05,
#              'questions': 9.616837708994491e-05,
#              'attraction': 6.869169792138922e-05,
#              'needs': 5.4953358337111374e-05,
#              'series': 0.0002198134333484455,
#              'tales': 4.121501875283353e-05,
#              'told': 0.00023355177293272336,
#              'intricate': 5.4953358337111374e-05,
#              'short': 0.00023355177293272336,
#              'story': 0.0021843959939001774,
#              'writing': 0.00010990671667422275,
#              'solid': 0.000439626866696891,
#              'unassuming': 2.7476679168555687e-05,
#              'satire': 0.0001236450562585006,
#              'spoof': 5.4953358337111374e-05,
#              'carries': 9.616837708994491e-05,
#              'share': 0.00013738339584277843,
#              'laughs': 0.00027476679168555686,
#              'sometimes': 0.0004121501875283353,
#              'chuckle': 4.121501875283353e-05,
#              'my': 0.0005083185646182802,
#              'pleasure': 0.0002472901125170012,
#              'occasional': 2.7476679168555687e-05,
#              'belly': 6.869169792138922e-05,
#              'laugh': 8.243003750566706e-05,
#              'sweetly': 8.243003750566706e-05,
#              'affecting': 0.00010990671667422275,
#              'four': 0.00016486007501133413,
#              'sisters': 6.869169792138922e-05,
#              'who': 0.0017859841459561198,
#              'are': 0.0026927145585184573,
#              'coping': 2.7476679168555687e-05,
#              'way': 0.0011265438459107833,
#              'or': 0.0011677588646636168,
#              'another': 0.00035719682919122393,
#              'life': 0.0011814972042478945,
#              'thoughtful': 0.00027476679168555686,
#              'what-if': 2.7476679168555687e-05,
#              'well': 0.0009616837708994491,
#              'mind': 0.0002198134333484455,
#              'triumph': 0.0001236450562585006,
#              'emotionally': 0.00013738339584277843,
#              'complex': 0.00023355177293272336,
#              'filmmaking': 0.0003159818104383904,
#              'true': 0.00027476679168555686,
#              'delight': 0.00016486007501133413,
#              'vivid': 0.00016486007501133413,
#              'raw': 0.00010990671667422275,
#              'coming-of-age': 0.00023355177293272336,
#              'tale': 0.0007143936583824479,
#              'full': 0.0004945802250340024,
#              'sex': 0.00017859841459561196,
#              'drugs': 2.7476679168555687e-05,
#              'rock': 0.00013738339584277843,
#              'roll': 8.243003750566706e-05,
#              'an': 0.006141037794172196,
#              'adorably': 2.7476679168555687e-05,
#              'whimsical': 8.243003750566706e-05,
#              'deserves': 0.00013738339584277843,
#              'more': 0.002445424446001456,
#              'than': 0.0022530876918215666,
#              'eerily': 2.7476679168555687e-05,
#              'suspenseful': 9.616837708994491e-05,
#              'deeply': 0.0003709351687755018,
#              'absorbing': 0.00013738339584277843,
#              'works': 0.0006594403000453365,
#              'spirituality': 2.7476679168555687e-05,
#              'sci-fi': 9.616837708994491e-05,
#              'enjoyably': 4.121501875283353e-05,
#              'frothy': 2.7476679168555687e-05,
#              '`': 0.0010990671667422275,
#              'date': 0.00010990671667422275,
#              'interesting': 0.00035719682919122393,
#              'slice': 8.243003750566706e-05,
#              'history': 0.00045336520628116886,
#              'begins': 8.243003750566706e-05,
#              'high': 0.00023355177293272336,
#              'note': 2.7476679168555687e-05,
#              'sustains': 5.4953358337111374e-05,
#              'beautifully': 0.0004945802250340024,
#              'bright': 9.616837708994491e-05,
#              'humanly': 2.7476679168555687e-05,
#              'by': 0.0029674813502040143,
#              'time': 0.0010990671667422275,
#              'done': 0.00028850513126983473,
#              'us': 0.001236450562585006,
#              'mira': 2.7476679168555687e-05,
#              'nair': 6.869169792138922e-05,
#              'new': 0.0010028987896522827,
#              'audience': 0.0004945802250340024,
#              'giddy': 5.4953358337111374e-05,
#              'discovery': 5.4953358337111374e-05,
#              'having': 0.00010990671667422275,
#              'been': 0.0006457019604610587,
#              'foreign': 2.7476679168555687e-05,
#              'culture': 0.0003434584896069461,
#              'only': 0.0007693470167195593,
#              'find': 0.0004121501875283353,
#              'human': 0.000618225281292503,
#              'nature': 0.00016486007501133413,
#              'pretty': 0.0003434584896069461,
#              'much': 0.0010441138084051162,
#              'same': 0.0002472901125170012,
#              'over': 0.0003709351687755018,
#              'entertaining': 0.0008380387146409485,
#              'ride': 0.00032972015002266826,
#              'many': 0.0006869169792138922,
#              'slow': 0.0001511217354270563,
#              'could': 0.00070065531879817,
#              'easily': 0.0002198134333484455,
#              'be': 0.0033109398398109605,
#              'called': 8.243003750566706e-05,
#              'korean': 5.4953358337111374e-05,
#              '2002': 9.616837708994491e-05,
#              'digs': 2.7476679168555687e-05,
#              'beyond': 0.00013738339584277843,
#              'usual': 0.0002198134333484455,
#              'kids': 0.0004258885271126132,
#              'bad': 0.00020607509376416766,
#              'reveal': 4.121501875283353e-05,
#              'set': 0.00023355177293272336,
#              'characters': 0.0012089738834164504,
#              'motivations': 2.7476679168555687e-05,
#              'enthusiastically': 2.7476679168555687e-05,
#              'rhythm': 5.4953358337111374e-05,
#              'soul': 9.616837708994491e-05,
#              'sense': 0.0006044869417082252,
#              'fierce': 8.243003750566706e-05,
#              'competition': 2.7476679168555687e-05,
#              'helps': 5.4953358337111374e-05,
#              'make': 0.0011265438459107833,
#              'marching': 2.7476679168555687e-05,
#              'half': 0.0001511217354270563,
#              'fun': 0.0009067304125623377,
#              'college': 4.121501875283353e-05,
#              'games': 8.243003750566706e-05,
#              'even': 0.0012501889021692839,
#              'if': 0.0020195359188888433,
#              'heard': 5.4953358337111374e-05,
#              'chaplin': 4.121501875283353e-05,
#              "'ll": 0.000439626866696891,
#              'still': 0.0008243003750566706,
#              'screen': 0.0005632719229553916,
#              'flat-out': 2.7476679168555687e-05,
#              'amusing': 0.00028850513126983473,
#              'endearing': 0.00013738339584277843,
#              'often': 0.0006869169792138922,
#              'cast': 0.0008243003750566706,
#              'dialogue': 0.00026102845210127906,
#              'wide': 4.121501875283353e-05,
#              'effective': 0.0001511217354270563,
#              'sight': 6.869169792138922e-05,
#              'gags': 6.869169792138922e-05,
#              'events': 0.00020607509376416766,
#              'her': 0.0009067304125623377,
#              'imagery': 0.00010990671667422275,
#              'paintings': 2.7476679168555687e-05,
#              'so': 0.0017859841459561198,
#              'vividly': 0.00013738339584277843,
#              'artist': 0.00017859841459561196,
#              'work': 0.0012501889021692839,
#              'may': 0.0011677588646636168,
#              'take': 0.0005907486021239473,
#              'striking': 0.00010990671667422275,
#              'significance': 2.7476679168555687e-05,
#              'anyone': 0.0002472901125170012,
#              'sees': 6.869169792138922e-05,
#              'no': 0.0007693470167195593,
#              'original': 0.0004121501875283353,
#              'memorable': 0.0002198134333484455,
#              'downtown': 2.7476679168555687e-05,
#              'saturday': 5.4953358337111374e-05,
#              'matinee': 4.121501875283353e-05,
#              'brain': 5.4953358337111374e-05,
#              'candy': 5.4953358337111374e-05,
#              'does': 0.001318880600090673,
#              "n't": 0.0022943027105744,
#              'disappoint': 2.7476679168555687e-05,
#              'any': 0.0007556086771352814,
#              'something': 0.0007418703375510036,
#              'can': 0.0013875722980120622,
#              'enjoy': 0.00028850513126983473,
#              'manages': 0.0004258885271126132,
#              'deliver': 0.00010990671667422275,
#              'fair': 8.243003750566706e-05,
#              'bit': 0.0003159818104383904,
#              'once': 0.00045336520628116886,
#              'impact': 0.00013738339584277843,
#              'day': 0.00028850513126983473,
#              'unfolds': 0.0001511217354270563,
#              'power': 0.0003709351687755018,
#              'undeniable': 8.243003750566706e-05,
#              'wave': 5.4953358337111374e-05,
#              'monster': 6.869169792138922e-05,
#              'ages': 0.00013738339584277843,
#              'plenty': 0.00013738339584277843,
#              'warmth': 0.00017859841459561196,
#              'go': 0.00039841184794405746,
#              'around': 0.00019233675417988983,
#              'laughter': 9.616837708994491e-05,
#              'love': 0.00140131063759634,
#              'family': 0.0007556086771352814,
#              'quite': 0.0003709351687755018,
#              'providing': 5.4953358337111374e-05,
#              'old': 0.00027476679168555686,
#              'fashioned': 2.7476679168555687e-05,
#              'deliciously': 5.4953358337111374e-05,
#              'exploitative': 4.121501875283353e-05,
#              'standard': 0.00010990671667422275,
#              'guns': 5.4953358337111374e-05,
#              'versus': 4.121501875283353e-05,
#              'martial': 4.121501875283353e-05,
#              'arts': 2.7476679168555687e-05,
#              'cliche': 2.7476679168555687e-05,
#              'added': 4.121501875283353e-05,
#              'potential': 6.869169792138922e-05,
#              'making': 0.0003159818104383904,
#              'them': 0.000618225281292503,
#              'meaningful': 5.4953358337111374e-05,
#              'both': 0.0009891604500680048,
#              'adults': 0.0001511217354270563,
#              'kind': 0.0004671035458654467,
#              'entertainment': 0.0003709351687755018,
#              'parents': 0.00019233675417988983,
#              'their': 0.0014425256563491736,
#              'see': 0.0007418703375510036,
#              'plot': 0.00038467350835977965,
#              'weaves': 2.7476679168555687e-05,
#              'into': 0.0016211240709447857,
#              'web': 6.869169792138922e-05,
#              'like': 0.0019783209001360096,
#              'builds': 6.869169792138922e-05,
#              'we': 0.0009891604500680048,
#              'started': 5.4953358337111374e-05,
#              'passionate': 8.243003750566706e-05,
#              'affair': 4.121501875283353e-05,
#              'sand': 6.869169792138922e-05,
#              'masculine': 2.7476679168555687e-05,
#              'persona': 5.4953358337111374e-05,
#              'beauty': 0.00023355177293272336,
#              'takes': 0.0003709351687755018,
#              'form': 0.00017859841459561196,
#              'enough': 0.0010441138084051162,
#              'cool': 0.00017859841459561196,
#              'here': 0.00039841184794405746,
#              'warm': 0.00027476679168555686,
#              'hearts': 9.616837708994491e-05,
#              'animation': 0.00016486007501133413,
#              'originality': 0.0001236450562585006,
#              'distance': 6.869169792138922e-05,
#              'from': 0.002816359614776958,
#              'pack': 6.869169792138922e-05,
#              'paint-by-number': 2.7476679168555687e-05,
#              'romantic': 0.0006044869417082252,
#              'comedies': 0.00020607509376416766,
#              'end': 0.000439626866696891,
#              'up': 0.001332618939674951,
#              'cinema': 0.0006044869417082252,
#              'screens': 2.7476679168555687e-05,
#              'very': 0.0010441138084051162,
#              'wise': 0.0001236450562585006,
#              'gifted': 8.243003750566706e-05,
#              'hand': 9.616837708994491e-05,
#              'keep': 0.0005083185646182802,
#              'things': 0.00032972015002266826,
#              'ground': 4.121501875283353e-05,
#              'dramatically': 4.121501875283353e-05,
#              'machine': 2.7476679168555687e-05,
#              'ultimately': 0.00035719682919122393,
#              'achieving': 2.7476679168555687e-05,
#              'modest': 0.00010990671667422275,
#              'goals': 2.7476679168555687e-05,
#              'sets': 0.00013738339584277843,
#              'itself': 0.0004121501875283353,
#              'levels': 5.4953358337111374e-05,
#              'worth': 0.0006319636208767808,
#              'seeing': 0.0002472901125170012,
#              'least': 0.0003434584896069461,
#              '10': 4.121501875283353e-05,
#              'minutes': 0.00017859841459561196,
#              'unable': 2.7476679168555687e-05,
#              'look': 0.0009479454313151712,
#              'away': 0.00032972015002266826,
#              '300': 4.121501875283353e-05,
#              'years': 0.0005770102625396695,
#              'russian': 9.616837708994491e-05,
#              'compressed': 2.7476679168555687e-05,
#              'sumptuous': 4.121501875283353e-05,
#              'stream': 2.7476679168555687e-05,
#              'consciousness': 4.121501875283353e-05,
#              'appeal': 0.00016486007501133413,
#              'pokemon': 4.121501875283353e-05,
#              'videos': 2.7476679168555687e-05,
#              'breathes': 4.121501875283353e-05,
#              'big': 0.0006594403000453365,
#              'slowly': 6.869169792138922e-05,
#              'b-movie': 6.869169792138922e-05,
#              'sit': 5.4953358337111374e-05,
#              'through': 0.0007281319979667258,
#              'certain': 0.0001236450562585006,
#              'level': 0.00013738339584277843,
#              'then': 0.0003159818104383904,
#              'forget': 9.616837708994491e-05,
#              'french': 0.00035719682919122393,
#              'flavor': 2.7476679168555687e-05,
#              'backstage': 4.121501875283353e-05,
#              'must-see': 4.121501875283353e-05,
#              'fans': 0.0003434584896069461,
#              'beautiful': 0.0004258885271126132,
#              'two': 0.0006869169792138922,
#              'hours': 0.00016486007501133413,
#              'timeless': 5.4953358337111374e-05,
#              'universal': 0.0001511217354270563,
#              'heated': 2.7476679168555687e-05,
#              'passions': 4.121501875283353e-05,
#              'jealousy': 5.4953358337111374e-05,
#              'betrayal': 5.4953358337111374e-05,
#              'forgiveness': 2.7476679168555687e-05,
#              'murder': 0.00010990671667422275,
#              'past': 0.0001511217354270563,
#              'observed': 2.7476679168555687e-05,
#              'character': 0.0005907486021239473,
#              'action': 0.0005083185646182802,
#              'korea': 5.4953358337111374e-05,
#              'beguiling': 4.121501875283353e-05,
#              'evocation': 2.7476679168555687e-05,
#              'quality': 0.0001236450562585006,
#              'keeps': 0.00016486007501133413,
#              'dickens': 8.243003750566706e-05,
#              ':': 0.0006869169792138922,
#              'openness': 6.869169792138922e-05,
#              'which': 0.000879253733393782,
#              'he': 0.001057852147989394,
#              'our': 0.0005495335833711137,
#              'basic': 4.121501875283353e-05,
#              'emotions': 0.00016486007501133413,
#              'pure': 0.00020607509376416766,
#              'distinct': 2.7476679168555687e-05,
#              'rarity': 2.7476679168555687e-05,
#              'event': 6.869169792138922e-05,
#              'times': 0.0003709351687755018,
#              'people': 0.0007418703375510036,
#              'romances': 4.121501875283353e-05,
#              'realism': 9.616837708994491e-05,
#              'bittersweet': 0.0001236450562585006,
#              'contemporary': 0.00017859841459561196,
#              'deception': 2.7476679168555687e-05,
#              'not': 0.002637761200181346,
#              'rival': 4.121501875283353e-05,
#              'filmmaker': 0.00028850513126983473,
#              'period': 0.0001511217354270563,
#              'pieces': 0.0001236450562585006,
#              'grief': 0.0001236450562585006,
#              'open': 6.869169792138922e-05,
#              'door': 2.7476679168555687e-05,
#              'liberation': 2.7476679168555687e-05,
#              'simple': 0.0002472901125170012,
#              'bracing': 5.4953358337111374e-05,
#              'unblinking': 4.121501875283353e-05,
#              'serves': 5.4953358337111374e-05,
#              'painful': 9.616837708994491e-05,
#              'sobering': 6.869169792138922e-05,
#              'cautionary': 4.121501875283353e-05,
#              'breathtaking': 9.616837708994491e-05,
#              'spirit': 0.0003159818104383904,
#              'tells': 0.00010990671667422275,
#              'poignant': 0.00019233675417988983,
#              'uplifting': 9.616837708994491e-05,
#              'stunning': 0.0001236450562585006,
#              'images': 0.00023355177293272336,
#              'breezy': 6.869169792138922e-05,
#              'blend': 9.616837708994491e-05,
#              'art': 0.00039841184794405746,
#              'philosophy': 2.7476679168555687e-05,
#              'inventive': 0.00020607509376416766,
#              'thoroughly': 0.00017859841459561196,
#              'winning': 0.00019233675417988983,
#              'revisionist': 2.7476679168555687e-05,
#              'fancy': 4.121501875283353e-05,
#              'brilliant': 0.0002472901125170012,
#              'absurd': 2.7476679168555687e-05,
#              'collection': 4.121501875283353e-05,
#              'vignettes': 2.7476679168555687e-05,
#              'own': 0.0007281319979667258,
#              'idiosyncratic': 5.4953358337111374e-05,
#              'strange': 0.00019233675417988983,
#              'horror': 0.00023355177293272336,
#              'brisk': 2.7476679168555687e-05,
#              'reverent': 2.7476679168555687e-05,
#              'subtly': 4.121501875283353e-05,
#              'different': 0.00023355177293272336,
#              'brutal': 6.869169792138922e-05,
#              'buoyant': 8.243003750566706e-05,
#              'friendship': 9.616837708994491e-05,
#              'truth': 0.00013738339584277843,
#              'together': 0.00038467350835977965,
#              'burst': 4.121501875283353e-05,
#              'color': 8.243003750566706e-05,
#              'dance': 5.4953358337111374e-05,
#              'fail': 2.7476679168555687e-05,
#              'crack': 4.121501875283353e-05,
#              'smile': 9.616837708994491e-05,
#              'captivating': 9.616837708994491e-05,
#              'intimate': 0.00016486007501133413,
#              'study': 0.00038467350835977965,
#              'dying': 5.4953358337111374e-05,
#              'loving': 4.121501875283353e-05,
#              'first': 0.0005770102625396695,
#              'narrative': 0.0002472901125170012,
#              'truly': 0.00020607509376416766,
#              'age': 0.00013738339584277843,
#              'quirky': 0.00035719682919122393,
#              'hybrid': 5.4953358337111374e-05,
#              'chance': 0.00013738339584277843,
#              'three': 0.00020607509376416766,
#              'splendid': 0.00010990671667422275,
#              'actors': 0.0005083185646182802,
#              'turn': 0.0002198134333484455,
#              'chase': 6.869169792138922e-05,
#              'exploration': 0.00010990671667422275,
#              'need': 0.00027476679168555686,
#              'somebody': 4.121501875283353e-05,
#              'charmer': 9.616837708994491e-05,
#              'belgium': 2.7476679168555687e-05,
#              'charming': 0.0004121501875283353,
#              'those': 0.0007830853563038371,
#              'cinematic': 0.00035719682919122393,
#              'whose': 0.00039841184794405746,
#              'aims': 2.7476679168555687e-05,
#              'seem': 0.0002198134333484455,
#              'deceptively': 8.243003750566706e-05,
#              'slight': 0.0001511217354270563,
#              'surface': 8.243003750566706e-05,
#              'chilling': 0.00013738339584277843,
#              'without': 0.0007693470167195593,
#              'oppressive': 2.7476679168555687e-05,
#              'crimes': 2.7476679168555687e-05,
#              '20th': 5.4953358337111374e-05,
#              'century': 0.0001236450562585006,
#              'france': 6.869169792138922e-05,
#              'servants': 2.7476679168555687e-05,
#              'chilly': 5.4953358337111374e-05,
#              'brooding': 4.121501875283353e-05,
#              'resonant': 9.616837708994491e-05,
#              'psychological': 0.00019233675417988983,
#              'tension': 0.0001236450562585006,
#              'chronicle': 2.7476679168555687e-05,
#              'man': 0.0005770102625396695,
#              'quest': 2.7476679168555687e-05,
#              'president': 2.7476679168555687e-05,
#              'turned': 4.121501875283353e-05,
#              'plane': 2.7476679168555687e-05,
#              'what': 0.0018684141834617869,
#              'was': 0.0005770102625396695,
#              'essentially': 5.4953358337111374e-05,
#              'extended': 5.4953358337111374e-05,
#              'classic': 0.0001511217354270563,
#              'fairy': 2.7476679168555687e-05,
#              'perfectly': 0.00023355177293272336,
#              'captures': 0.00026102845210127906,
#              'wonders': 6.869169792138922e-05,
#              'childhood': 5.4953358337111374e-05,
#              'ever': 0.0006869169792138922,
#              'sprightly': 4.121501875283353e-05,
#              'spin': 4.121501875283353e-05,
#              'clever': 0.0003022434708541126,
#              'script': 0.0003434584896069461,
#              'bring': 0.0002198134333484455,
#              'energy': 0.00026102845210127906,
#              'familiar': 0.0003022434708541126,
#              'topic': 4.121501875283353e-05,
#              'office': 6.869169792138922e-05,
#              'politics': 9.616837708994491e-05,
#              'colorful': 0.00017859841459561196,
#              'joyous': 0.0001236450562585006,
#              'celebration': 4.121501875283353e-05,
#              ';': 0.0004121501875283353,
#              'tapestry': 2.7476679168555687e-05,
#              'woven': 4.121501875283353e-05,
#              'romance': 0.00026102845210127906,
#              'dancing': 5.4953358337111374e-05,
#              'singing': 5.4953358337111374e-05,
#              'unforgettable': 4.121501875283353e-05,
#              'vibrant': 0.00013738339584277843,
#              'introduction': 4.121501875283353e-05,
#              'photographed': 6.869169792138922e-05,
#              'inviting': 4.121501875283353e-05,
#              'surprising': 0.00020607509376416766,
#              'rhythms': 8.243003750566706e-05,
#              'comedy-drama': 4.121501875283353e-05,
#              'nearly': 0.00017859841459561196,
#              'epic': 0.0001511217354270563,
#              'proportions': 2.7476679168555687e-05,
#              'sincere': 6.869169792138922e-05,
#              'performance': 0.0008105620354723928,
#              'title': 0.00016486007501133413,
#              'midlife': 2.7476679168555687e-05,
#              'crisis': 2.7476679168555687e-05,
#              'hollywood': 0.0004945802250340024,
#              'would': 0.0006594403000453365,
#              'guts': 4.121501875283353e-05,
#              'languid': 2.7476679168555687e-05,
#              'air': 0.0001511217354270563,
#              'balanced': 2.7476679168555687e-05,
#              'visual': 0.00032972015002266826,
#              'clarity': 8.243003750566706e-05,
#              'felt': 0.00017859841459561196,
#              'across': 0.00013738339584277843,
#              'board': 2.7476679168555687e-05,
#              'compelling': 0.0005907486021239473,
#              'along': 0.00020607509376416766,
#              'emotion': 8.243003750566706e-05,
#              'explores': 5.4953358337111374e-05,
#              'awful': 4.121501875283353e-05,
#              'complications': 2.7476679168555687e-05,
#              'terrifying': 6.869169792138922e-05,
#              'encounter': 6.869169792138922e-05,
#              'aloof': 2.7476679168555687e-05,
#              'father': 8.243003750566706e-05,
#              'son': 0.0001236450562585006,
#              'after': 0.00039841184794405746,
#              '20': 4.121501875283353e-05,
#              'apart': 0.0001236450562585006,
#              'last': 0.00032972015002266826,
#              'days': 0.00013738339584277843,
#              'journey': 0.00026102845210127906,
#              'sensitive': 0.00017859841459561196,
#              'young': 0.000439626866696891,
#              'girl': 0.0002472901125170012,
#              'foster': 6.869169792138922e-05,
#              'homes': 2.7476679168555687e-05,
#              'struggle': 0.00010990671667422275,
#              'pull': 6.869169792138922e-05,
#              'free': 5.4953358337111374e-05,
#              'dangerous': 6.869169792138922e-05,
#              'mother': 9.616837708994491e-05,
#              'hold': 0.00010990671667422275,
#              'motion': 9.616837708994491e-05,
#              'picture': 0.0004945802250340024,
#              'illustrates': 4.121501875283353e-05,
#              'american': 0.0004671035458654467,
#              'tragedy': 0.0002198134333484455,
#              'moving': 0.0005907486021239473,
#              'message': 0.00020607509376416766,
#              'musical': 0.00010990671667422275,
#              'passion': 0.00019233675417988983,
#              'against': 0.00019233675417988983,
#              'odds': 6.869169792138922e-05,
#              'yarn': 0.00010990671667422275,
#              'ripping': 2.7476679168555687e-05,
#              'competent': 2.7476679168555687e-05,
#              'unpretentious': 2.7476679168555687e-05,
#              'destined': 5.4953358337111374e-05,
#              'fill': 2.7476679168555687e-05,
#              'theaters': 5.4953358337111374e-05,
#              'country': 9.616837708994491e-05,
#              'completely': 0.0001511217354270563,
#              'spooky': 8.243003750566706e-05,
#              'business': 9.616837708994491e-05,
#              'gets': 0.0003434584896069461,
#              'under': 0.0002198134333484455,
#              'skin': 0.00010990671667422275,
#              'aside': 6.869169792138922e-05,
#              'stays': 6.869169792138922e-05,
#              'duration': 2.7476679168555687e-05,
#              'returns': 9.616837708994491e-05,
#              'decades': 0.0001236450562585006,
#              'kiddie': 2.7476679168555687e-05,
#              'sophisticated': 0.0001511217354270563,
#              'wit': 0.00026102845210127906,
#              'symbolic': 4.121501875283353e-05,
#              'graphic': 4.121501875283353e-05,
#              'design': 6.869169792138922e-05,
#              'conventional': 6.869169792138922e-05,
#              'well-crafted': 5.4953358337111374e-05,
#              'historic': 2.7476679168555687e-05,
#              'legal': 4.121501875283353e-05,
#              'right': 0.00048084188544972453,
#              'raise': 2.7476679168555687e-05,
#              'children': 0.0003434584896069461,
#              'heartwarming': 0.0001236450562585006,
#              'creepy': 0.00013738339584277843,
#              'intermittently': 4.121501875283353e-05,
#              'self-destructive': 2.7476679168555687e-05,
#              'unsettling': 0.00017859841459561196,
#              'watch': 0.00039841184794405746,
#              'procedure': 2.7476679168555687e-05,
#              'autopsy': 2.7476679168555687e-05,
#              'cultural': 0.00010990671667422275,
#              'experience': 0.0004671035458654467,
#              'unusual': 8.243003750566706e-05,
#              'nutty': 2.7476679168555687e-05,
#              'addition': 9.616837708994491e-05,
#              'being': 0.0006044869417082252,
#              'embarrassment': 2.7476679168555687e-05,
#              'bumbling': 2.7476679168555687e-05,
#              'twist': 6.869169792138922e-05,
#              'damn': 6.869169792138922e-05,
#              'fine': 0.00026102845210127906,
#              'distinctive': 5.4953358337111374e-05,
#              'pertinent': 4.121501875283353e-05,
#              'road': 0.00016486007501133413,
#              'constantly': 4.121501875283353e-05,
#              'defies': 4.121501875283353e-05,
#              'expectation': 4.121501875283353e-05,
#              'dashing': 2.7476679168555687e-05,
#              'outing': 2.7476679168555687e-05,
#              'directors': 8.243003750566706e-05,
#              'dazzling': 0.00010990671667422275,
#              'dream': 0.00013738339584277843,
#              'documentary': 0.0007418703375510036,
#              'thing': 0.0003159818104383904,
#              'behold': 8.243003750566706e-05,
#              'somewhat': 0.00017859841459561196,
#              '3d': 2.7476679168555687e-05,
#              'theater': 0.0001511217354270563,
#              'provides': 0.00019233675417988983,
#              'stands': 6.869169792138922e-05,
#              'hit': 0.00016486007501133413,
#              'franklin': 4.121501875283353e-05,
#              'stay': 8.243003750566706e-05,
#              'afloat': 2.7476679168555687e-05,
#              'detailed': 0.0001236450562585006,
#              'world': 0.0007968236958881149,
#              'deft': 9.616837708994491e-05,
#              'delightful': 0.00026102845210127906,
#              'mix': 0.0001511217354270563,
#              'teen': 0.00013738339584277843,
#              'deftly': 0.00010990671667422275,
#              'smartly': 9.616837708994491e-05,
#              'played': 9.616837708994491e-05,
#              'directed': 0.0002472901125170012,
#              'account': 2.7476679168555687e-05,
#              'lifestyle': 2.7476679168555687e-05,
#              'post': 4.121501875283353e-05,
#              'terrific': 0.00035719682919122393,
#              'screenplay': 0.00023355177293272336,
#              'fanciful': 6.869169792138922e-05,
#              'direction': 0.00035719682919122393,
#              'michael': 0.00023355177293272336,
#              'gondry': 2.7476679168555687e-05,
#              'delicately': 9.616837708994491e-05,
#              'neighborhood': 5.4953358337111374e-05,
#              'tosses': 2.7476679168555687e-05,
#              'city': 0.00016486007501133413,
#              'coming': 8.243003750566706e-05,
#              'seams': 4.121501875283353e-05,
#              'minor': 0.00013738339584277843,
#              'tradition': 5.4953358337111374e-05,
#              'food': 9.616837708994491e-05,
#              'simplicity': 5.4953358337111374e-05,
#              'mostly': 0.00019233675417988983,
#              'martha': 8.243003750566706e-05,
#              'leave': 0.0002472901125170012,
#              'face': 0.0003159818104383904,
#              'stomach': 4.121501875283353e-05,
#              'nerves': 4.121501875283353e-05,
#              'feels': 0.0002472901125170012,
#              'every': 0.000439626866696891,
#              'other': 0.0005495335833711137,
#              'tomorrow': 5.4953358337111374e-05,
#              'surprise': 0.00013738339584277843,
#              'because': 0.0005907486021239473,
#              'stories': 0.00023355177293272336,
#              'looks': 0.00017859841459561196,
#              'professional': 4.121501875283353e-05,
#              'reserved': 2.7476679168555687e-05,
#              'type': 2.7476679168555687e-05,
#              'survival': 2.7476679168555687e-05,
#              'less': 0.00027476679168555686,
#              'ii': 9.616837708994491e-05,
#              'specific': 2.7476679168555687e-05,
#              'lost': 0.00013738339584277843,
#              'midst': 2.7476679168555687e-05,
#              'tedious': 4.121501875283353e-05,
#              'director': 0.0011814972042478945,
#              'viewers': 0.00013738339584277843,
#              'buffs': 5.4953358337111374e-05,
#              'should': 0.0006044869417082252,
#              'get': 0.0004258885271126132,
#              'know': 0.00026102845210127906,
#              'directorial': 9.616837708994491e-05,
#              'tour': 8.243003750566706e-05,
#              'de': 0.0002472901125170012,
#              'force': 0.0001511217354270563,
#              'bernard': 2.7476679168555687e-05,
#              'rose': 4.121501875283353e-05,
#              'occasionally': 0.0001511217354270563,
#              'saga': 6.869169792138922e-05,
#              'packed': 6.869169792138922e-05,
#              'moments': 0.0005357952437868359,
#              'alice': 4.121501875283353e-05,
#              'condensed': 2.7476679168555687e-05,
#              'season': 0.00010990671667422275,
#              'tv': 5.4953358337111374e-05,
#              'brother': 5.4953358337111374e-05,
#              'distinguished': 4.121501875283353e-05,
#              'marked': 2.7476679168555687e-05,
#              'acute': 2.7476679168555687e-05,
#              'host': 2.7476679168555687e-05,
#              'diverse': 5.4953358337111374e-05,
#              'astonishingly': 4.121501875283353e-05,
#              'articulate': 2.7476679168555687e-05,
#              'israeli': 2.7476679168555687e-05,
#              'dreadful': 2.7476679168555687e-05,
#              'irish': 2.7476679168555687e-05,
#              'given': 0.0001236450562585006,
#              'flawed': 0.00013738339584277843,
#              'treatment': 0.00010990671667422275,
#              'fairly': 0.00019233675417988983,
#              'mixture': 6.869169792138922e-05,
#              'guy': 5.4953358337111374e-05,
#              'caper': 6.869169792138922e-05,
#              'lock': 2.7476679168555687e-05,
#              'stock': 6.869169792138922e-05,
#              'smoking': 2.7476679168555687e-05,
#              'barrels': 2.7476679168555687e-05,
#              'thematic': 2.7476679168555687e-05,
#              'material': 0.00032972015002266826,
#              'death': 0.00013738339584277843,
#              'needed': 8.243003750566706e-05,
#              'live': 0.00016486007501133413,
#              'napoleon': 5.4953358337111374e-05,
#              'vital': 2.7476679168555687e-05,
#              'real': 0.0006594403000453365,
#              'humor': 0.0006731786396296143,
#              'sensuality': 2.7476679168555687e-05,
#              'sympathy': 5.4953358337111374e-05,
#              'adolescent': 6.869169792138922e-05,
#              'boys': 6.869169792138922e-05,
#              'fascinating': 0.0006044869417082252,
#              'americans': 5.4953358337111374e-05,
#              'regardless': 4.121501875283353e-05,
#              'whether': 0.0001236450562585006,
#              'ultimate': 0.00010990671667422275,
#              'blame': 4.121501875283353e-05,
#              'finally': 0.00019233675417988983,
#              'lies': 8.243003750566706e-05,
#              'kissinger': 6.869169792138922e-05,
#              'lurid': 4.121501875283353e-05,
#              'fiction': 8.243003750566706e-05,
#              'unnerving': 5.4953358337111374e-05,
#              'examination': 0.00019233675417988983,
#              'case': 0.00010990671667422275,
#              'price': 6.869169792138922e-05,
#              'paid': 5.4953358337111374e-05,
#              'spiritual': 9.616837708994491e-05,
#              'helped': 2.7476679168555687e-05,
#              'revealing': 9.616837708994491e-05,
#              'overview': 2.7476679168555687e-05,
#              'ancient': 4.121501875283353e-05,
#              'healing': 2.7476679168555687e-05,
#              'system': 5.4953358337111374e-05,
#              'turbulent': 2.7476679168555687e-05,
#              'self-discovery': 4.121501875283353e-05,
#              'made': 0.0007281319979667258,
#              'proper': 2.7476679168555687e-05,
#              'middle-aged': 4.121501875283353e-05,
#              'woman': 0.00028850513126983473,
#              'literary': 8.243003750566706e-05,
#              'mystery': 0.00013738339584277843,
#              'multiple': 2.7476679168555687e-05,
#              'controversy': 4.121501875283353e-05,
#              'really': 0.0005907486021239473,
#              'plays': 0.00013738339584277843,
#              'fast': 8.243003750566706e-05,
#              'paced': 5.4953358337111374e-05,
#              'shadow': 2.7476679168555687e-05,
#              'side': 0.0001511217354270563,
#              'play': 0.00017859841459561196,
#              'faster': 4.121501875283353e-05,
#              'flick': 0.00026102845210127906,
#              'when': 0.0007281319979667258,
#              'joy': 9.616837708994491e-05,
#              'likely': 0.00017859841459561196,
#              'enter': 4.121501875283353e-05,
#              'fiercely': 2.7476679168555687e-05,
#              'subtle': 0.00019233675417988983,
#              'capturing': 5.4953358337111374e-05,
#              'balance': 9.616837708994491e-05,
#              'extravagant': 4.121501875283353e-05,
#              'confidence': 5.4953358337111374e-05,
#              'cruel': 5.4953358337111374e-05,
#              'earnestness': 4.121501875283353e-05,
#              'female': 0.00013738339584277843,
#              'men': 0.00023355177293272336,
#              'embrace': 4.121501875283353e-05,
#              'talk': 8.243003750566706e-05,
#              'centering': 2.7476679168555687e-05,
#              'traditional': 9.616837708994491e-05,
#              'indian': 9.616837708994491e-05,
#              'wedding': 0.00016486007501133413,
#              'sound': 8.243003750566706e-05,
#              'fare': 0.0001511217354270563,
#              'absolute': 2.7476679168555687e-05,
#              'audiences': 0.00019233675417988983,
#              'class': 0.0001511217354270563,
#              'spike': 5.4953358337111374e-05,
#              'lee': 0.0001236450562585006,
#              'masterful': 8.243003750566706e-05,
#              'do': 0.00070065531879817,
#              'neither': 9.616837708994491e-05,
#              'bitter': 4.121501875283353e-05,
#              'nor': 0.00010990671667422275,
#              'sweet': 0.00048084188544972453,
#              'comedic': 8.243003750566706e-05,
#              'fuzzy': 4.121501875283353e-05,
#              'delicate': 0.0001511217354270563,
#              'feeling': 0.0003159818104383904,
#              'friendships': 2.7476679168555687e-05,
#              'ideas': 0.00020607509376416766,
#              'wry': 0.00010990671667422275,
#              'comic': 0.000439626866696891,
#              'mayhem': 6.869169792138922e-05,
#              'quiet': 0.0002198134333484455,
#              'equal': 2.7476679168555687e-05,
#              'measure': 6.869169792138922e-05,
#              'everyday': 5.4953358337111374e-05,
#              'lives': 0.00026102845210127906,
#              'san': 2.7476679168555687e-05,
#              'ends': 5.4953358337111374e-05,
#              'heartbreaking': 0.00010990671667422275,
#              'tears': 8.243003750566706e-05,
#              'eyes': 0.00027476679168555686,
#              'saw': 6.869169792138922e-05,
#              'appreciated': 2.7476679168555687e-05,
#              ...})

# %%
[w for w in pos_bigram_freqs_with_unknown if w[1] == '<unk>']
pos_bigram_freqs_with_unknown[('<unk>', '<unk>')]
# Out:
# 0.10142173338118846

# %%
calculate_perplexity_unigram(pos_corpus_with_unknown[1], pos_unigram_freqs_with_unknown)
calculate_perplexity_bigram(pos_bigram_corpus_with_unknown[1], neg_bigram_freqs_with_unknown, neg_unigram_freqs_with_unknown['<s>'])

dev_pos_corpus = get_corpus('SentimentDataset/Dev/pos.txt')
dev_neg_corpus = get_corpus('SentimentDataset/Dev/neg.txt')
dev_pos_corpus_with_unknown = get_corpus_with_unknown(dev_pos_corpus)
dev_neg_corpus_with_unknown = get_corpus_with_unknown(dev_neg_corpus)
dev_pos_unigram_freqs_with_unknown = get_unigram_freqs(dev_pos_corpus_with_unknown)
dev_neg_unigram_freqs_with_unknown = get_unigram_freqs(dev_neg_corpus_with_unknown)
dev_pos_bigram_freqs_with_unknown = get_bigram_freqs(dev_pos_corpus_with_unknown, dev_pos_unigram_freqs_with_unknown)
dev_neg_bigram_freqs_with_unknown = get_bigram_freqs(dev_neg_corpus_with_unknown, dev_neg_unigram_freqs_with_unknown)
dev_pos_bigram_corpus_with_unknown = get_bigram_corpus(dev_pos_corpus_with_unknown)
dev_neg_bigram_corpus_with_unknown = get_bigram_corpus(dev_neg_corpus_with_unknown)

# %%
def predict_with_unigram_perplexity(corpus, pos_model, neg_model):
    res = []
    for line in corpus:
        pos_pp = calculate_perplexity_unigram_sentence(line, pos_model)
        neg_pp = calculate_perplexity_unigram_sentence(line, neg_model)
        if pos_pp < neg_pp:
            res.append(0)
        else:
            res.append(1)
    return res


def predict_with_bigram_perplexity(corpus, pos_model, neg_model):
    res = []
    for line in corpus:
        pos_pp = calculate_perplexity_bigram_sentence(line, pos_model, pos_unigram_freqs_with_unknown_smoothed['<s>'])
        neg_pp = calculate_perplexity_bigram_sentence(line, neg_model, neg_unigram_freqs_with_unknown_smoothed['<s>'])
        if pos_pp < neg_pp:
            res.append(0)
        else:
            res.append(1)
    return res

def accuracy(prediction, actual):
    return 1 - sum([1 for i in range(len(prediction)) if prediction[i] != actual[i]]) * 1.0 / len(prediction)

# %%
### perplexity does not produce good results
dev_pos_pred_uni_pp = predict_with_unigram_perplexity(dev_pos_corpus_with_unknown, pos_unigram_freqs_with_unknown_smoothed, neg_unigram_freqs_with_unknown_smoothed)
print(accuracy(dev_pos_pred_uni_pp, [0 for l in range(len(dev_pos_pred_uni_pp))]))

dev_neg_pred_uni_pp = predict_with_unigram_perplexity(dev_neg_corpus_with_unknown, pos_unigram_freqs_with_unknown_smoothed, neg_unigram_freqs_with_unknown_smoothed)
print(accuracy(dev_neg_pred_uni_pp, [0 for l in range(len(dev_neg_pred_uni_pp))]))
# Out:
# 0.38129496402877694
# 0.321078431372549

# %%
dev_pos_pred_bi_pp = predict_with_bigram_perplexity(dev_pos_corpus_with_unknown, pos_bigram_freqs_with_unknown_smoothed, neg_bigram_freqs_with_unknown_smoothed)
print(accuracy(dev_pos_pred_bi_pp, [0 for l in range(len(dev_pos_pred_bi_pp))]))

dev_neg_pred_bi_pp = predict_with_bigram_perplexity(dev_neg_corpus_with_unknown, pos_bigram_freqs_with_unknown_smoothed, neg_bigram_freqs_with_unknown_smoothed)
print(accuracy(dev_neg_pred_bi_pp, [0 for l in range(len(dev_neg_pred_bi_pp))]))
# Out:
# 0.2757793764988009
# 0.42156862745098034

# %%
test_corpus = get_corpus('SentimentDataset/Test/test.txt')
test_corpus_with_unknown = get_corpus_with_unknown(test_corpus)
test_bigram_corpus_with_unknown = get_bigram_corpus(test_corpus_with_unknown)

test_pred_uni_pp = predict_with_unigram_perplexity(test_corpus_with_unknown, pos_unigram_freqs_with_unknown, neg_unigram_freqs_with_unknown)
test_pred_bi_pp = predict_with_bigram_perplexity(test_bigram_corpus_with_unknown, pos_bigram_freqs_with_unknown, neg_bigram_freqs_with_unknown)

# %%
pred_file = open('section6.csv', 'w')
pred_file.write('Id,Prediction\n')
for i in range(len(test_pred_uni_pp)):
    pred_file.write(str(i + 1) + ',' + str(test_pred_bi_pp[i]) + '\n')
pred_file.close()

# %%
def smooth(_lambda, unigram_model, bigram_model):
    new_model = defaultdict(float)
    for w in bigram_model:
        if len(w) == 2:
            new_model[w] = _lambda * bigram_model[w] + (1.0 - _lambda) * unigram_model[w[1]]
    return new_model

# %%
pos_mixed_freqs = smooth(0.9, pos_unigram_freqs, pos_bigram_freqs)
print(calculate_perplexity(pos_mixed_freqs))

pos_mixed_freqs_with_unknown = smooth(0.9, pos_unigram_freqs_with_unknown, pos_bigram_freqs_with_unknown)
print(calculate_perplexity(pos_mixed_freqs_with_unknown))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-770b3972806f> in <module>()
#       1 pos_mixed_freqs = smooth(0.9, pos_unigram_freqs, pos_bigram_freqs)
# ----> 2 print(calculate_perplexity(pos_mixed_freqs))
#       3
#       4 pos_mixed_freqs_with_unknown = smooth(0.9, pos_unigram_freqs_with_unknown, pos_bigram_freqs_with_unknown)
#       5 print(calculate_perplexity(pos_mixed_freqs_with_unknown))
#
# NameError: name 'calculate_perplexity' is not defined

# %%
[w for w in pos_bigram_freqs if w[0] == "'s"]
# Out:
# [("'s", 'mouth'),
#  ("'s", 'endgame'),
#  ("'s", 'done'),
#  ("'s", 'new'),
#  ("'s", 'work'),
#  ("'s", 'as'),
#  ("'s", 'bolero'),
#  ("'s", 'masculine'),
#  ("'s", 'enough'),
#  ("'s", 'period'),
#  ("'s", 'quest'),
#  ("'s", 'end'),
#  ("'s", 'democratic'),
#  ("'s", 'hold'),
#  ("'s", 'home'),
#  ("'s", 'right'),
#  ("'s", 'most'),
#  ("'s", 'forgivable'),
#  ("'s", 'big'),
#  ("'s", 'last'),
#  ("'s", 'plays'),
#  ("'s", 'film'),
#  ("'s", 'masterful'),
#  ("'s", 'flawed'),
#  ("'s", 'ability'),
#  ("'s", 'saccharine'),
#  ("'s", 'suitable'),
#  ("'s", 'never'),
#  ("'s", '.'),
#  ("'s", 'finest'),
#  ("'s", 'occupational'),
#  ("'s", 'time'),
#  ("'s", 'movie'),
#  ("'s", 'afraid'),
#  ("'s", 'every'),
#  ("'s", 'two'),
#  ("'s", 'diary'),
#  ("'s", 'potentially'),
#  ("'s", 'stone'),
#  ("'s", 'meow'),
#  ("'s", 'good'),
#  ("'s", 'winning'),
#  ("'s", 'complexity'),
#  ("'s", 'travel'),
#  ("'s", 'a'),
#  ("'s", 'fans'),
#  ("'s", 'attempts'),
#  ("'s", 'similarly'),
#  ("'s", 'next'),
#  ("'s", 'certainly'),
#  ("'s", 'impossible'),
#  ("'s", 'dying'),
#  ("'s", 'so'),
#  ("'s", 'entertainment'),
#  ("'s", 'i'),
#  ("'s", 'ever'),
#  ("'s", 'office'),
#  ("'s", 'surprise'),
#  ("'s", 'yearning'),
#  ("'s", 'based'),
#  ("'s", 'mother'),
#  ("'s", 'reporters'),
#  ("'s", 'always'),
#  ("'s", 'comic-book'),
#  ("'s", 'own'),
#  ("'s", 'actions'),
#  ("'s", 'old-fashioned'),
#  ("'s", 'understanding'),
#  ("'s", 'amusing'),
#  ("'s", 'show-biz'),
#  ("'s", 'goofy'),
#  ("'s", 'characters'),
#  ("'s", 'success'),
#  ("'s", 'themes'),
#  ("'s", 'sophomoric'),
#  ("'s", 'memorable'),
#  ("'s", 'throbbing'),
#  ("'s", 'the'),
#  ("'s", 'both'),
#  ("'s", 'finally'),
#  ("'s", 'funniest'),
#  ("'s", 'underestimated'),
#  ("'s", 'documentary'),
#  ("'s", 'still'),
#  ("'s", 'usual'),
#  ("'s", 'acclaimed'),
#  ("'s", '-'),
#  ("'s", 'unafraid'),
#  ("'s", 'organizing'),
#  ("'s", '1937'),
#  ("'s", 'recent'),
#  ("'s", 'being'),
#  ("'s", 'immortal'),
#  ("'s", 'steeped'),
#  ("'s", 'pure'),
#  ("'s", 'extraordinary'),
#  ("'s", 'slide'),
#  ("'s", 'what'),
#  ("'s", 'no'),
#  ("'s", 'an'),
#  ("'s", 'superbly'),
#  ("'s", 'story'),
#  ("'s", 'remarkable'),
#  ("'s", 'cut'),
#  ("'s", 'ambitious'),
#  ("'s", 'like'),
#  ("'s", 'skill'),
#  ("'s", 'treasure'),
#  ("'s", 'showcase'),
#  ("'s", 'war'),
#  ("'s", 'theories'),
#  ("'s", 'invaluable'),
#  ("'s", 'modern'),
#  ("'s", 'understated'),
#  ("'s", 'continuing'),
#  ("'s", 'athletic'),
#  ("'s", 'gifts'),
#  ("'s", 'airless'),
#  ("'s", 'bold'),
#  ("'s", 'lifelong'),
#  ("'s", 'capability'),
#  ("'s", 'novel'),
#  ("'s", 'versatile'),
#  ("'s", 'career'),
#  ("'s", 'black'),
#  ("'s", 'bowling'),
#  ("'s", 'popular'),
#  ("'s", 'there'),
#  ("'s", 'adaptation'),
#  ("'s", 'harrowing'),
#  ("'s", 'emergence'),
#  ("'s", 'obvious'),
#  ("'s", 'saucy'),
#  ("'s", 'decasia'),
#  ("'s", 'darker'),
#  ("'s", 'tremendously'),
#  ("'s", 'portrait'),
#  ("'s", 'handsome'),
#  ("'s", 'excellent'),
#  ("'s", 'harshness'),
#  ("'s", 'maternal'),
#  ("'s", '1993'),
#  ("'s", 'deranged'),
#  ("'s", 'one'),
#  ("'s", 'defiantly'),
#  ("'s", 'surprisingly'),
#  ("'s", 'worth'),
#  ("'s", 'droll'),
#  ("'s", 'creative'),
#  ("'s", 'nice'),
#  ("'s", 'his'),
#  ("'s", 'competent'),
#  ("'s", 'evolution'),
#  ("'s", 'arctic'),
#  ("'s", 'confidence'),
#  ("'s", 'saving'),
#  ("'s", 'also'),
#  ("'s", 'despair'),
#  ("'s", 'latest'),
#  ("'s", 'timing'),
#  ("'s", 'verbal'),
#  ("'s", 'bluff'),
#  ("'s", 'dogma'),
#  ("'s", 'old-world'),
#  ("'s", 'camera'),
#  ("'s", 'blood'),
#  ("'s", 'better'),
#  ("'s", 'not'),
#  ("'s", 'sharply'),
#  ("'s", 'meticulous'),
#  ("'s", 'updating'),
#  ("'s", 'directorial'),
#  ("'s", 'endangered'),
#  ("'s", 'likely'),
#  ("'s", 'diaries'),
#  ("'s", 'screen'),
#  ("'s", 'just'),
#  ("'s", 'even'),
#  ("'s", 'misanthropic'),
#  ("'s", 'more'),
#  ("'s", 'much'),
#  ("'s", 'high-profile'),
#  ("'s", 'thoroughly'),
#  ("'s", 'dreams'),
#  ("'s", 'bizarre'),
#  ("'s", 'gripping'),
#  ("'s", 'shortcomings'),
#  ("'s", 'cinematography'),
#  ("'s", 'something'),
#  ("'s", 'roger'),
#  ("'s", 'music'),
#  ("'s", 'best'),
#  ("'s", 'no-frills'),
#  ("'s", 'unorthodox'),
#  ("'s", 'uninspired'),
#  ("'s", 'nicholas'),
#  ("'s", 'perfect'),
#  ("'s", 'strong'),
#  ("'s", 'documenting'),
#  ("'s", 'waltzed'),
#  ("'s", 'songs'),
#  ("'s", 'common'),
#  ("'s", 'astonishing'),
#  ("'s", 'fate'),
#  ("'s", 'point'),
#  ("'s", 'insecure'),
#  ("'s", '``'),
#  ("'s", 'kubrick-meets-spielberg'),
#  ("'s", 'suspenseful'),
#  ("'s", 'characteristically'),
#  ("'s", 'block'),
#  ("'s", 'strongest'),
#  ("'s", 'narrative'),
#  ("'s", 'cooper'),
#  ("'s", 'haunting'),
#  ("'s", 'monotone'),
#  ("'s", 'democracie'),
#  ("'s", 'now'),
#  ("'s", 'direction'),
#  ("'s", '168-minute'),
#  ("'s", 'rendering'),
#  ("'s", 'tale'),
#  ("'s", 'witnessed'),
#  ("'s", 'script'),
#  ("'s", 'hard'),
#  ("'s", 'performance'),
#  ("'s", 'attracting'),
#  ("'s", 'heidegger'),
#  ("'s", 'play'),
#  ("'s", 'great'),
#  ("'s", 'willing'),
#  ("'s", 'manic'),
#  ("'s", 'political'),
#  ("'s", 'thoughtful'),
#  ("'s", 'yet'),
#  ("'s", 'struggle'),
#  ("'s", 'notably'),
#  ("'s", 'messiness'),
#  ("'s", 'pleasant'),
#  ("'s", 'act'),
#  ("'s", 'difficult'),
#  ("'s", 'version'),
#  ("'s", 'show'),
#  ("'s", 'creepy'),
#  ("'s", 'augustine'),
#  ("'s", 'complaint'),
#  ("'s", 'pinocchio'),
#  ("'s", 'made'),
#  ("'s", 'cleverly'),
#  ("'s", 'primary'),
#  ("'s", ','),
#  ("'s", 'unnerving'),
#  ("'s", 'vision'),
#  ("'s", 'intoxicating'),
#  ("'s", 'because'),
#  ("'s", 'revolution'),
#  ("'s", 'life'),
#  ("'s", 'informative'),
#  ("'s", 'theory'),
#  ("'s", 'set'),
#  ("'s", 'clothes'),
#  ("'s", 'heart'),
#  ("'s", 'less'),
#  ("'s", 'powerful'),
#  ("'s", 'quite'),
#  ("'s", 'closely'),
#  ("'s", 'land'),
#  ("'s", 'often'),
#  ("'s", '...'),
#  ("'s", 'burns'),
#  ("'s", 'quaid'),
#  ("'s", 'destined'),
#  ("'s", 'animated'),
#  ("'s", 'unburdened'),
#  ("'s", 'unique'),
#  ("'s", 'only'),
#  ("'s", 'considerable'),
#  ("'s", 'attentions'),
#  ("'s", 'about'),
#  ("'s", 'actually'),
#  ("'s", 'absolutely'),
#  ("'s", 'affecting'),
#  ("'s", 'all'),
#  ("'s", 'anchored'),
#  ("'s", 'at'),
#  ("'s", 'been'),
#  ("'s", 'bright'),
#  ("'s", 'consistently'),
#  ("'s", 'crafty'),
#  ("'s", 'dark'),
#  ("'s", 'definitely'),
#  ("'s", 'endlessly'),
#  ("'s", 'excessively'),
#  ("'s", 'fairly'),
#  ("'s", 'far'),
#  ("'s", 'full'),
#  ("'s", 'fun'),
#  ("'s", 'funny'),
#  ("'s", 'true'),
#  ("'s", 'got'),
#  ("'s", 'equally'),
#  ("'s", 'started'),
#  ("'s", 'immensely'),
#  ("'s", 'trying'),
#  ("'s", 'incredible'),
#  ("'s", 'light'),
#  ("'s", 'mildly'),
#  ("'s", 'mostly'),
#  ("'s", 'neither'),
#  ("'s", 'bag'),
#  ("'s", 'packed'),
#  ("'s", 'pretty'),
#  ("'s", 'probably'),
#  ("'s", 'rare'),
#  ("'s", 'room'),
#  ("'s", 'refreshing'),
#  ("'s", 'secondary'),
#  ("'s", 'sort'),
#  ("'s", 'stylishly'),
#  ("'s", 'sweet'),
#  ("'s", 'technically'),
#  ("'s", 'that'),
#  ("'s", 'too'),
#  ("'s", 'touching'),
#  ("'s", 'tough'),
#  ("'s", 'truly'),
#  ("'s", 'unlikely'),
#  ("'s", 'usually'),
#  ("'s", 'very'),
#  ("'s", 'weird'),
#  ("'s", 'lame'),
#  ("'s", 'playful'),
#  ("'s", 'capacity'),
#  ("'s", 'convincing'),
#  ("'s", 'surprising'),
#  ("'s", 'various'),
#  ("'s", 'crisp'),
#  ("'s", 'journey'),
#  ("'s", 'length'),
#  ("'s", 'previous'),
#  ("'s", 'lives'),
#  ("'s", 'easy'),
#  ("'s", 'strategy'),
#  ("'s", 'drama'),
#  ("'s", 'take'),
#  ("'s", 'bartleby'),
#  ("'s", 'extended'),
#  ("'s", 'sand'),
#  ("'s", 'ultimate'),
#  ("'s", 'uncomfortable'),
#  ("'s", 'careful'),
#  ("'s", 'radar'),
#  ("'s", 'tempting'),
#  ("'s", 'canny'),
#  ("'s", 'ultimately'),
#  ("'s", 'dilemma'),
#  ("'s", 'achievement'),
#  ("'s", 'web'),
#  ("'s", 'simultaneously'),
#  ("'s", 'issue'),
#  ("'s", 'precious'),
#  ("'s", 'simply'),
#  ("'s", 'orgasm'),
#  ("'s", 'visual'),
#  ("'s", 'spirits'),
#  ("'s", 'future'),
#  ("'s", 'movies'),
#  ("'s", 'astringent'),
#  ("'s", 'deep'),
#  ("'s", 'self-esteem'),
#  ("'s", 'power'),
#  ("'s", 'mission'),
#  ("'s", 'going'),
#  ("'s", 'wasted'),
#  ("'s", 'nothing'),
#  ("'s", 'joyous'),
#  ("'s", 'odyssey'),
#  ("'s", 'flag-waving'),
#  ("'s", 'lifetime'),
#  ("'s", 'thirst'),
#  ("'s", 'moving'),
#  ("'s", 'deft'),
#  ("'s", 'bloated'),
#  ("'s", 'nonstop'),
#  ("'s", 'almost'),
#  ("'s", 'solaris'),
#  ("'s", 'fallen'),
#  ("'s", 'wise'),
#  ("'s", 'chicken'),
#  ("'s", 'bravery'),
#  ("'s", 'charm'),
#  ("'s", 'screenplay'),
#  ("'s", 'attention'),
#  ("'s", 'cast'),
#  ("'s", 'altman-esque'),
#  ("'s", 'technique'),
#  ("'s", 'lovely'),
#  ("'s", 'films'),
#  ("'s", 'original'),
#  ("'s", 'sure'),
#  ("'s", 'architecture'),
#  ("'s", 'final'),
#  ("'s", 'alternately'),
#  ("'s", 'meandering'),
#  ("'s", 'tragic'),
#  ("'s", 'promising'),
#  ("'s", 'experiences'),
#  ("'s", 'iconoclastic'),
#  ("'s", 'eye'),
#  ("'s", 'well'),
#  ("'s", 'effort'),
#  ("'s", 'exposition'),
#  ("'s", 'cheeky'),
#  ("'s", 'cliche'),
#  ("'s", 'prose'),
#  ("'s", 'robert'),
#  ("'s", 'betting'),
#  ("'s", 'memory'),
#  ("'s", 'thrillers'),
#  ("'s", 'apparent'),
#  ("'s", 'dry'),
#  ("'s", 'devils'),
#  ("'s", 'references'),
#  ("'s", 'less-is-more'),
#  ("'s", 'thick'),
#  ("'s", 'autobiographical'),
#  ("'s", 'list'),
#  ("'s", 'humorously'),
#  ("'s", 'short'),
#  ("'s", 'satire'),
#  ("'s", 'encouraging'),
#  ("'s", 'experience'),
#  ("'s", 'light-hearted'),
#  ("'s", 'present'),
#  ("'s", 'past'),
#  ("'s", 'decline'),
#  ("'s", 'experiment'),
#  ("'s", 'earlier'),
#  ("'s", 'all-powerful'),
#  ("'s", 'souls'),
#  ("'s", 'pain'),
#  ("'s", 'darling'),
#  ("'s", 'clear'),
#  ("'s", 'skin'),
#  ("'s", 'eleven'),
#  ("'s", 'first'),
#  ("'s", 'realization'),
#  ("'s", 'paintings'),
#  ("'s", 'conclusion'),
#  ("'s", 'digital'),
#  ("'s", 'charisma'),
#  ("'s", 'contrived'),
#  ("'s", 'face'),
#  ("'s", 'doubts'),
#  ("'s", 'appealingly'),
#  ("'s", 'kidman'),
#  ("'s", 'loyal'),
#  ("'s", 'why'),
#  ("'s", 'club'),
#  ("'s", 'familiar'),
#  ("'s", 'humour'),
#  ("'s", 'romantic'),
#  ("'s", 'refusal'),
#  ("'s", 'bad'),
#  ("'s", 'ear'),
#  ("'s", 'ode'),
#  ("'s", 'impressive'),
#  ("'s", 'luckiest'),
#  ("'s", 'problems'),
#  ("'s", 'industry'),
#  ("'s", 'liberating'),
#  ("'s", 'victims'),
#  ("'s", 'sustained'),
#  ("'s", 'interviewees'),
#  ("'s", 'appeal'),
#  ("'s", 'constant'),
#  ("'s", 'gamble'),
#  ("'s", 'highlight'),
#  ("'s", 'images'),
#  ("'s", 'intimate'),
#  ("'s", 'opened'),
#  ("'s", 'messages'),
#  ("'s", 'plot'),
#  ("'s", 'sense'),
#  ("'s", 'propelled'),
#  ("'s", 'strength'),
#  ("'s", 'unhurried'),
#  ("'s", 'character'),
#  ("'s", 'conviction'),
#  ("'s", 'in'),
#  ("'s", 'on'),
#  ("'s", 'background'),
#  ("'s", 'patience'),
#  ("'s", 'perspective'),
#  ("'s", 'delicate'),
#  ("'s", 'posthumously'),
#  ("'s", 'expanded'),
#  ("'s", 'middle-earth'),
#  ("'s", 'eventual'),
#  ("'s", 'captivating'),
#  ("'s", 'barking-mad'),
#  ("'s", 'smoothly'),
#  ("'s", 'hard-eyed'),
#  ("'s", 'seams'),
#  ("'s", 'thesis'),
#  ("'s", 'fascinating'),
#  ("'s", 'apollo'),
#  ("'s", 'really'),
#  ("'s", 'lines'),
#  ("'s", 'scope'),
#  ("'s", 'morals'),
#  ("'s", 'taxi'),
#  ("'s", 'minimalist'),
#  ("'s", 'book'),
#  ("'s", 'tribute'),
#  ("'s", 'greatest'),
#  ("'s", 'limited'),
#  ("'s", 'straight'),
#  ("'s", 'back-stabbing'),
#  ("'s", 'lots'),
#  ("'s", 'none'),
#  ("'s", 'part'),
#  ("'s", 'outstanding'),
#  ("'s", 'plenty'),
#  ("'s", 'real'),
#  ("'s", 'undeniable'),
#  ("'s", 'boldly'),
#  ("'s", 'told'),
#  ("'s", 'sixth'),
#  ("'s", 'filmed'),
#  ("'s", 'good-natured'),
#  ("'s", 'subtlest'),
#  ("'s", 'ever-watchful'),
#  ("'s", 'dud'),
#  ("'s", 'courage'),
#  ("'s", 'austerity'),
#  ("'s", 'distinctive'),
#  ("'s", 'words'),
#  ("'s", 'works'),
#  ("'s", 'back'),
#  ("'s", 'fat'),
#  ("'s", 'anchoring'),
#  ("'s", '`'),
#  ("'s", 'three'),
#  ("'s", 'approach'),
#  ("'s", 'witty'),
#  ("'s", 'misunderstood'),
#  ("'s", 'spooky'),
#  ("'s", 'epitaph'),
#  ("'s", 'undisputed'),
#  ("'s", 'flaws'),
#  ("'s", 'anguish'),
#  ("'s", 'desire'),
#  ("'s", 'praises'),
#  ("'s", 'invigorating'),
#  ("'s", 'shot'),
#  ("'s", "'"),
#  ("'s", 'talent'),
#  ("'s", 'pipe'),
#  ("'s", 'willingness'),
#  ("'s", 'master'),
#  ("'s", 'this'),
#  ("'s", 'hollywood'),
#  ("'s", 'conspiracy'),
#  ("'s", 'lectures'),
#  ("'s", 'findings'),
#  ("'s", 'plotline'),
#  ("'s", 'warmest'),
#  ("'s", 'plaguing'),
#  ("'s", 'undeniably'),
#  ("'s", 'gorgeous'),
#  ("'s", 'awfully'),
#  ("'s", 'reach'),
#  ("'s", 'queasy'),
#  ("'s", 'even-toned'),
#  ("'s", 'trip'),
#  ("'s", 'winter'),
#  ("'s", 'psychology'),
#  ("'s", 'cameo'),
#  ("'s", 'adventure'),
#  ("'s", 'intense'),
#  ("'s", 'forrest'),
#  ("'s", 'thanks'),
#  ("'s", 'revelatory'),
#  ("'s", 'woman')]

# %%
k = 0.0
pos_unigram_freqs_smoothed = get_unigram_freqs_add_k(pos_corpus, k)
pos_unigram_freqs_with_unknown_smoothed = get_unigram_freqs_add_k(pos_corpus_with_unknown, k)

# %%
pos_bigram_freqs_smoothed = get_bigram_freqs_add_k(pos_corpus, k)
pos_bigram_freqs_with_unknown_smoothed = get_bigram_freqs_add_k(pos_corpus_with_unknown, k)

# %%
print(calculate_perplexity(pos_unigram_freqs_smoothed))
print(calculate_perplexity(pos_unigram_freqs_with_unknown_smoothed))
print(calculate_perplexity(pos_bigram_freqs_smoothed))
print(calculate_perplexity(pos_bigram_freqs_with_unknown_smoothed))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-554401e34a67> in <module>()
# ----> 1 print(calculate_perplexity(pos_unigram_freqs_smoothed))
#       2 print(calculate_perplexity(pos_unigram_freqs_with_unknown_smoothed))
#       3 print(calculate_perplexity(pos_bigram_freqs_smoothed))
#       4 print(calculate_perplexity(pos_bigram_freqs_with_unknown_smoothed))
#
# NameError: name 'calculate_perplexity' is not defined

# %%
# Out:
# ['<s>',
#  ',',
#  'the',
#  'sum',
#  'of',
#  'all',
#  'fears',
#  'is',
#  'simply',
#  'a',
#  'well-made',
#  'and',
#  'satisfying',
#  'thriller',
#  '.',
#  '</s>',
#  ('<s>', ','),
#  (',', 'the'),
#  ('the', 'sum'),
#  ('sum', 'of'),
#  ('of', 'all'),
#  ('all', 'fears'),
#  ('fears', 'is'),
#  ('is', 'simply'),
#  ('simply', 'a'),
#  ('a', 'well-made'),
#  ('well-made', 'and'),
#  ('and', 'satisfying'),
#  ('satisfying', 'thriller'),
#  ('thriller', '.'),
#  ('.', '</s>')]

# %%
def add_corpus(source_corpus, to_add):
    for line in to_add:
        for w in line:
            source_corpus.append(w)
    return source_corpus
    
def feature(original_corpus, training_corpus, training_corpusID):
    training_corpus_set = set(training_corpus)
    X = []
    for line in original_corpus:
        #print(line)
        feat = [0] * len(training_corpusID)
        for w in line:
            if w in training_corpus:
                #print(w, ' ', training_corpusID[w])
                feat[training_corpusID[w]] += 1
            else:
                feat[training_corpusID['<unk>']] += 1
        feat.append(1)
        X.append(feat)
    return X

# %%
pos_corpus_with_unknown
# Out:
# [['<s>',
#   ',',
#   'the',
#   'sum',
#   'of',
#   'all',
#   'fears',
#   'is',
#   'simply',
#   'a',
#   'well-made',
#   'and',
#   'satisfying',
#   'thriller',
#   '.',
#   '</s>'],
#  ['<s>', ',', '``', 'they', "'re", 'out', 'there', '!', "''", '</s>'],
#  ['<s>',
#   ',',
#   'is',
#   'a',
#   '<unk>',
#   'inquiry',
#   'that',
#   'shoulders',
#   'its',
#   'philosophical',
#   '<unk>',
#   'lightly',
#   '.',
#   '</s>'],
#  ['<s>',
#   '-',
#   'i',
#   'also',
#   'wanted',
#   'a',
#   'little',
#   '<unk>',
#   'as',
#   'a',
#   'friend',
#   '!',
#   '</s>'],
#  ['<s>',
#   '-',
#   'west',
#   '<unk>',
#   'rap',
#   'wars',
#   ',',
#   'this',
#   'modern',
#   '<unk>',
#   'music',
#   'drama',
#   'never',
#   'fails',
#   'to',
#   'fascinate',
#   '.',
#   '</s>'],
#  ['<s>',
#   '-',
#   'style',
#   '<unk>',
#   'adventure',
#   '...',
#   'it',
#   'has',
#   'sporadic',
#   'bursts',
#   'of',
#   '<unk>',
#   ',',
#   'some',
#   '<unk>',
#   'slapstick',
#   'and',
#   'a',
#   'few',
#   '<unk>',
#   'songs',
#   'on',
#   'its',
#   'soundtrack',
#   '.',
#   '</s>'],
#  ['<s>', '--', 'but', 'certainly', 'hard', 'to', 'hate', '.', '</s>'],
#  ['<s>',
#   '--',
#   'but',
#   'it',
#   'makes',
#   'for',
#   'one',
#   'of',
#   'the',
#   'most',
#   'purely',
#   'enjoyable',
#   'and',
#   'satisfying',
#   '<unk>',
#   'at',
#   'the',
#   'movies',
#   'i',
#   "'ve",
#   'had',
#   'in',
#   'a',
#   'while',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'despite',
#   '<unk>',
#   'near',
#   'the',
#   'finish',
#   'line',
#   ',',
#   'the',
#   'movie',
#   'runs',
#   'a',
#   'good',
#   'race',
#   ',',
#   'one',
#   'that',
#   'will',
#   'have',
#   'you',
#   'at',
#   'the',
#   'edge',
#   'of',
#   'your',
#   'seat',
#   'for',
#   'long',
#   'stretches',
#   '.',
#   "'",
#   '</s>'],
#  ['<s>',
#   '...',
#   '<unk>',
#   "'s",
#   'mouth',
#   'never',
#   'stops',
#   '<unk>',
#   'about',
#   'the',
#   'war',
#   'between',
#   'the',
#   '<unk>',
#   'and',
#   'how',
#   'to',
#   'win',
#   'the',
#   'battle',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'wallace',
#   'is',
#   'smart',
#   'to',
#   '<unk>',
#   'the',
#   'pitch',
#   'of',
#   'his',
#   'movie',
#   ',',
#   '<unk>',
#   '<unk>',
#   'battle',
#   'scenes',
#   'with',
#   'quieter',
#   'domestic',
#   'scenes',
#   'of',
#   'women',
#   'back',
#   'home',
#   '<unk>',
#   'war',
#   'department',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   '``',
#   'bowling',
#   'for',
#   'columbine',
#   "''",
#   'remains',
#   'a',
#   'disquieting',
#   'and',
#   'thought-provoking',
#   'film',
#   '...',
#   '</s>'],
#  ['<s>',
#   '...',
#   'a',
#   'delicious',
#   'crime',
#   'drama',
#   'on',
#   'par',
#   'with',
#   'the',
#   '<unk>',
#   'of',
#   'mamet',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'a',
#   'delightfully',
#   'unpredictable',
#   ',',
#   'hilarious',
#   'comedy',
#   'with',
#   'wonderful',
#   'performances',
#   'that',
#   'tug',
#   'at',
#   'your',
#   'heart',
#   'in',
#   'ways',
#   'that',
#   'utterly',
#   'transcend',
#   'gender',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'a',
#   'funny',
#   'yet',
#   'dark',
#   'and',
#   '<unk>',
#   'clash',
#   'of',
#   'cultures',
#   'and',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'a',
#   '<unk>',
#   '<unk>',
#   ',',
#   '<unk>',
#   'wicked',
#   'black',
#   'comedy',
#   '...',
#   '</s>'],
#  ['<s>',
#   '...',
#   'a',
#   'good',
#   'film',
#   'that',
#   'must',
#   'have',
#   'baffled',
#   'the',
#   'folks',
#   'in',
#   'the',
#   '<unk>',
#   'department',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'a',
#   'great',
#   ',',
#   '<unk>',
#   '<unk>',
#   'sport',
#   '.',
#   "'",
#   '</s>'],
#  ['<s>',
#   '...',
#   'a',
#   '<unk>',
#   'film',
#   'for',
#   'nice',
#   'evening',
#   'out',
#   '.',
#   '</s>'],
#  ['<s>', '...', 'a', 'light', ',', 'yet', 'engrossing', 'piece', '.', '</s>'],
#  ['<s>',
#   '...',
#   'a',
#   'powerful',
#   'sequel',
#   'and',
#   'one',
#   'of',
#   'the',
#   'best',
#   'films',
#   'of',
#   'the',
#   'year',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'a',
#   'quietly',
#   'introspective',
#   'portrait',
#   'of',
#   'the',
#   'self-esteem',
#   'of',
#   'employment',
#   'and',
#   'the',
#   'shame',
#   'of',
#   'losing',
#   'a',
#   'job',
#   '...',
#   '</s>'],
#  ['<s>',
#   '...',
#   'a',
#   'rich',
#   'and',
#   'intelligent',
#   'film',
#   'that',
#   'uses',
#   'its',
#   'pulpy',
#   'core',
#   'conceit',
#   'to',
#   'probe',
#   'questions',
#   'of',
#   'attraction',
#   'and',
#   '<unk>',
#   'and',
#   'how',
#   'the',
#   'heart',
#   '<unk>',
#   '<unk>',
#   'needs',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'a',
#   'series',
#   'of',
#   'tales',
#   'told',
#   'with',
#   'the',
#   'intricate',
#   '<unk>',
#   'of',
#   'the',
#   'best',
#   'short',
#   'story',
#   'writing',
#   '.',
#   '</s>'],
#  ['<s>', '...', 'a', 'solid', ',', 'unassuming', 'drama', '.', '</s>'],
#  ['<s>', '...', 'a', 'solid', ',', '<unk>', 'satire', '.', '</s>'],
#  ['<s>',
#   '...',
#   'a',
#   'spoof',
#   'comedy',
#   'that',
#   'carries',
#   'its',
#   'share',
#   'of',
#   'laughs',
#   '--',
#   'sometimes',
#   'a',
#   'chuckle',
#   ',',
#   'sometimes',
#   'a',
#   '<unk>',
#   'and',
#   ',',
#   'to',
#   'my',
#   'great',
#   'pleasure',
#   ',',
#   'the',
#   'occasional',
#   'belly',
#   'laugh',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'a',
#   'sweetly',
#   'affecting',
#   'story',
#   'about',
#   'four',
#   'sisters',
#   'who',
#   'are',
#   'coping',
#   ',',
#   'in',
#   'one',
#   'way',
#   'or',
#   'another',
#   ',',
#   'with',
#   'life',
#   "'s",
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'a',
#   'thoughtful',
#   'what-if',
#   'for',
#   'the',
#   'heart',
#   'as',
#   'well',
#   'as',
#   'the',
#   'mind',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'a',
#   'triumph',
#   'of',
#   'emotionally',
#   'and',
#   '<unk>',
#   'complex',
#   'filmmaking',
#   '.',
#   '</s>'],
#  ['<s>', '...', 'a', 'true', 'delight', '.', '</s>'],
#  ['<s>',
#   '...',
#   'a',
#   'vivid',
#   ',',
#   'thoughtful',
#   ',',
#   '<unk>',
#   'raw',
#   'coming-of-age',
#   'tale',
#   'full',
#   'of',
#   'sex',
#   ',',
#   'drugs',
#   'and',
#   'rock',
#   '<unk>',
#   'roll',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'an',
#   'adorably',
#   'whimsical',
#   'comedy',
#   'that',
#   'deserves',
#   'more',
#   'than',
#   'a',
#   '<unk>',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'an',
#   'eerily',
#   'suspenseful',
#   ',',
#   'deeply',
#   'absorbing',
#   'piece',
#   'that',
#   'works',
#   'as',
#   'a',
#   '<unk>',
#   'on',
#   'spirituality',
#   'as',
#   'well',
#   'as',
#   'a',
#   'solid',
#   'sci-fi',
#   'thriller',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'an',
#   'enjoyably',
#   'frothy',
#   '`',
#   'date',
#   'movie',
#   "'",
#   '...',
#   '</s>'],
#  ['<s>', '...', 'an', 'interesting', 'slice', 'of', 'history', '.', '</s>'],
#  ['<s>',
#   '...',
#   'begins',
#   'on',
#   'a',
#   'high',
#   'note',
#   'and',
#   'sustains',
#   'it',
#   'beautifully',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'bright',
#   ',',
#   'intelligent',
#   ',',
#   'and',
#   'humanly',
#   'funny',
#   'film',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'by',
#   'the',
#   'time',
#   'it',
#   "'s",
#   'done',
#   'with',
#   'us',
#   ',',
#   'mira',
#   'nair',
#   "'s",
#   'new',
#   'movie',
#   'has',
#   'its',
#   'audience',
#   'giddy',
#   'with',
#   'the',
#   'delight',
#   'of',
#   'discovery',
#   ',',
#   'of',
#   'having',
#   'been',
#   '<unk>',
#   'in',
#   'a',
#   'foreign',
#   'culture',
#   'only',
#   'to',
#   'find',
#   'that',
#   'human',
#   'nature',
#   'is',
#   'pretty',
#   'much',
#   'the',
#   'same',
#   'all',
#   'over',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'certainly',
#   'an',
#   'entertaining',
#   'ride',
#   ',',
#   'despite',
#   'many',
#   '<unk>',
#   ',',
#   'slow',
#   'scenes',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'could',
#   'easily',
#   'be',
#   'called',
#   'the',
#   'best',
#   'korean',
#   'film',
#   'of',
#   '2002',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'digs',
#   'beyond',
#   'the',
#   'usual',
#   '<unk>',
#   'of',
#   'good',
#   'kids',
#   'and',
#   'bad',
#   '<unk>',
#   'to',
#   'reveal',
#   'a',
#   'more',
#   '<unk>',
#   'set',
#   'of',
#   'characters',
#   'and',
#   'motivations',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'enthusiastically',
#   '<unk>',
#   'the',
#   '<unk>',
#   'rhythm',
#   ',',
#   'the',
#   '<unk>',
#   'soul',
#   'and',
#   'the',
#   'sense',
#   'of',
#   'fierce',
#   'competition',
#   'that',
#   'helps',
#   'make',
#   'great',
#   'marching',
#   '<unk>',
#   'half',
#   'the',
#   'fun',
#   'of',
#   'college',
#   '<unk>',
#   'games',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'even',
#   'if',
#   'you',
#   "'ve",
#   'never',
#   'heard',
#   'of',
#   'chaplin',
#   ',',
#   'you',
#   "'ll",
#   'still',
#   'be',
#   '<unk>',
#   'to',
#   'the',
#   'screen',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'flat-out',
#   'amusing',
#   ',',
#   'sometimes',
#   'endearing',
#   'and',
#   'often',
#   '<unk>',
#   ',',
#   'with',
#   'a',
#   'solid',
#   'cast',
#   ',',
#   '<unk>',
#   'characters',
#   ',',
#   'delicious',
#   'dialogue',
#   'and',
#   'a',
#   'wide',
#   '<unk>',
#   'of',
#   'effective',
#   'sight',
#   'gags',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   '<unk>',
#   'the',
#   'events',
#   'of',
#   'her',
#   'life',
#   'with',
#   'the',
#   'imagery',
#   'in',
#   'her',
#   'paintings',
#   'so',
#   'vividly',
#   'that',
#   'the',
#   'artist',
#   "'s",
#   'work',
#   'may',
#   'take',
#   'on',
#   'a',
#   'striking',
#   'new',
#   'significance',
#   'for',
#   'anyone',
#   'who',
#   'sees',
#   'the',
#   'film',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'in',
#   'no',
#   'way',
#   'original',
#   ',',
#   'or',
#   'even',
#   'all',
#   'that',
#   'memorable',
#   ',',
#   'but',
#   'as',
#   'downtown',
#   'saturday',
#   'matinee',
#   'brain',
#   'candy',
#   ',',
#   'it',
#   'does',
#   "n't",
#   'disappoint',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'it',
#   "'s",
#   'as',
#   '<unk>',
#   'as',
#   'any',
#   '<unk>',
#   '<unk>',
#   ',',
#   'something',
#   'even',
#   '<unk>',
#   'can',
#   'enjoy',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'manages',
#   'to',
#   'deliver',
#   'a',
#   'fair',
#   'bit',
#   'of',
#   '<unk>',
#   'fun',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'once',
#   'the',
#   'true',
#   'impact',
#   'of',
#   'the',
#   'day',
#   'unfolds',
#   ',',
#   'the',
#   'power',
#   'of',
#   'this',
#   'movie',
#   'is',
#   'undeniable',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'one',
#   'of',
#   'the',
#   'more',
#   '<unk>',
#   'works',
#   'of',
#   'the',
#   '`',
#   'korean',
#   'new',
#   'wave',
#   "'",
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'one',
#   'of',
#   'the',
#   'most',
#   'entertaining',
#   'monster',
#   'movies',
#   'in',
#   'ages',
#   '...',
#   '</s>'],
#  ['<s>',
#   '...',
#   'plenty',
#   'of',
#   'warmth',
#   'to',
#   'go',
#   'around',
#   ',',
#   'with',
#   'music',
#   'and',
#   'laughter',
#   'and',
#   'the',
#   'love',
#   'of',
#   'family',
#   '.',
#   '</s>'],
#  ['<s>', '...', 'quite', 'endearing', '.', '</s>'],
#  ['<s>',
#   '...',
#   'quite',
#   'good',
#   'at',
#   'providing',
#   'some',
#   'good',
#   'old',
#   'fashioned',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   '<unk>',
#   'fun',
#   'and',
#   'deliciously',
#   'exploitative',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'standard',
#   'guns',
#   'versus',
#   'martial',
#   'arts',
#   'cliche',
#   'with',
#   'little',
#   'new',
#   'added',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   '<unk>',
#   '<unk>',
#   '<unk>',
#   'of',
#   'the',
#   'potential',
#   'for',
#   '<unk>',
#   ',',
#   'making',
#   'them',
#   'meaningful',
#   'for',
#   'both',
#   'kids',
#   'and',
#   '<unk>',
#   'adults',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'the',
#   'kind',
#   'of',
#   'entertainment',
#   'that',
#   'parents',
#   'love',
#   'to',
#   'have',
#   'their',
#   'kids',
#   'see',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'the',
#   'plot',
#   'weaves',
#   'us',
#   'into',
#   'a',
#   'complex',
#   'web',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'the',
#   'story',
#   ',',
#   'like',
#   '<unk>',
#   "'s",
#   '<unk>',
#   ',',
#   'builds',
#   'to',
#   'a',
#   '<unk>',
#   'that',
#   '<unk>',
#   'many',
#   'more',
#   '<unk>',
#   'than',
#   'we',
#   'started',
#   'with',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'the',
#   'tale',
#   'of',
#   'her',
#   'passionate',
#   ',',
#   '<unk>',
#   'affair',
#   'with',
#   '<unk>',
#   'unfolds',
#   'as',
#   'sand',
#   "'s",
#   'masculine',
#   'persona',
#   ',',
#   'with',
#   'its',
#   'love',
#   'of',
#   'life',
#   'and',
#   'beauty',
#   ',',
#   'takes',
#   'form',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'there',
#   "'s",
#   'enough',
#   'cool',
#   'fun',
#   'here',
#   'to',
#   'warm',
#   'the',
#   'hearts',
#   'of',
#   'animation',
#   '<unk>',
#   'of',
#   'all',
#   'ages',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'there',
#   'is',
#   'enough',
#   'originality',
#   'in',
#   '`',
#   'life',
#   "'",
#   'to',
#   'distance',
#   'it',
#   'from',
#   'the',
#   'pack',
#   'of',
#   'paint-by-number',
#   'romantic',
#   'comedies',
#   'that',
#   'so',
#   'often',
#   'end',
#   'up',
#   'on',
#   'cinema',
#   'screens',
#   '.',
#   '</s>'],
#  ['<s>', '...', 'very', 'funny', ',', 'very', 'enjoyable', '...', '</s>'],
#  ['<s>', '...', 'wise', 'and', '<unk>', '...', '</s>'],
#  ['<s>',
#   '...',
#   'with',
#   'the',
#   'gifted',
#   '<unk>',
#   'on',
#   'hand',
#   'to',
#   'keep',
#   'things',
#   'on',
#   '<unk>',
#   'ground',
#   'dramatically',
#   ',',
#   'this',
#   '<unk>',
#   'machine',
#   'is',
#   'ultimately',
#   'effective',
#   'enough',
#   'at',
#   'achieving',
#   'the',
#   'modest',
#   ',',
#   '<unk>',
#   'goals',
#   'it',
#   'sets',
#   'for',
#   'itself',
#   '.',
#   '</s>'],
#  ['<s>',
#   '...',
#   'works',
#   'on',
#   'some',
#   'levels',
#   'and',
#   'is',
#   'certainly',
#   'worth',
#   'seeing',
#   'at',
#   'least',
#   'once',
#   '.',
#   '</s>'],
#  ['<s>',
#   '10',
#   'minutes',
#   'into',
#   'the',
#   'film',
#   'you',
#   "'ll",
#   'be',
#   '<unk>',
#   'and',
#   'unable',
#   'to',
#   'look',
#   'away',
#   '.',
#   '</s>'],
#  ['<s>',
#   '300',
#   'years',
#   'of',
#   'russian',
#   'history',
#   'and',
#   'culture',
#   'compressed',
#   'into',
#   'an',
#   '<unk>',
#   ',',
#   '<unk>',
#   'and',
#   'sumptuous',
#   'stream',
#   'of',
#   'consciousness',
#   '.',
#   '</s>'],
#  ['<s>',
#   '<unk>',
#   'has',
#   'the',
#   'same',
#   '<unk>',
#   'appeal',
#   'as',
#   'pokemon',
#   'videos',
#   ',',
#   'but',
#   'it',
#   'breathes',
#   'more',
#   'on',
#   'the',
#   'big',
#   'screen',
#   'and',
#   '<unk>',
#   '<unk>',
#   'more',
#   'slowly',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'b-movie',
#   'you',
#   'can',
#   'sit',
#   'through',
#   ',',
#   'enjoy',
#   'on',
#   'a',
#   'certain',
#   'level',
#   'and',
#   'then',
#   'forget',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'french',
#   'film',
#   'with',
#   'a',
#   'more',
#   '<unk>',
#   'flavor',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'backstage',
#   'must-see',
#   'for',
#   'true',
#   'fans',
#   'of',
#   'comedy',
#   '.',
#   '</s>'],
#  ['<s>', 'a', 'beautiful', ',', 'entertaining', 'two', 'hours', '.', '</s>'],
#  ['<s>',
#   'a',
#   'beautiful',
#   ',',
#   'timeless',
#   'and',
#   'universal',
#   'tale',
#   'of',
#   'heated',
#   'passions',
#   '--',
#   'jealousy',
#   ',',
#   'betrayal',
#   ',',
#   'forgiveness',
#   'and',
#   'murder',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'beautiful',
#   '<unk>',
#   'to',
#   'a',
#   'time',
#   'long',
#   'past',
#   '.',
#   '</s>'],
#  ['<s>', 'a', 'beautifully', 'observed', 'character', 'piece', '.', '</s>'],
#  ['<s>',
#   'a',
#   'beautifully',
#   '<unk>',
#   'action',
#   'thriller',
#   'about',
#   'love',
#   'and',
#   '<unk>',
#   'in',
#   'korea',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'beguiling',
#   'evocation',
#   'of',
#   'the',
#   'quality',
#   'that',
#   'keeps',
#   'dickens',
#   '<unk>',
#   ':',
#   'the',
#   '<unk>',
#   'openness',
#   'with',
#   'which',
#   'he',
#   '<unk>',
#   'our',
#   'most',
#   'basic',
#   'emotions',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   '<unk>',
#   'movie',
#   'as',
#   '<unk>',
#   'pure',
#   'as',
#   'the',
#   'hours',
#   'is',
#   'a',
#   'distinct',
#   'rarity',
#   ',',
#   'and',
#   'an',
#   'event',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'bit',
#   'of',
#   'a',
#   '<unk>',
#   'and',
#   'a',
#   'little',
#   '<unk>',
#   'at',
#   'times',
#   ',',
#   'but',
#   'this',
#   'is',
#   'a',
#   'beautiful',
#   'film',
#   'for',
#   'people',
#   'who',
#   'like',
#   'their',
#   'romances',
#   'to',
#   'have',
#   'that',
#   'french',
#   'realism',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'bittersweet',
#   'contemporary',
#   'comedy',
#   'about',
#   '<unk>',
#   'deception',
#   ',',
#   'which',
#   ',',
#   'while',
#   'it',
#   'may',
#   'not',
#   'rival',
#   'the',
#   'filmmaker',
#   "'s",
#   'period',
#   'pieces',
#   ',',
#   'is',
#   'still',
#   'very',
#   'much',
#   'worth',
#   'seeing',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'bittersweet',
#   'drama',
#   'about',
#   'the',
#   '<unk>',
#   'of',
#   'grief',
#   'and',
#   'how',
#   '<unk>',
#   'can',
#   'open',
#   'the',
#   'door',
#   'to',
#   'liberation',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'bittersweet',
#   'film',
#   ',',
#   'simple',
#   'in',
#   'form',
#   'but',
#   'rich',
#   'with',
#   'human',
#   'events',
#   '.',
#   '</s>'],
#  ['<s>', 'a', '<unk>', 'for', '<unk>', '.', '</s>'],
#  ['<s>',
#   'a',
#   'bracing',
#   ',',
#   'unblinking',
#   'work',
#   'that',
#   'serves',
#   'as',
#   'a',
#   'painful',
#   '<unk>',
#   'and',
#   'sobering',
#   'cautionary',
#   'tale',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'breathtaking',
#   'adventure',
#   'for',
#   'all',
#   'ages',
#   ',',
#   'spirit',
#   'tells',
#   'its',
#   'poignant',
#   'and',
#   'uplifting',
#   'story',
#   'in',
#   'a',
#   'stunning',
#   '<unk>',
#   'of',
#   'music',
#   'and',
#   'images',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'breezy',
#   'blend',
#   'of',
#   'art',
#   ',',
#   'history',
#   ',',
#   '<unk>',
#   '<unk>',
#   'and',
#   'philosophy',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'bright',
#   ',',
#   'inventive',
#   ',',
#   'thoroughly',
#   'winning',
#   '<unk>',
#   'of',
#   'revisionist',
#   'fancy',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'brilliant',
#   ',',
#   'absurd',
#   'collection',
#   'of',
#   'vignettes',
#   'that',
#   ',',
#   'in',
#   'their',
#   'own',
#   'idiosyncratic',
#   'way',
#   ',',
#   'sum',
#   'up',
#   'the',
#   'strange',
#   'horror',
#   'of',
#   'life',
#   'in',
#   'the',
#   'new',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'brisk',
#   ',',
#   'reverent',
#   ',',
#   'and',
#   'subtly',
#   'different',
#   'sequel',
#   '.',
#   '</s>'],
#  ['<s>', 'a', 'brutal', 'and', 'funny', 'work', '.', '</s>'],
#  ['<s>',
#   'a',
#   'buoyant',
#   'romantic',
#   'comedy',
#   'about',
#   'friendship',
#   ',',
#   'love',
#   ',',
#   'and',
#   'the',
#   'truth',
#   'that',
#   'we',
#   "'re",
#   'all',
#   'in',
#   'this',
#   'together',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'burst',
#   'of',
#   'color',
#   ',',
#   'music',
#   ',',
#   'and',
#   'dance',
#   'that',
#   'only',
#   'the',
#   'most',
#   '<unk>',
#   '<unk>',
#   'could',
#   'fail',
#   'to',
#   'crack',
#   'a',
#   'smile',
#   'at',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'captivating',
#   'and',
#   'intimate',
#   'study',
#   'about',
#   'dying',
#   'and',
#   'loving',
#   '...',
#   '</s>'],
#  ['<s>',
#   'a',
#   'captivating',
#   'coming-of-age',
#   'story',
#   'that',
#   'may',
#   'also',
#   'be',
#   'the',
#   'first',
#   'narrative',
#   'film',
#   'to',
#   'be',
#   'truly',
#   '<unk>',
#   'by',
#   'the',
#   '<unk>',
#   'age',
#   '.',
#   '</s>'],
#  ['<s>', 'a', 'captivating', 'new', 'film', '.', '</s>'],
#  ['<s>',
#   'a',
#   '<unk>',
#   'quirky',
#   'hybrid',
#   'of',
#   'character',
#   'portrait',
#   ',',
#   'romantic',
#   'comedy',
#   'and',
#   '<unk>',
#   'thriller',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'certain',
#   '<unk>',
#   '<unk>',
#   'even',
#   'the',
#   '<unk>',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'chance',
#   'to',
#   'see',
#   'three',
#   'splendid',
#   'actors',
#   'turn',
#   'a',
#   '<unk>',
#   'chase',
#   'movie',
#   'into',
#   'an',
#   'emotionally',
#   'satisfying',
#   'exploration',
#   'of',
#   'the',
#   'very',
#   'human',
#   'need',
#   'to',
#   'be',
#   'somebody',
#   ',',
#   'and',
#   'to',
#   '<unk>',
#   'to',
#   'somebody',
#   '.',
#   '</s>'],
#  ['<s>', 'a', 'charmer', 'from', 'belgium', '.', '</s>'],
#  ['<s>',
#   'a',
#   'charming',
#   ',',
#   '<unk>',
#   'comedy',
#   '...',
#   'one',
#   'of',
#   'those',
#   '<unk>',
#   'cinematic',
#   '<unk>',
#   '<unk>',
#   'whose',
#   'aims',
#   '--',
#   'and',
#   'by',
#   '<unk>',
#   ',',
#   '<unk>',
#   '--',
#   'seem',
#   'deceptively',
#   'slight',
#   'on',
#   'the',
#   'surface',
#   '.',
#   '</s>'],
#  ['<s>', 'a', 'charming', 'but', 'slight', 'comedy', '.', '</s>'],
#  ['<s>',
#   'a',
#   'chilling',
#   'movie',
#   'without',
#   'oppressive',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'chilling',
#   'tale',
#   'of',
#   'one',
#   'of',
#   'the',
#   'great',
#   'crimes',
#   'of',
#   '20th',
#   'century',
#   'france',
#   ':',
#   'the',
#   'murder',
#   'of',
#   'two',
#   'rich',
#   'women',
#   'by',
#   'their',
#   'servants',
#   'in',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'chilly',
#   ',',
#   'brooding',
#   'but',
#   'quietly',
#   'resonant',
#   'psychological',
#   'study',
#   'of',
#   'domestic',
#   'tension',
#   'and',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'chronicle',
#   'not',
#   'only',
#   'of',
#   'one',
#   'man',
#   "'s",
#   'quest',
#   'to',
#   'be',
#   'president',
#   ',',
#   'but',
#   'of',
#   'how',
#   'that',
#   'man',
#   '<unk>',
#   'turned',
#   'a',
#   'plane',
#   'full',
#   'of',
#   '<unk>',
#   ',',
#   '<unk>',
#   '<unk>',
#   'into',
#   'what',
#   'was',
#   'essentially',
#   ',',
#   'by',
#   '<unk>',
#   "'s",
#   'end',
#   ',',
#   'an',
#   'extended',
#   '<unk>',
#   'department',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'classic',
#   'fairy',
#   'tale',
#   'that',
#   'perfectly',
#   'captures',
#   'the',
#   'wonders',
#   'and',
#   '<unk>',
#   'of',
#   'childhood',
#   'in',
#   'a',
#   'way',
#   'that',
#   'few',
#   'movies',
#   'have',
#   'ever',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>', 'a', '<unk>', ',', 'sprightly', 'spin', 'on', 'film', '.', '</s>'],
#  ['<s>',
#   'a',
#   'clever',
#   'script',
#   'and',
#   '<unk>',
#   'actors',
#   'bring',
#   'new',
#   'energy',
#   'to',
#   'the',
#   'familiar',
#   'topic',
#   'of',
#   'office',
#   'politics',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'college',
#   'story',
#   'that',
#   'works',
#   'even',
#   'without',
#   '<unk>',
#   ',',
#   'sex',
#   'scenes',
#   ',',
#   'and',
#   '<unk>',
#   '!',
#   '</s>'],
#  ['<s>',
#   'a',
#   'colorful',
#   ',',
#   'joyous',
#   'celebration',
#   'of',
#   'life',
#   ';',
#   'a',
#   'tapestry',
#   'woven',
#   'of',
#   'romance',
#   ',',
#   'dancing',
#   ',',
#   'singing',
#   ',',
#   'and',
#   'unforgettable',
#   'characters',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'colorful',
#   ',',
#   'vibrant',
#   'introduction',
#   'to',
#   'a',
#   'universal',
#   'human',
#   '<unk>',
#   ',',
#   '<unk>',
#   'photographed',
#   'and',
#   'beautifully',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'comedy',
#   'that',
#   'is',
#   'warm',
#   ',',
#   'inviting',
#   ',',
#   'and',
#   'surprising',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'comedy',
#   'that',
#   '<unk>',
#   'and',
#   '<unk>',
#   'to',
#   'the',
#   'rhythms',
#   'of',
#   'life',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'comedy-drama',
#   'of',
#   'nearly',
#   'epic',
#   'proportions',
#   '<unk>',
#   'in',
#   'a',
#   'sincere',
#   'performance',
#   'by',
#   'the',
#   'title',
#   'character',
#   '<unk>',
#   'midlife',
#   'crisis',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'coming-of-age',
#   'movie',
#   'that',
#   'hollywood',
#   'would',
#   "n't",
#   'have',
#   'the',
#   'guts',
#   'to',
#   'make',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'coming-of-age',
#   'tale',
#   'from',
#   'new',
#   '<unk>',
#   'whose',
#   '<unk>',
#   ',',
#   'languid',
#   'air',
#   'is',
#   'balanced',
#   'by',
#   'a',
#   'rich',
#   'visual',
#   'clarity',
#   'and',
#   'deeply',
#   'felt',
#   'performances',
#   'across',
#   'the',
#   'board',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'compelling',
#   ',',
#   '<unk>',
#   'piece',
#   'of',
#   '<unk>',
#   'cinema',
#   'that',
#   'carries',
#   'you',
#   'along',
#   'in',
#   'a',
#   '<unk>',
#   'of',
#   'emotion',
#   'as',
#   'it',
#   'explores',
#   'the',
#   'awful',
#   'complications',
#   'of',
#   'one',
#   'terrifying',
#   'day',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'compelling',
#   'french',
#   'psychological',
#   'drama',
#   '<unk>',
#   'the',
#   'encounter',
#   'of',
#   'an',
#   'aloof',
#   'father',
#   'and',
#   'his',
#   'chilly',
#   'son',
#   'after',
#   '20',
#   'years',
#   'apart',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'compelling',
#   '<unk>',
#   'about',
#   'the',
#   'last',
#   'days',
#   'of',
#   '<unk>',
#   "'s",
#   '<unk>',
#   '<unk>',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'compelling',
#   'coming-of-age',
#   'drama',
#   'about',
#   'the',
#   '<unk>',
#   'journey',
#   'of',
#   'a',
#   'sensitive',
#   'young',
#   'girl',
#   'through',
#   'a',
#   'series',
#   'of',
#   'foster',
#   'homes',
#   'and',
#   'a',
#   'fierce',
#   'struggle',
#   'to',
#   'pull',
#   'free',
#   'from',
#   'her',
#   'dangerous',
#   'and',
#   '<unk>',
#   'mother',
#   "'s",
#   'hold',
#   'over',
#   'her',
#   '.',
#   '</s>'],
#  ['<s>', 'a', 'compelling', 'film', '.', '</s>'],
#  ['<s>',
#   'a',
#   'compelling',
#   'motion',
#   'picture',
#   'that',
#   'illustrates',
#   'an',
#   'american',
#   'tragedy',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'compelling',
#   '<unk>',
#   'drama',
#   'with',
#   'vivid',
#   'characters',
#   'and',
#   'a',
#   'warm',
#   ',',
#   'moving',
#   'message',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'compelling',
#   'story',
#   'of',
#   'musical',
#   'passion',
#   'against',
#   '<unk>',
#   'odds',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'compelling',
#   'yarn',
#   ',',
#   'but',
#   'not',
#   'quite',
#   'a',
#   'ripping',
#   'one',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'competent',
#   ',',
#   'unpretentious',
#   'entertainment',
#   'destined',
#   'to',
#   'fill',
#   'the',
#   '<unk>',
#   '<unk>',
#   'at',
#   '<unk>',
#   '<unk>',
#   'theaters',
#   'across',
#   'the',
#   'country',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'completely',
#   'spooky',
#   'piece',
#   'of',
#   'business',
#   'that',
#   'gets',
#   'under',
#   'your',
#   'skin',
#   'and',
#   ',',
#   'some',
#   'plot',
#   '<unk>',
#   'aside',
#   ',',
#   'stays',
#   'there',
#   'for',
#   'the',
#   'duration',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'complex',
#   'psychological',
#   'drama',
#   'about',
#   'a',
#   'father',
#   'who',
#   'returns',
#   'to',
#   'his',
#   'son',
#   "'s",
#   'home',
#   'after',
#   'decades',
#   'away',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   '<unk>',
#   'of',
#   'kiddie',
#   'entertainment',
#   ',',
#   'sophisticated',
#   'wit',
#   'and',
#   'symbolic',
#   'graphic',
#   'design',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'conventional',
#   ',',
#   'but',
#   'well-crafted',
#   'film',
#   'about',
#   'a',
#   'historic',
#   'legal',
#   'battle',
#   'in',
#   '<unk>',
#   'over',
#   'a',
#   'man',
#   "'s",
#   'right',
#   'to',
#   'raise',
#   'his',
#   'own',
#   'children',
#   '.',
#   '</s>'],
#  ['<s>', 'a', 'conventional', 'but', 'heartwarming', 'tale', '.', '</s>'],
#  ['<s>',
#   'a',
#   'creepy',
#   ',',
#   'intermittently',
#   'powerful',
#   'study',
#   'of',
#   'a',
#   'self-destructive',
#   'man',
#   '...',
#   'about',
#   'as',
#   'unsettling',
#   'to',
#   'watch',
#   'as',
#   'an',
#   '<unk>',
#   '<unk>',
#   'procedure',
#   'or',
#   'an',
#   'autopsy',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'cultural',
#   '<unk>',
#   'experience',
#   ':',
#   '<unk>',
#   ',',
#   'different',
#   ',',
#   'unusual',
#   ',',
#   'even',
#   'nutty',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   '<unk>',
#   'comedy',
#   'that',
#   ',',
#   'in',
#   'addition',
#   'to',
#   'being',
#   'very',
#   'funny',
#   ',',
#   'captures',
#   'some',
#   'of',
#   'the',
#   '<unk>',
#   'and',
#   'embarrassment',
#   'of',
#   'being',
#   'a',
#   'bumbling',
#   'american',
#   'in',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>', 'a', '<unk>', 'romantic', 'tale', 'with', 'a', 'twist', '.', '</s>'],
#  ['<s>',
#   'a',
#   'damn',
#   'fine',
#   'and',
#   'a',
#   'truly',
#   'distinctive',
#   'and',
#   'a',
#   'deeply',
#   'pertinent',
#   'film',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'dark',
#   ',',
#   'quirky',
#   'road',
#   'movie',
#   'that',
#   'constantly',
#   'defies',
#   'expectation',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'dashing',
#   'and',
#   'absorbing',
#   'outing',
#   'with',
#   'one',
#   'of',
#   'france',
#   "'s",
#   'most',
#   'inventive',
#   'directors',
#   '.',
#   '</s>'],
#  ['<s>', 'a', 'dazzling', 'dream', 'of', 'a', 'documentary', '.', '</s>'],
#  ['<s>',
#   'a',
#   'dazzling',
#   'thing',
#   'to',
#   'behold',
#   '--',
#   'as',
#   'long',
#   'as',
#   'you',
#   "'re",
#   '<unk>',
#   'the',
#   'somewhat',
#   '<unk>',
#   '3d',
#   '<unk>',
#   'the',
#   'theater',
#   'provides',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   '<unk>',
#   '<unk>',
#   'that',
#   'stands',
#   'a',
#   'good',
#   'chance',
#   'of',
#   'being',
#   'the',
#   'big',
#   'hit',
#   'franklin',
#   'needs',
#   'to',
#   'stay',
#   'afloat',
#   'in',
#   'hollywood',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'deeply',
#   'felt',
#   'and',
#   'vividly',
#   'detailed',
#   'story',
#   'about',
#   '<unk>',
#   'in',
#   'a',
#   'strange',
#   'new',
#   'world',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'deft',
#   ',',
#   'delightful',
#   'mix',
#   'of',
#   '<unk>',
#   'teen',
#   'drama',
#   'and',
#   '<unk>',
#   '<unk>',
#   'triumph',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'deftly',
#   'entertaining',
#   'film',
#   ',',
#   'smartly',
#   'played',
#   'and',
#   'smartly',
#   'directed',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   '<unk>',
#   'account',
#   'of',
#   'a',
#   'lifestyle',
#   '<unk>',
#   'by',
#   'its',
#   '<unk>',
#   '--',
#   'one',
#   'that',
#   '<unk>',
#   'the',
#   '<unk>',
#   'of',
#   'post',
#   ',',
#   '<unk>',
#   ',',
#   'and',
#   '<unk>',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'delicious',
#   ',',
#   'quirky',
#   'movie',
#   'with',
#   'a',
#   'terrific',
#   'screenplay',
#   'and',
#   'fanciful',
#   'direction',
#   'by',
#   'michael',
#   'gondry',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'delicious',
#   'and',
#   'delicately',
#   'funny',
#   'look',
#   'at',
#   'the',
#   '<unk>',
#   'of',
#   'a',
#   '<unk>',
#   'neighborhood',
#   'coping',
#   'with',
#   'the',
#   '<unk>',
#   'complications',
#   'life',
#   'tosses',
#   'at',
#   'them',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'deliciously',
#   '<unk>',
#   'comedy',
#   'about',
#   'a',
#   'city',
#   'coming',
#   'apart',
#   'at',
#   'its',
#   'seams',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'delightful',
#   ',',
#   'if',
#   'minor',
#   ',',
#   '<unk>',
#   'of',
#   'a',
#   'movie',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'delightful',
#   '<unk>',
#   'in',
#   'the',
#   'tradition',
#   'of',
#   'food',
#   'movies',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'delightful',
#   'little',
#   'film',
#   'that',
#   '<unk>',
#   'in',
#   'its',
#   'own',
#   'simplicity',
#   ',',
#   'mostly',
#   'martha',
#   'will',
#   'leave',
#   'you',
#   'with',
#   'a',
#   'smile',
#   'on',
#   'your',
#   'face',
#   'and',
#   'a',
#   '<unk>',
#   'in',
#   'your',
#   'stomach',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'delightful',
#   '<unk>',
#   'for',
#   'the',
#   '<unk>',
#   'nerves',
#   ',',
#   'so',
#   'much',
#   'that',
#   'it',
#   "'s",
#   '<unk>',
#   'that',
#   'the',
#   'plot',
#   'feels',
#   'like',
#   'every',
#   'other',
#   'tale',
#   'of',
#   'a',
#   '<unk>',
#   'tomorrow',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'delightful',
#   'surprise',
#   'because',
#   'despite',
#   'all',
#   'the',
#   'backstage',
#   'drama',
#   ',',
#   'this',
#   'is',
#   'a',
#   'movie',
#   'that',
#   'tells',
#   'stories',
#   'that',
#   'work',
#   '--',
#   'is',
#   'charming',
#   ',',
#   'is',
#   'moving',
#   ',',
#   'is',
#   'funny',
#   'and',
#   'looks',
#   'professional',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'different',
#   'and',
#   'emotionally',
#   'reserved',
#   'type',
#   'of',
#   'survival',
#   'story',
#   '--',
#   'a',
#   'film',
#   'less',
#   'about',
#   '<unk>',
#   'all',
#   'of',
#   'world',
#   'war',
#   'ii',
#   'through',
#   'the',
#   'specific',
#   '<unk>',
#   'of',
#   'one',
#   'man',
#   ',',
#   'and',
#   'more',
#   'about',
#   'that',
#   'man',
#   'lost',
#   'in',
#   'its',
#   'midst',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'different',
#   'movie',
#   '--',
#   'sometimes',
#   'tedious',
#   '--',
#   'by',
#   'a',
#   'director',
#   'many',
#   'viewers',
#   'would',
#   'like',
#   'to',
#   '<unk>',
#   'but',
#   'film',
#   'buffs',
#   'should',
#   'get',
#   'to',
#   'know',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'directorial',
#   'tour',
#   'de',
#   'force',
#   'by',
#   'bernard',
#   'rose',
#   ',',
#   '<unk>',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   '<unk>',
#   'but',
#   'occasionally',
#   '<unk>',
#   'saga',
#   'packed',
#   'with',
#   'moments',
#   'out',
#   'of',
#   'an',
#   'alice',
#   'in',
#   '<unk>',
#   'adventure',
#   ',',
#   'a',
#   '<unk>',
#   'thriller',
#   ',',
#   'and',
#   'a',
#   'condensed',
#   'season',
#   'of',
#   'tv',
#   "'s",
#   'big',
#   'brother',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'distinguished',
#   'and',
#   'thoughtful',
#   'film',
#   ',',
#   'marked',
#   'by',
#   'acute',
#   'writing',
#   'and',
#   'a',
#   'host',
#   'of',
#   'splendid',
#   'performances',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'diverse',
#   'and',
#   'astonishingly',
#   'articulate',
#   'cast',
#   'of',
#   '<unk>',
#   'and',
#   'israeli',
#   'children',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'dreadful',
#   'day',
#   'in',
#   'irish',
#   'history',
#   'is',
#   'given',
#   'passionate',
#   ',',
#   'if',
#   'somewhat',
#   'flawed',
#   ',',
#   'treatment',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'fairly',
#   'enjoyable',
#   'mixture',
#   'of',
#   '<unk>',
#   '<unk>',
#   '...',
#   'and',
#   'the',
#   '<unk>',
#   'guy',
#   '<unk>',
#   'caper',
#   'lock',
#   'stock',
#   'and',
#   'two',
#   'smoking',
#   'barrels',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'family',
#   'film',
#   'that',
#   '<unk>',
#   'some',
#   '<unk>',
#   'thematic',
#   'material',
#   'on',
#   'time',
#   ',',
#   'death',
#   ',',
#   '<unk>',
#   ',',
#   'and',
#   'what',
#   'is',
#   'needed',
#   'to',
#   'live',
#   'a',
#   'rich',
#   'and',
#   'full',
#   'life',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'fanciful',
#   'drama',
#   'about',
#   'napoleon',
#   "'s",
#   'last',
#   'years',
#   'and',
#   'his',
#   'surprising',
#   'discovery',
#   'of',
#   'love',
#   'and',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   '<unk>',
#   'vital',
#   'movie',
#   'that',
#   'manages',
#   'to',
#   '<unk>',
#   'real',
#   'humor',
#   ',',
#   'sensuality',
#   ',',
#   'and',
#   'sympathy',
#   'into',
#   'a',
#   'story',
#   'about',
#   'two',
#   'adolescent',
#   'boys',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'fascinating',
#   ',',
#   '<unk>',
#   'documentary',
#   'that',
#   'should',
#   'shame',
#   'americans',
#   ',',
#   'regardless',
#   'of',
#   'whether',
#   'or',
#   'not',
#   'ultimate',
#   'blame',
#   'finally',
#   'lies',
#   'with',
#   'kissinger',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'fascinating',
#   ',',
#   'dark',
#   'thriller',
#   'that',
#   'keeps',
#   'you',
#   '<unk>',
#   'on',
#   'the',
#   'delicious',
#   '<unk>',
#   'of',
#   'its',
#   'lurid',
#   'fiction',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'fascinating',
#   ',',
#   'unnerving',
#   'examination',
#   'of',
#   'the',
#   '<unk>',
#   'of',
#   'one',
#   '<unk>',
#   'man',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'fascinating',
#   'case',
#   'study',
#   'of',
#   '<unk>',
#   'liberation',
#   '--',
#   'and',
#   'the',
#   'price',
#   'that',
#   'was',
#   'paid',
#   'for',
#   'it',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'fascinating',
#   'documentary',
#   'about',
#   'the',
#   'long',
#   'and',
#   '<unk>',
#   'spiritual',
#   'journey',
#   'of',
#   'the',
#   '<unk>',
#   'who',
#   'helped',
#   '<unk>',
#   'the',
#   'new',
#   'age',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'fascinating',
#   'documentary',
#   'that',
#   'provides',
#   'a',
#   '<unk>',
#   'and',
#   'revealing',
#   'overview',
#   'of',
#   'this',
#   'ancient',
#   '<unk>',
#   'healing',
#   'system',
#   '</s>'],
#  ['<s>',
#   'a',
#   'fascinating',
#   'examination',
#   'of',
#   'the',
#   'joyous',
#   ',',
#   'turbulent',
#   'self-discovery',
#   'made',
#   'by',
#   'a',
#   'proper',
#   ',',
#   'middle-aged',
#   'woman',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'fascinating',
#   'literary',
#   'mystery',
#   'story',
#   'with',
#   'multiple',
#   '<unk>',
#   'about',
#   'the',
#   'controversy',
#   'of',
#   'who',
#   'really',
#   '<unk>',
#   '<unk>',
#   "'s",
#   'plays',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'fast',
#   'paced',
#   'and',
#   'suspenseful',
#   '<unk>',
#   'thriller',
#   'about',
#   'the',
#   'shadow',
#   'side',
#   'of',
#   'play',
#   '.',
#   '</s>'],
#  ['<s>', 'a', 'faster', 'paced', 'family', 'flick', '.', '</s>'],
#  ['<s>',
#   'a',
#   'few',
#   '<unk>',
#   'may',
#   '<unk>',
#   'their',
#   '<unk>',
#   'when',
#   'they',
#   'see',
#   'the',
#   'joy',
#   'the',
#   'characters',
#   'take',
#   'in',
#   'this',
#   '<unk>',
#   ',',
#   'but',
#   '<unk>',
#   'are',
#   "n't",
#   'likely',
#   'to',
#   'enter',
#   'the',
#   'theater',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'fiercely',
#   'clever',
#   'and',
#   'subtle',
#   'film',
#   ',',
#   'capturing',
#   'the',
#   '<unk>',
#   'balance',
#   'between',
#   'the',
#   'extravagant',
#   'confidence',
#   'of',
#   'the',
#   '<unk>',
#   '<unk>',
#   'and',
#   'the',
#   'cruel',
#   'earnestness',
#   'of',
#   'the',
#   '<unk>',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'film',
#   'about',
#   'female',
#   'friendship',
#   'that',
#   'men',
#   'can',
#   'embrace',
#   'and',
#   'women',
#   'will',
#   'talk',
#   'about',
#   'for',
#   'hours',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'film',
#   'centering',
#   'on',
#   'a',
#   'traditional',
#   'indian',
#   'wedding',
#   'in',
#   'contemporary',
#   'new',
#   '<unk>',
#   'may',
#   'not',
#   'sound',
#   'like',
#   '<unk>',
#   'fare',
#   ',',
#   'but',
#   'mira',
#   'nair',
#   "'s",
#   'film',
#   'is',
#   'an',
#   'absolute',
#   'delight',
#   'for',
#   'all',
#   'audiences',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'film',
#   'in',
#   'a',
#   'class',
#   'with',
#   'spike',
#   'lee',
#   "'s",
#   'masterful',
#   'do',
#   'the',
#   'right',
#   'thing',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'film',
#   'neither',
#   'bitter',
#   'nor',
#   'sweet',
#   ',',
#   'neither',
#   'romantic',
#   'nor',
#   'comedic',
#   ',',
#   'neither',
#   'warm',
#   'nor',
#   'fuzzy',
#   '.',
#   '</s>'],
#  ['<s>', 'a', 'film', 'of', 'delicate', '<unk>', '<unk>', '.', '</s>'],
#  ['<s>',
#   'a',
#   'film',
#   'of',
#   'epic',
#   '<unk>',
#   'with',
#   'an',
#   'intimate',
#   'feeling',
#   ',',
#   'a',
#   'saga',
#   'of',
#   'the',
#   '<unk>',
#   'and',
#   '<unk>',
#   'of',
#   'friendships',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'film',
#   'of',
#   'ideas',
#   'and',
#   'wry',
#   'comic',
#   'mayhem',
#   '.',
#   '</s>'],
#  ['<s>', 'a', 'film', 'of', 'quiet', 'power', '.', '</s>'],
#  ['<s>',
#   'a',
#   'film',
#   'that',
#   "'s",
#   'flawed',
#   'and',
#   'brilliant',
#   'in',
#   'equal',
#   'measure',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'film',
#   'that',
#   'begins',
#   'with',
#   'the',
#   'everyday',
#   'lives',
#   'of',
#   '<unk>',
#   '<unk>',
#   'in',
#   'san',
#   '<unk>',
#   'and',
#   'ends',
#   'with',
#   'scenes',
#   'so',
#   'true',
#   'and',
#   'heartbreaking',
#   'that',
#   'tears',
#   '<unk>',
#   'up',
#   'in',
#   'my',
#   'eyes',
#   'both',
#   'times',
#   'i',
#   'saw',
#   'the',
#   'film',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'film',
#   'that',
#   'will',
#   'be',
#   'best',
#   'appreciated',
#   'by',
#   'those',
#   'willing',
#   'to',
#   'endure',
#   'its',
#   'extremely',
#   'languorous',
#   'rhythms',
#   ',',
#   'waiting',
#   'for',
#   'happiness',
#   'is',
#   'ultimately',
#   'thoughtful',
#   'without',
#   'having',
#   'much',
#   'dramatic',
#   'impact',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'film',
#   'that',
#   'will',
#   '<unk>',
#   'the',
#   'whole',
#   'family',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'film',
#   'with',
#   'a',
#   'great',
#   'premise',
#   'but',
#   'only',
#   'a',
#   'great',
#   'premise',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'film',
#   'with',
#   'almost',
#   'as',
#   'many',
#   'delights',
#   'for',
#   'adults',
#   'as',
#   'there',
#   'are',
#   'for',
#   'children',
#   'and',
#   'dog',
#   'lovers',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'film',
#   'with',
#   'contemporary',
#   'political',
#   'resonance',
#   'illustrated',
#   'by',
#   'a',
#   'winning',
#   'family',
#   'story',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'fine',
#   ',',
#   'rousing',
#   ',',
#   '<unk>',
#   'family',
#   'film',
#   ',',
#   'aimed',
#   'mainly',
#   'at',
#   'little',
#   'kids',
#   'but',
#   'with',
#   'plenty',
#   'of',
#   'entertainment',
#   'value',
#   'to',
#   'keep',
#   'grown-ups',
#   'from',
#   '<unk>',
#   'in',
#   'their',
#   'seats',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'fine',
#   'documentary',
#   'can',
#   'be',
#   'distinguished',
#   'from',
#   'a',
#   '<unk>',
#   'one',
#   'by',
#   'the',
#   'better',
#   'film',
#   "'s",
#   'ability',
#   'to',
#   'make',
#   'its',
#   'subject',
#   'interesting',
#   'to',
#   'those',
#   'who',
#   'are',
#   "n't",
#   'part',
#   'of',
#   'its',
#   'supposed',
#   'target',
#   'audience',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'fine',
#   'effort',
#   ',',
#   'an',
#   'interesting',
#   'topic',
#   ',',
#   'some',
#   'intriguing',
#   'characters',
#   'and',
#   'a',
#   'sad',
#   'ending',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'fine',
#   'production',
#   'with',
#   'splendid',
#   'singing',
#   'by',
#   'angela',
#   'gheorghiu',
#   ',',
#   'ruggero',
#   '<unk>',
#   ',',
#   'and',
#   'roberto',
#   'alagna',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'finely',
#   'tuned',
#   'mood',
#   'piece',
#   ',',
#   'a',
#   '<unk>',
#   'of',
#   'menacing',
#   'atmosphere',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'first-class',
#   ',',
#   'thoroughly',
#   'involving',
#   'b',
#   'movie',
#   'that',
#   'effectively',
#   'combines',
#   'two',
#   '<unk>',
#   ',',
#   '<unk>',
#   '<unk>',
#   '--',
#   'the',
#   'prison',
#   'flick',
#   'and',
#   'the',
#   'fight',
#   'film',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'first-class',
#   'road',
#   'movie',
#   'that',
#   'proves',
#   'you',
#   'can',
#   'run',
#   'away',
#   'from',
#   'home',
#   ',',
#   'but',
#   'your',
#   'ego',
#   'and',
#   'all',
#   'your',
#   'problems',
#   'go',
#   'with',
#   'you',
#   '.',
#   '</s>'],
#  ['<s>', 'a', 'flawed', 'but', 'engrossing', 'thriller', '.', '</s>'],
#  ['<s>',
#   'a',
#   '<unk>',
#   'and',
#   'pleasingly',
#   'upbeat',
#   'family',
#   'diversion',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'flick',
#   'about',
#   'our',
#   '<unk>',
#   'culture',
#   'that',
#   'is',
#   "n't",
#   'entirely',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'forceful',
#   'drama',
#   'of',
#   'an',
#   '<unk>',
#   'executive',
#   'who',
#   '<unk>',
#   'himself',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'formula',
#   'family',
#   'tearjerker',
#   'told',
#   'with',
#   'a',
#   'heavy',
#   'irish',
#   'brogue',
#   '...',
#   '<unk>',
#   ',',
#   'rather',
#   'than',
#   '<unk>',
#   ',',
#   'the',
#   'plot',
#   "'s",
#   'saccharine',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'four',
#   'star',
#   'performance',
#   'from',
#   'kevin',
#   'kline',
#   'who',
#   'unfortunately',
#   'works',
#   'with',
#   'a',
#   'two',
#   'star',
#   'script',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'fresh',
#   ',',
#   'entertaining',
#   'comedy',
#   'that',
#   'looks',
#   'at',
#   'relationships',
#   '<unk>',
#   'traditional',
#   'gender',
#   'roles',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   '<unk>',
#   ',',
#   '<unk>',
#   'and',
#   'frequently',
#   'funny',
#   'thrill',
#   'ride',
#   'for',
#   'the',
#   '<unk>',
#   ',',
#   'with',
#   'enough',
#   'eye',
#   'candy',
#   'and',
#   'cheeky',
#   'wit',
#   'to',
#   'keep',
#   'parents',
#   'away',
#   'from',
#   'the',
#   '<unk>',
#   'stand',
#   '.',
#   "'",
#   '</s>'],
#  ['<s>',
#   'a',
#   'full',
#   'experience',
#   ',',
#   'a',
#   'love',
#   'story',
#   'and',
#   'a',
#   'murder',
#   'mystery',
#   'that',
#   'expands',
#   'into',
#   'a',
#   'meditation',
#   'on',
#   'the',
#   'deep',
#   '<unk>',
#   'of',
#   'innocence',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'fun',
#   'family',
#   'movie',
#   'that',
#   "'s",
#   'suitable',
#   'for',
#   'all',
#   'ages',
#   '--',
#   'a',
#   'movie',
#   'that',
#   'will',
#   'make',
#   'you',
#   'laugh',
#   ',',
#   '<unk>',
#   'and',
#   'realize',
#   ',',
#   '`',
#   'it',
#   "'s",
#   'never',
#   'too',
#   'late',
#   'to',
#   'believe',
#   'in',
#   'your',
#   'dreams',
#   '.',
#   "'",
#   '</s>'],
#  ['<s>', 'a', 'fun', 'ride', '.', '</s>'],
#  ['<s>',
#   'a',
#   'funny',
#   ',',
#   '<unk>',
#   ',',
#   'and',
#   'moving',
#   'documentary',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'funny',
#   'and',
#   'touching',
#   'film',
#   'that',
#   'is',
#   'gorgeously',
#   'acted',
#   'by',
#   'a',
#   'british',
#   'cast',
#   'to',
#   'rival',
#   'gosford',
#   'park',
#   "'s",
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'funny',
#   'and',
#   '<unk>',
#   'black',
#   'comedy',
#   'where',
#   'the',
#   'old',
#   'adage',
#   '``',
#   'be',
#   'careful',
#   'what',
#   'you',
#   'wish',
#   'for',
#   "''",
#   'is',
#   'given',
#   'a',
#   'full',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>', 'a', 'funny', 'film', '.', '</s>'],
#  ['<s>',
#   'a',
#   'gangster',
#   'movie',
#   'with',
#   'the',
#   'capacity',
#   'to',
#   'surprise',
#   '.',
#   '</s>'],
#  ['<s>', 'a', 'gem', 'of', 'a', 'movie', '.', '</s>'],
#  ['<s>',
#   'a',
#   'gem',
#   'of',
#   'a',
#   'romantic',
#   'crime',
#   'comedy',
#   'that',
#   'turns',
#   'out',
#   'to',
#   'be',
#   'clever',
#   ',',
#   'amusing',
#   'and',
#   'unpredictable',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'generous',
#   ',',
#   'inspiring',
#   'film',
#   'that',
#   'unfolds',
#   'with',
#   'grace',
#   'and',
#   'humor',
#   'and',
#   'gradually',
#   'becomes',
#   'a',
#   'testament',
#   'to',
#   'faith',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'gentle',
#   'and',
#   'engrossing',
#   'character',
#   'study',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'gently',
#   'funny',
#   ',',
#   'sweetly',
#   'adventurous',
#   'film',
#   'that',
#   'makes',
#   'you',
#   'feel',
#   'genuinely',
#   'good',
#   ',',
#   'that',
#   'is',
#   'to',
#   'say',
#   ',',
#   'entirely',
#   '<unk>',
#   'by',
#   'false',
#   '<unk>',
#   'or',
#   'sharp',
#   ',',
#   '<unk>',
#   'hollywood',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>', 'a', 'genuine', '<unk>', '.', '</s>'],
#  ['<s>',
#   'a',
#   'genuinely',
#   'funny',
#   'ensemble',
#   'comedy',
#   'that',
#   'also',
#   'asks',
#   'its',
#   'audience',
#   '--',
#   'in',
#   'a',
#   'heartwarming',
#   ',',
#   'nonjudgmental',
#   'kind',
#   'of',
#   'way',
#   '--',
#   'to',
#   'consider',
#   'what',
#   'we',
#   'value',
#   'in',
#   'our',
#   'daily',
#   'lives',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'genuinely',
#   'moving',
#   'and',
#   'wisely',
#   'unsentimental',
#   'drama',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'giddy',
#   'and',
#   'provocative',
#   'sexual',
#   'romp',
#   'that',
#   'has',
#   'something',
#   'to',
#   'say',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'gift',
#   'to',
#   'anyone',
#   'who',
#   'loves',
#   'both',
#   'dance',
#   'and',
#   'cinema',
#   '</s>'],
#  ['<s>',
#   'a',
#   '<unk>',
#   'but',
#   'bouncy',
#   'bit',
#   'of',
#   '<unk>',
#   '<unk>',
#   'in',
#   'which',
#   'the',
#   'hero',
#   'might',
#   'wind',
#   'up',
#   'caught',
#   'but',
#   'the',
#   'audience',
#   'gets',
#   'pure',
#   'escapism',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'good',
#   'documentary',
#   'can',
#   'make',
#   'interesting',
#   'a',
#   'subject',
#   'you',
#   'thought',
#   'would',
#   'leave',
#   'you',
#   'cold',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'good',
#   'film',
#   'with',
#   'a',
#   'solid',
#   '<unk>',
#   'both',
#   'in',
#   'front',
#   'of',
#   'and',
#   ',',
#   'more',
#   'specifically',
#   ',',
#   'behind',
#   'the',
#   'camera',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'good',
#   'music',
#   'documentary',
#   ',',
#   'probably',
#   'one',
#   'of',
#   'the',
#   'best',
#   'since',
#   'the',
#   'last',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>', 'a', 'good', 'thriller', '.', '</s>'],
#  ['<s>',
#   'a',
#   'gorgeously',
#   'strange',
#   'movie',
#   ',',
#   'heaven',
#   'is',
#   'deeply',
#   'concerned',
#   'with',
#   'morality',
#   ',',
#   'but',
#   'it',
#   'refuses',
#   'to',
#   'spell',
#   'things',
#   'out',
#   'for',
#   'viewers',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   '<unk>',
#   ',',
#   'moving',
#   'tribute',
#   'to',
#   'the',
#   'courage',
#   'of',
#   'new',
#   'york',
#   "'s",
#   'finest',
#   'and',
#   'a',
#   'nicely',
#   'understated',
#   '<unk>',
#   'of',
#   'the',
#   'grief',
#   'shared',
#   'by',
#   'the',
#   'nation',
#   'at',
#   'their',
#   'sacrifice',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   '<unk>',
#   ',',
#   'eloquent',
#   'film',
#   'that',
#   'by',
#   'its',
#   'end',
#   'offers',
#   'a',
#   'ray',
#   'of',
#   'hope',
#   'to',
#   'the',
#   'refugees',
#   'able',
#   'to',
#   'look',
#   'ahead',
#   'and',
#   'resist',
#   'living',
#   'in',
#   'a',
#   'past',
#   '<unk>',
#   'lost',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'great',
#   'cast',
#   'and',
#   'a',
#   'wonderful',
#   'but',
#   'sometimes',
#   'confusing',
#   '<unk>',
#   'movie',
#   'about',
#   'growing',
#   'up',
#   'in',
#   'a',
#   'dysfunctional',
#   'family',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'great',
#   'companion',
#   'piece',
#   'to',
#   'other',
#   'napoleon',
#   'films',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'gripping',
#   'documentary',
#   'that',
#   'reveals',
#   'how',
#   'deep',
#   'the',
#   '<unk>',
#   'lies',
#   'in',
#   'war-torn',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>', 'a', 'gripping', 'drama', '.', '</s>'],
#  ['<s>',
#   'a',
#   '<unk>',
#   'beautiful',
#   'film',
#   'that',
#   'looks',
#   ',',
#   'sounds',
#   ',',
#   'and',
#   'feels',
#   'more',
#   'like',
#   'an',
#   'extended',
#   ',',
#   'open-ended',
#   'poem',
#   'than',
#   'a',
#   'traditionally',
#   'structured',
#   'story',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'hallmark',
#   'film',
#   'in',
#   'an',
#   'increasingly',
#   'important',
#   'film',
#   'industry',
#   'and',
#   'worth',
#   'the',
#   'look',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'hard',
#   'look',
#   'at',
#   'one',
#   'man',
#   "'s",
#   '<unk>',
#   'angst',
#   'and',
#   'its',
#   '<unk>',
#   '<unk>',
#   ',',
#   'a',
#   'terrifying',
#   'study',
#   'of',
#   'bourgeois',
#   'desperation',
#   'worthy',
#   'of',
#   'claude',
#   'chabrol',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'harrowing',
#   'account',
#   'of',
#   'a',
#   'psychological',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'haunting',
#   'tale',
#   'of',
#   'murder',
#   'and',
#   'mayhem',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   '<unk>',
#   'thriller',
#   'set',
#   'among',
#   '<unk>',
#   '<unk>',
#   'on',
#   'the',
#   'west',
#   'bank',
#   ',',
#   'joseph',
#   'cedar',
#   "'s",
#   'time',
#   'of',
#   'favor',
#   'manages',
#   'not',
#   'only',
#   'to',
#   'find',
#   'a',
#   'compelling',
#   'dramatic',
#   'means',
#   'of',
#   '<unk>',
#   'a',
#   'complex',
#   'situation',
#   ',',
#   'it',
#   'does',
#   'so',
#   'without',
#   '<unk>',
#   'that',
#   'complexity',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'heady',
#   ',',
#   'biting',
#   ',',
#   '<unk>',
#   'ride',
#   'through',
#   '<unk>',
#   'manhattan',
#   ',',
#   'a',
#   '<unk>',
#   '<unk>',
#   'of',
#   'the',
#   'modern',
#   'male',
#   'and',
#   'the',
#   '<unk>',
#   'to',
#   'which',
#   'he',
#   "'ll",
#   'go',
#   'to',
#   'weave',
#   'a',
#   '<unk>',
#   '<unk>',
#   'around',
#   'his',
#   'own',
#   'ego',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   '<unk>',
#   'thoughtful',
#   'minor',
#   'classic',
#   ',',
#   'the',
#   'work',
#   'of',
#   'a',
#   'genuine',
#   'and',
#   '<unk>',
#   'artist',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'heartening',
#   'tale',
#   'of',
#   'small',
#   'victories',
#   'and',
#   'enduring',
#   'hope',
#   '.',
#   '</s>'],
#  ['<s>',
#   'a',
#   'heroic',
#   'tale',
# ...
#   'to',
#   'behold',
#   '.',
#   '</s>'],
#  ['<s>',
#   'buy',
#   'is',
#   'an',
#   'accomplished',
#   'actress',
#   ',',
#   'and',
#   'this',
#   'is',
#   'a',
#   'big',
#   ',',
#   'juicy',
#   'role',
#   '.',
#   '</s>'],
#  ['<s>',
#   'by',
#   'and',
#   'large',
#   'this',
#   'is',
#   'mr.',
#   '<unk>',
#   "'s",
#   'movie',
#   ',',
#   'and',
#   'it',
#   "'s",
#   'his',
#   'strongest',
#   'performance',
#   'since',
#   'the',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   'by',
#   '<unk>',
#   'definition',
#   'to',
#   'both',
#   'sides',
#   'of',
#   'the',
#   'man',
#   ',',
#   'the',
#   'picture',
#   '<unk>',
#   'a',
#   '<unk>',
#   'that',
#   'does',
#   'not',
#   '<unk>',
#   'the',
#   'subject',
#   '.',
#   '</s>'],
#  ['<s>',
#   'by',
#   '<unk>',
#   'through',
#   'this',
#   'picture',
#   'i',
#   'was',
#   'beginning',
#   'to',
#   'hate',
#   'it',
#   ',',
#   'and',
#   ',',
#   'of',
#   'course',
#   ',',
#   'feeling',
#   'guilty',
#   'for',
#   'it',
#   '...',
#   'then',
#   ',',
#   'miracle',
#   'of',
#   '<unk>',
#   ',',
#   'the',
#   'movie',
#   'does',
#   'a',
#   'flip-flop',
#   '.',
#   '</s>'],
#  ['<s>',
#   'by',
#   'its',
#   'modest',
#   ',',
#   '<unk>',
#   'standards',
#   ',',
#   'undisputed',
#   'scores',
#   'a',
#   '<unk>',
#   'hit',
#   '.',
#   '</s>'],
#  ['<s>',
#   'by',
#   'no',
#   'means',
#   'a',
#   'great',
#   'movie',
#   ',',
#   'but',
#   'it',
#   'is',
#   'a',
#   'refreshingly',
#   '<unk>',
#   'one',
#   '.',
#   '</s>'],
#  ['<s>',
#   'by',
#   'not',
#   'averting',
#   'his',
#   'eyes',
#   ',',
#   'solondz',
#   'forces',
#   'us',
#   'to',
#   'consider',
#   'the',
#   '<unk>',
#   ',',
#   'the',
#   '<unk>',
#   ',',
#   'the',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   'by',
#   '<unk>',
#   'us',
#   'with',
#   '<unk>',
#   ',',
#   'haynes',
#   'makes',
#   'us',
#   'see',
#   'familiar',
#   'issues',
#   ',',
#   'like',
#   '<unk>',
#   'and',
#   '<unk>',
#   ',',
#   'in',
#   'a',
#   'fresh',
#   'way',
#   '.',
#   '</s>'],
#  ['<s>',
#   'by',
#   'the',
#   'end',
#   'of',
#   'it',
#   'all',
#   'i',
#   'sort',
#   'of',
#   'loved',
#   'the',
#   'people',
#   'onscreen',
#   ',',
#   'even',
#   'though',
#   'i',
#   'could',
#   'not',
#   'stand',
#   'them',
#   '.',
#   '</s>'],
#  ['<s>',
#   'by',
#   'the',
#   'end',
#   'of',
#   'the',
#   'movie',
#   ',',
#   'you',
#   "'re",
#   'definitely',
#   '<unk>',
#   'that',
#   'these',
#   'women',
#   'are',
#   'spectacular',
#   '.',
#   '</s>'],
#  ['<s>',
#   'by',
#   'the',
#   'end',
#   'you',
#   'ca',
#   "n't",
#   'help',
#   'but',
#   'feel',
#   '`',
#   '<unk>',
#   '.',
#   "'",
#   '</s>'],
#  ['<s>',
#   'by',
#   'the',
#   'standards',
#   'of',
#   '<unk>',
#   '<unk>',
#   ',',
#   'the',
#   'hot',
#   'chick',
#   'is',
#   'pretty',
#   'damned',
#   'funny',
#   '.',
#   '</s>'],
#  ['<s>',
#   'by',
#   'turns',
#   'fanciful',
#   ',',
#   '<unk>',
#   'and',
#   'engagingly',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   'by',
#   'turns',
#   'gripping',
#   ',',
#   'amusing',
#   ',',
#   'tender',
#   'and',
#   '<unk>',
#   ',',
#   '<unk>',
#   'has',
#   'all',
#   'the',
#   '<unk>',
#   'of',
#   'french',
#   'cinema',
#   'at',
#   'its',
#   'best',
#   '.',
#   '</s>'],
#  ['<s>',
#   'by',
#   'turns',
#   'pretentious',
#   ',',
#   'fascinating',
#   ',',
#   'ludicrous',
#   ',',
#   'provocative',
#   'and',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   'by',
#   'turns',
#   'touching',
#   ',',
#   '<unk>',
#   'amusing',
#   ',',
#   'uncomfortable',
#   ',',
#   'and',
#   ',',
#   'yes',
#   ',',
#   'even',
#   'sexy',
#   ',',
#   'never',
#   'again',
#   'is',
#   'a',
#   'welcome',
#   'and',
#   'heartwarming',
#   'addition',
#   'to',
#   'the',
#   'romantic',
#   'comedy',
#   'genre',
#   '.',
#   '</s>'],
#  ['<s>', 'by', 'turns', 'very', 'dark', 'and', 'very', 'funny', '.', '</s>'],
#  ['<s>',
#   'byler',
#   'is',
#   'too',
#   'savvy',
#   'a',
#   'filmmaker',
#   'to',
#   'let',
#   'this',
#   '<unk>',
#   'into',
#   'a',
#   'typical',
#   'romantic',
#   'triangle',
#   '.',
#   '</s>'],
#  ['<s>',
#   '<unk>',
#   'makes',
#   'an',
#   'unusual',
#   'but',
#   'pleasantly',
#   'haunting',
#   'debut',
#   'behind',
#   'the',
#   'camera',
#   '.',
#   '</s>'],
#  ['<s>',
#   'caine',
#   'makes',
#   'us',
#   'watch',
#   'as',
#   'his',
#   'character',
#   '<unk>',
#   'to',
#   'the',
#   'notion',
#   'that',
#   'to',
#   'be',
#   'human',
#   'is',
#   'eventually',
#   'to',
#   'have',
#   'to',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   'call',
#   'it',
#   'magic',
#   'realism',
#   'or',
#   '<unk>',
#   ',',
#   'but',
#   'miss',
#   '<unk>',
#   '<unk>',
#   'beyond',
#   'reality',
#   'with',
#   'a',
#   'certain',
#   'degree',
#   'of',
#   'wit',
#   'and',
#   'dignity',
#   '.',
#   '</s>'],
#  ['<s>',
#   'campanella',
#   "'s",
#   'competent',
#   'direction',
#   'and',
#   'his',
#   'excellent',
#   'cast',
#   'overcome',
#   'the',
#   'obstacles',
#   'of',
#   'a',
#   'predictable',
#   'outcome',
#   'and',
#   'a',
#   'screenplay',
#   'that',
#   '<unk>',
#   'over',
#   '<unk>',
#   "'s",
#   'evolution',
#   '.',
#   '</s>'],
#  ['<s>',
#   'campanella',
#   'gets',
#   'the',
#   'tone',
#   'just',
#   'right',
#   '--',
#   'funny',
#   'in',
#   'the',
#   'middle',
#   'of',
#   'sad',
#   'in',
#   'the',
#   'middle',
#   'of',
#   'hopeful',
#   '.',
#   '</s>'],
#  ['<s>',
#   '<unk>',
#   'scott',
#   'finds',
#   'the',
#   'ideal',
#   '<unk>',
#   'for',
#   'his',
#   '<unk>',
#   '<unk>',
#   'in',
#   'the',
#   'role',
#   'of',
#   'roger',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   'can',
#   'be',
#   'viewed',
#   'as',
#   'pure',
#   'composition',
#   'and',
#   'form',
#   '--',
#   'film',
#   'as',
#   'music',
#   '</s>'],
#  ['<s>', 'can', 'you', '<unk>', 'the', 'laughter', '?', '</s>'],
#  ['<s>',
#   'canada',
#   "'s",
#   '<unk>',
#   'light',
#   'shines',
#   'bright',
#   'on',
#   'this',
#   'frozen',
#   '<unk>',
#   'soap',
#   'opera',
#   'that',
#   'breathes',
#   'extraordinary',
#   'life',
#   'into',
#   'the',
#   'private',
#   'existence',
#   'of',
#   'the',
#   'inuit',
#   'people',
#   '.',
#   '</s>'],
#  ['<s>',
#   '<unk>',
#   'filmmaker',
#   'gary',
#   'burns',
#   "'",
#   'inventive',
#   'and',
#   'mordantly',
#   'humorous',
#   'take',
#   'on',
#   'the',
#   '<unk>',
#   'of',
#   'work',
#   'in',
#   'the',
#   'city',
#   '.',
#   '</s>'],
#  ['<s>',
#   '<unk>',
#   "'s",
#   'confidence',
#   'and',
#   '<unk>',
#   'good',
#   'spirits',
#   'are',
#   ',',
#   'with',
#   'the',
#   '<unk>',
#   '<unk>',
#   ',',
#   'among',
#   'the',
#   'film',
#   "'s",
#   'saving',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   '<unk>',
#   'beautifully',
#   '<unk>',
#   'what',
#   'it',
#   'means',
#   'sometimes',
#   'to',
#   'be',
#   'inside',
#   'looking',
#   'out',
#   ',',
#   'and',
#   'at',
#   'other',
#   'times',
#   'outside',
#   'looking',
#   'in',
#   '.',
#   '</s>'],
#  ['<s>',
#   'captivates',
#   'and',
#   'shows',
#   'how',
#   'a',
#   'skillful',
#   'filmmaker',
#   'can',
#   'impart',
#   'a',
#   'message',
#   'without',
#   '<unk>',
#   'the',
#   'audience',
#   'over',
#   'the',
#   'head',
#   '.',
#   '</s>'],
#  ['<s>',
#   'captivates',
#   'as',
#   'it',
#   'shows',
#   'excess',
#   'in',
#   'business',
#   'and',
#   'pleasure',
#   ',',
#   'allowing',
#   'us',
#   'to',
#   'find',
#   'the',
#   'small',
#   ',',
#   'human',
#   'moments',
#   ',',
#   'and',
#   'leaving',
#   'off',
#   'with',
#   'a',
#   'grand',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   'captures',
#   'all',
#   'the',
#   'longing',
#   ',',
#   'anguish',
#   'and',
#   'ache',
#   ',',
#   'the',
#   'confusing',
#   'sexual',
#   'messages',
#   'and',
#   'the',
#   'wish',
#   'to',
#   'be',
#   'a',
#   'part',
#   'of',
#   'that',
#   'elusive',
#   'adult',
#   'world',
#   '.',
#   '</s>'],
#  ['<s>',
#   'captures',
#   'the',
#   'raw',
#   'comic',
#   'energy',
#   'of',
#   'one',
#   'of',
#   'our',
#   'most',
#   'flamboyant',
#   'female',
#   'comics',
#   '.',
#   '</s>'],
#  ['<s>',
#   'caruso',
#   'sometimes',
#   '<unk>',
#   'into',
#   '<unk>',
#   'cuteness',
#   '...',
#   'but',
#   'for',
#   'the',
#   'most',
#   'part',
#   'he',
#   'makes',
#   'sure',
#   'the',
#   'salton',
#   'sea',
#   'works',
#   'the',
#   'way',
#   'a',
#   'good',
#   'noir',
#   'should',
#   ',',
#   'keeping',
#   'it',
#   'tight',
#   'and',
#   'nasty',
#   '.',
#   '</s>'],
#  ['<s>', 'catch', 'it', '...', 'if', 'you', 'can', '!', '</s>'],
#  ['<s>',
#   '<unk>',
#   '<unk>',
#   'the',
#   'transformation',
#   'of',
#   'his',
#   'character',
#   'completely',
#   '.',
#   '</s>'],
#  ['<s>',
#   'cedar',
#   'somewhat',
#   '<unk>',
#   'this',
#   'provocative',
#   'theme',
#   'by',
#   '<unk>',
#   'it',
#   'in',
#   'a',
#   '<unk>',
#   'love',
#   'triangle',
#   '.',
#   '</s>'],
#  ['<s>',
#   'certainly',
#   'the',
#   'big',
#   'finish',
#   'was',
#   "n't",
#   'something',
#   '<unk>',
#   'and',
#   '<unk>',
#   'could',
#   'have',
#   '<unk>',
#   'for',
#   '...',
#   'but',
#   'part',
#   'of',
#   'being',
#   'a',
#   'good',
#   '<unk>',
#   'is',
#   'being',
#   'there',
#   'when',
#   'the',
#   '<unk>',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>', 'certainly', 'the', 'performances', 'are', 'worthwhile', '.', '</s>'],
#  ['<s>',
#   'chaiken',
#   'ably',
#   'balances',
#   '<unk>',
#   'rhythms',
#   'with',
#   '<unk>',
#   'incident',
#   '.',
#   '</s>'],
#  ['<s>',
#   'chamber',
#   'of',
#   'secrets',
#   'will',
#   'find',
#   '<unk>',
#   'of',
#   'eager',
#   'fans',
#   '.',
#   '</s>'],
#  ['<s>',
#   'changing',
#   'lanes',
#   'is',
#   'an',
#   '<unk>',
#   'for',
#   'a',
#   'hollywood',
#   'movie',
#   ';',
#   'it',
#   "'s",
#   'a',
#   'well-written',
#   'and',
#   'occasionally',
#   'challenging',
#   'social',
#   'drama',
#   'that',
#   'actually',
#   'has',
#   'something',
#   'interesting',
#   'to',
#   'say',
#   '.',
#   '</s>'],
#  ['<s>', 'changing', 'lanes', 'tries', 'for', 'more', '.', '</s>'],
#  ['<s>',
#   'charlie',
#   '<unk>',
#   'has',
#   'the',
#   '<unk>',
#   'eyes',
#   ',',
#   'repressed',
#   'smile',
#   'and',
#   'determined',
#   'face',
#   'needed',
#   'to',
#   'carry',
#   'out',
#   'a',
#   'dickensian',
#   'hero',
#   '.',
#   '</s>'],
#  ['<s>',
#   'charlotte',
#   'sometimes',
#   'is',
#   'a',
#   'brilliant',
#   'movie',
#   '.',
#   '</s>'],
#  ['<s>', 'charlotte', 'sometimes', 'is', 'a', 'gem', '.', '</s>'],
#  ['<s>',
#   'charming',
#   'and',
#   'witty',
#   ',',
#   'it',
#   "'s",
#   'also',
#   'somewhat',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   'chicago',
#   'offers',
#   'much',
#   'colorful',
#   'eye',
#   'candy',
#   ',',
#   'including',
#   'the',
#   'spectacle',
#   'of',
#   'gere',
#   'in',
#   'his',
#   'dancing',
#   '<unk>',
#   ',',
#   '<unk>',
#   'and',
#   '<unk>',
#   'with',
#   'the',
#   'best',
#   'of',
#   'them',
#   '.',
#   '</s>'],
#  ['<s>',
#   'children',
#   ',',
#   'christian',
#   'or',
#   'otherwise',
#   ',',
#   'deserve',
#   'to',
#   'hear',
#   'the',
#   'full',
#   'story',
#   'of',
#   'jonah',
#   "'s",
#   'despair',
#   '--',
#   'in',
#   'all',
#   'its',
#   '<unk>',
#   ',',
#   '<unk>',
#   'glory',
#   '--',
#   'even',
#   'if',
#   'they',
#   'spend',
#   'years',
#   'trying',
#   'to',
#   'comprehend',
#   'it',
#   '.',
#   '</s>'],
#  ['<s>',
#   'children',
#   'and',
#   'adults',
#   '<unk>',
#   'of',
#   'all',
#   'things',
#   'pokemon',
#   'wo',
#   "n't",
#   'be',
#   'disappointed',
#   '.',
#   '</s>'],
#  ['<s>',
#   'chilling',
#   'in',
#   'its',
#   'objective',
#   'portrait',
#   'of',
#   '<unk>',
#   ',',
#   'lost',
#   '<unk>',
#   'century',
#   'america',
#   '.',
#   '</s>'],
#  ['<s>',
#   'cho',
#   "'s",
#   'latest',
#   'comic',
#   'set',
#   'is',
#   "n't",
#   'as',
#   'sharp',
#   'or',
#   'as',
#   'fresh',
#   'as',
#   'i',
#   "'m",
#   'the',
#   'one',
#   'that',
#   'i',
#   'want',
#   '...',
#   'but',
#   'it',
#   "'s",
#   'still',
#   'damn',
#   'funny',
#   'stuff',
#   '.',
#   '</s>'],
#  ['<s>', 'cho', "'s", 'timing', 'is', 'priceless', '.', '</s>'],
#  ['<s>',
#   'cho',
#   'continues',
#   'her',
#   'exploration',
#   'of',
#   'the',
#   'outer',
#   'limits',
#   'of',
#   'raunch',
#   'with',
#   'considerable',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   'chouraqui',
#   'brings',
#   '<unk>',
#   'credibility',
#   'to',
#   'the',
#   '<unk>',
#   'of',
#   'the',
#   'killing',
#   'field',
#   'and',
#   'the',
#   '<unk>',
#   'of',
#   '`',
#   'ethnic',
#   '<unk>',
#   '.',
#   "'",
#   '</s>'],
#  ['<s>',
#   'chris',
#   '<unk>',
#   "'",
#   'sequel',
#   'is',
#   'faster',
#   ',',
#   '<unk>',
#   'and',
#   'a',
#   'good',
#   'deal',
#   'funnier',
#   'than',
#   'his',
#   'original',
#   '.',
#   '</s>'],
#  ['<s>',
#   '<unk>',
#   'will',
#   'revel',
#   'in',
#   'those',
#   'visual',
#   '<unk>',
#   ',',
#   'as',
#   'in',
#   'the',
#   'film',
#   "'s",
#   'verbal',
#   'pokes',
#   'at',
#   'everything',
#   'from',
#   'the',
#   'likes',
#   'of',
#   '<unk>',
#   'chief',
#   '<unk>',
#   '<unk>',
#   "'s",
#   '<unk>',
#   'personal',
#   'style',
#   'to',
#   'the',
#   'stylistic',
#   '<unk>',
#   'of',
#   '<unk>',
#   "'s",
#   '<unk>',
#   'movement',
#   '.',
#   '</s>'],
#  ['<s>',
#   'cinematic',
#   'poetry',
#   'showcases',
#   'the',
#   'city',
#   "'s",
#   '<unk>',
#   'charm',
#   'before',
#   'machines',
#   'change',
#   'nearly',
#   'everything',
#   '.',
#   '</s>'],
#  ['<s>',
#   'city',
#   'by',
#   'the',
#   'sea',
#   'is',
#   'a',
#   'gritty',
#   'police',
#   'thriller',
#   'with',
#   'all',
#   'the',
#   'dysfunctional',
#   'family',
#   'dynamics',
#   'one',
#   'could',
#   'wish',
#   'for',
#   '.',
#   '</s>'],
#  ['<s>',
#   '<unk>',
#   'is',
#   'a',
#   'terrific',
#   'role',
#   'for',
#   'someone',
#   'like',
#   'judd',
#   ',',
#   'who',
#   'really',
#   '<unk>',
#   'to',
#   'be',
#   'playing',
#   'villains',
#   '.',
#   '</s>'],
#  ['<s>',
#   'claude',
#   'chabrol',
#   "'s",
#   'camera',
#   'has',
#   'a',
#   'way',
#   'of',
#   'gently',
#   '<unk>',
#   'back',
#   'and',
#   'forth',
#   'as',
#   'it',
#   '<unk>',
#   'its',
#   'characters',
#   ',',
#   '<unk>',
#   'tension',
#   'beneath',
#   'otherwise',
#   'tender',
#   'movements',
#   '.',
#   '</s>'],
#  ['<s>',
#   'cletis',
#   'is',
#   'playful',
#   'but',
#   'highly',
#   '<unk>',
#   'and',
#   '<unk>',
#   'for',
#   'its',
#   'success',
#   'on',
#   'a',
#   'patient',
#   'viewer',
#   '.',
#   '</s>'],
#  ['<s>',
#   'clever',
#   'and',
#   'unflinching',
#   'in',
#   'its',
#   'comic',
#   '<unk>',
#   ',',
#   'slap',
#   'her',
#   'is',
#   'a',
#   'small',
#   'but',
#   'rewarding',
#   'comedy',
#   'that',
#   'takes',
#   '<unk>',
#   'at',
#   'contemporary',
#   '<unk>',
#   'adolescence',
#   'and',
#   'never',
#   'lets',
#   'up',
#   '.',
#   '</s>'],
#  ['<s>',
#   '<unk>',
#   'eastwood',
#   "'s",
#   'blood',
#   'work',
#   'is',
#   'a',
#   'lot',
#   'like',
#   'a',
#   'well-made',
#   '<unk>',
#   '&',
#   '<unk>',
#   '<unk>',
#   ':',
#   'familiar',
#   ',',
#   'fairly',
#   '<unk>',
#   'and',
#   'boasting',
#   'no',
#   'real',
#   'surprises',
#   '--',
#   'but',
#   'still',
#   'quite',
#   'tasty',
#   'and',
#   'inviting',
#   'all',
#   'the',
#   'same',
#   '.',
#   '</s>'],
#  ['<s>',
#   'clooney',
#   'directs',
#   'this',
#   'film',
#   'always',
#   'keeping',
#   'the',
#   'balance',
#   'between',
#   'the',
#   'fantastic',
#   'and',
#   'the',
#   'believable',
#   '...',
#   '</s>'],
#  ['<s>',
#   'close',
#   'enough',
#   'in',
#   'spirit',
#   'to',
#   'its',
#   '<unk>',
#   '<unk>',
#   'roots',
#   'to',
#   'be',
#   'a',
#   'breath',
#   'of',
#   'fresh',
#   'air',
#   '.',
#   '</s>'],
#  ['<s>', 'cold', ',', 'nervy', 'and', 'memorable', '.', '</s>'],
#  ['<s>',
#   'colorful',
#   ',',
#   'energetic',
#   'and',
#   'sweetly',
#   'whimsical',
#   '...',
#   'the',
#   'rare',
#   'sequel',
#   'that',
#   "'s",
#   'better',
#   'than',
#   'its',
#   'predecessor',
#   '.',
#   '</s>'],
#  ['<s>',
#   'combine',
#   'the',
#   '<unk>',
#   '<unk>',
#   'of',
#   'a',
#   'submarine',
#   'movie',
#   'with',
#   'the',
#   'unsettling',
#   '<unk>',
#   'of',
#   'the',
#   'supernatural',
#   '--',
#   'why',
#   'did',
#   "n't",
#   'hollywood',
#   'think',
#   'of',
#   'this',
#   '<unk>',
#   '?',
#   '</s>'],
#  ['<s>',
#   'combines',
#   'a',
#   '<unk>',
#   '<unk>',
#   'social',
#   'realism',
#   'with',
#   'a',
#   '<unk>',
#   '<unk>',
#   'fantasy',
#   'of',
#   'redemption',
#   'and',
#   '<unk>',
#   '.',
#   '</s>'],
#  ['<s>',
#   'combines',
#   'sharp',
#   'comedy',
#   ',',
#   'old-fashioned',
#   'monster',
#   'movie',
#   'atmospherics',
#   ',',
#   'and',
#   'genuine',
#   'heart',
#   'to',
#   'create',
#   'a',
#   'film',
#   'that',
#   "'s",
#   'not',
#   'merely',
#   'about',
#   'kicking',
#   '<unk>',
#   '\\*\\*\\*',
#   ',',
#   'but',
#   'also',
#   'about',
#   'dealing',
#   'with',
#   'regret',
#   'and',
#   ',',
#   'ultimately',
#   ',',
#   'finding',
#   'redemption',
#   '.',
#   '</s>'],
#  ['<s>',
#   'comedian',
#   ',',
#   'like',
#   'its',
#   'subjects',
#   ',',
#   'delivers',
#   'the',
#   'goods',
#   'and',
#   'audiences',
#   'will',
#   'have',
#   'a',
#   'fun',
#   ',',
#   'no-frills',
#   'ride',
#   '.',
#   '</s>'],
#  ['<s>',
#   'compared',
#   'to',
#   'his',
#   'series',
#   'of',
#   'spectacular',
#   'belly',
#   '<unk>',
#   'both',
#   'on',
#   'and',
#   'off',
#   'the',
#   'screen',
#   ',',
#   '<unk>',
#   'is',
#   'something',
#   'of',
#   'a',
#   'triumph',
#   '.',
#   '</s>'],
#  ['<s>',
#   'compassionately',
#   'explores',
#   'the',
#   'seemingly',
#   '<unk>',
#   'situation',
#   'between',
#   'conservative',
#   'christian',
#   'parents',
#   'and',
#   'their',
#   '<unk>',
#   'gay',
#   'and',
#   '<unk>',
#   'children',
#   '.',
#   '</s>'],
#  ['<s>', 'compellingly', 'watchable', '.', '</s>'],
#  ['<s>',
#   '<unk>',
#   'directed',
#   'but',
#   'terminally',
#   'cute',
#   'drama',
#   '.',
#   '</s>'],
#  ['<s>',
#   'compulsively',
#   'watchable',
#   ',',
#   'no',
#   'matter',
#   'how',
#   '<unk>',
#   'things',
#   'get',
#   '.',
#   '</s>'],
#  ...]

# %%
training_corpus = add_corpus([], pos_corpus_with_unknown)
training_corpus = add_corpus(training_corpus, neg_corpus_with_unknown)
training_corpus_set = set(training_corpus)
training_corpus = list(training_corpus_set)
training_corpus.sort()
training_corpusID = dict(zip(training_corpus, range(len(training_corpus))))

# %%
def horizontal_concat(corpusA, corpusB):
    new_corpus = list()
    for i in range(len(corpusA)):
        new_corpus.append(corpusA[i] + corpusB[i])
    return new_corpus

mixed_training_pos_corpus = horizontal_concat(pos_corpus_with_unknown, pos_bigram_corpus_with_unknown)
mixed_training_neg_corpus = horizontal_concat(neg_corpus_with_unknown, neg_bigram_corpus_with_unknown)
mixed_training_corpus = add_corpus([], mixed_training_pos_corpus)
mixed_training_corpus = add_corpus(mixed_training_corpus, mixed_training_neg_corpus)
mixed_training_corpus_set = set(mixed_training_corpus)
mixed_training_corpus = list(mixed_training_corpus_set)
mixed_training_corpus.sort()
mixed_training_corpusID = dict(zip(mixed_training_corpus, range(len(mixed_training_corpus))))
len(mixed_training_corpus)
# Out:
# 59237

# %%
pos_bigrams_selected = sorted(pos_bigram_freqs_with_unknown.items(), key=operator.itemgetter(1), reverse=True)[:2000]
neg_bigrams_selected = sorted(neg_bigram_freqs_with_unknown.items(), key=operator.itemgetter(1), reverse=True)[:2000]
neg_bigrams_selected
# Out:
# [(('ca', "n't"), 1.0503659896262545),
#  (('blair', 'witch'), 1.0503659896262545),
#  (('eddie', 'murphy'), 1.0503659896262545),
#  (('combination', 'of'), 1.0503659896262545),
#  (('blue', 'crush'), 1.0503659896262545),
#  (('deuces', 'wild'), 1.0503659896262545),
#  (('able', 'to'), 1.0503659896262545),
#  (('equivalent', 'of'), 1.0503659896262545),
#  (('martial', 'arts'), 1.0503659896262543),
#  (('stylistically', ','), 1.0503659896262543),
#  (('examination', 'of'), 1.0503659896262543),
#  (('exploration', 'of'), 1.0503659896262543),
#  (('basketball', '<unk>'), 1.0503659896262543),
#  (('julia', 'roberts'), 1.0503659896262543),
#  (('described', 'as'), 1.0503659896262543),
#  (('del', '<unk>'), 1.0503659896262543),
#  (('maintains', 'a'), 1.0503659896262543),
#  (('assumption', 'that'), 1.0503659896262543),
#  (('hypnotically', 'dull'), 1.0503659896262543),
#  (('disguised', 'as'), 1.0503659896262543),
#  (('sharing', 'the'), 1.0503659896262543),
#  (('satirical', '<unk>'), 1.0503659896262543),
#  (('sum', 'of'), 1.0503659896262543),
#  (('stumbles', 'over'), 1.0503659896262543),
#  (('trick', 'in'), 1.0503659896262543),
#  (('frankly', ','), 1.0503659896262543),
#  (('urge', 'to'), 1.0503659896262543),
#  (('shakespeare', "'s"), 1.0503659896262543),
#  (('devoid', 'of'), 1.0503659896262543),
#  (('travesty', 'of'), 1.0503659896262543),
#  (('ode', 'to'), 1.0503659896262543),
#  (('universal', 'studios'), 1.0503659896262543),
#  (('tends', 'to'), 1.0503659896262543),
#  (('cautionary', 'tale'), 1.0503659896262543),
#  (('chills', '.'), 1.0503659896262543),
#  (('strives', 'to'), 1.0503659896262543),
#  (('dearth', 'of'), 1.0503659896262543),
#  (('depraved', ','), 1.0503659896262543),
#  (('attitude', 'toward'), 1.0503659896262543),
#  (('crocodile', 'hunter'), 1.0503659896262543),
#  (('pokes', 'fun'), 1.0503659896262543),
#  (('outbursts', 'of'), 1.0503659896262543),
#  (('afterschool', 'special'), 1.0503659896262543),
#  (('justify', 'a'), 1.0503659896262543),
#  (('geared', 'toward'), 1.0503659896262543),
#  (('unlikely', 'to'), 1.0503659896262543),
#  (('littered', 'with'), 1.0503659896262543),
#  (('hoped', '.'), 1.0503659896262543),
#  (('bomb', '.'), 1.0503659896262543),
#  (('indicative', 'of'), 1.0503659896262543),
#  (('miscalculation', '.'), 1.0503659896262543),
#  (('hurt', '.'), 1.0503659896262543),
#  (('qualify', 'as'), 1.0503659896262543),
#  (('procession', 'of'), 1.0503659896262543),
#  (('posing', 'as'), 1.0503659896262543),
#  (('bordering', 'on'), 1.0503659896262543),
#  (('jackie', 'chan'), 1.0503659896262543),
#  (('yard', '.'), 1.0503659896262543),
#  (('enters', 'the'), 1.0503659896262543),
#  (('pantheon', 'of'), 1.0503659896262543),
#  (('distance', 'from'), 1.0503659896262543),
#  (('rife', 'with'), 1.0503659896262543),
#  (('21\\/2', 'hours'), 1.0503659896262543),
#  (('filled', 'with'), 1.0503659896262543),
#  (('joyless', ','), 1.0503659896262543),
#  (('snooze', '.'), 1.0503659896262543),
#  (('hodgepodge', '.'), 1.0503659896262543),
#  (('blandness', '.'), 1.0503659896262543),
#  (('letdown', '.'), 1.0503659896262543),
#  (('selection', 'of'), 1.0503659896262543),
#  (('search', 'of'), 1.0503659896262543),
#  (('amounts', 'to'), 1.0503659896262543),
#  (('quietly', '<unk>'), 1.0503659896262543),
#  (('stealing', 'harvard'), 1.0503659896262543),
#  (('cars', ','), 1.0503659896262543),
#  (('clothing', '.'), 1.0503659896262543),
#  (('undercut', 'by'), 1.0503659896262543),
#  (('farrelly', '<unk>'), 1.0503659896262543),
#  (('wants', 'to'), 1.0503659896262543),
#  (('iwai', "'s"), 1.0503659896262543),
#  (('flame', '.'), 1.0503659896262543),
#  (('unashamedly', '<unk>'), 1.0503659896262543),
#  (('meat', '<unk>'), 1.0503659896262543),
#  (('stare', 'and'), 1.0503659896262543),
#  (('pressed', 'to'), 1.0503659896262543),
#  (('segment', 'of'), 1.0503659896262543),
#  (('allowed', 'to'), 1.0503659896262543),
#  (('supposed', 'to'), 1.0503659896262543),
#  (('ah', ','), 1.0503659896262543),
#  (('yes', ','), 1.0503659896262543),
#  (('alas', ','), 1.0503659896262543),
#  (('stays', 'in'), 1.0503659896262543),
#  (('replaced', 'by'), 1.0503659896262543),
#  (('appeared', 'in'), 1.0503659896262543),
#  (('allegiance', 'to'), 1.0503659896262543),
#  (('cherry', 'orchard'), 1.0503659896262543),
#  (('freddy', 'got'), 1.0503659896262543),
#  (('fingered', '.'), 1.0503659896262543),
#  (('relies', 'on'), 1.0503659896262543),
#  (('league', '.'), 1.0503659896262543),
#  (('underbelly', 'of'), 1.0503659896262543),
#  (('purportedly', 'a'), 1.0503659896262543),
#  (('overwritten', ','), 1.0503659896262543),
#  (('surfeit', 'of'), 1.0503659896262543),
#  (('amid', 'the'), 1.0503659896262543),
#  (('hindered', 'by'), 1.0503659896262543),
#  (('evans', 'is'), 1.0503659896262543),
#  (('boils', 'down'), 1.0503659896262543),
#  (('prince', 'of'), 1.0503659896262543),
#  (('impenetrable', 'and'), 1.0503659896262543),
#  (('piffle', '.'), 1.0503659896262543),
#  (('demographic', '.'), 1.0503659896262543),
#  (('slice', 'of'), 1.0503659896262543),
#  (('mix', 'of'), 1.0503659896262543),
#  (('awakening', '.'), 1.0503659896262543),
#  (('listen', 'to'), 1.0503659896262543),
#  (('meant', 'to'), 1.0503659896262543),
#  (('mid', '-'), 1.0503659896262543),
#  (('sap', '.'), 1.0503659896262543),
#  (('loads', 'of'), 1.0503659896262543),
#  (('box', 'of'), 1.0503659896262543),
#  (('grasp', 'of'), 1.0503659896262543),
#  (('billy', '<unk>'), 1.0503659896262543),
#  (('desired', '.'), 1.0503659896262543),
#  (('coma', '.'), 1.0503659896262543),
#  (('wo', "n't"), 1.0503659896262543),
#  (('burr', '<unk>'), 1.0503659896262543),
#  (('swept', 'away'), 1.0503659896262543),
#  (('handful', 'of'), 1.0503659896262543),
#  (('collateral', 'damage'), 1.0503659896262543),
#  (('cletis', 'tout'), 1.0503659896262543),
#  (('tolerance', '.'), 1.0503659896262543),
#  (('devolves', 'into'), 1.0503659896262543),
#  (('auto', 'focus'), 1.0503659896262543),
#  (('dare', 'i'), 1.0503659896262543),
#  (('austin', 'powers'), 1.0503659896262543),
#  (('endurance', 'test'), 1.0503659896262543),
#  (('tearjerker', 'that'), 1.0503659896262543),
#  (('emphasis', 'on'), 1.0503659896262543),
#  (('classified', 'as'), 1.0503659896262543),
#  (('claims', 'to'), 1.0503659896262543),
#  (('clare', 'peploe'), 1.0503659896262543),
#  (('peploe', "'s"), 1.0503659896262543),
#  (('hugh', 'grant'), 1.0503659896262543),
#  (('sandra', 'bullock'), 1.0503659896262543),
#  (('bygone', 'era'), 1.0503659896262543),
#  (('misdemeanor', ','), 1.0503659896262543),
#  (('desire', 'to'), 1.0503659896262543),
#  (('litmus', 'test'), 1.0503659896262543),
#  (('sanctimony', ','), 1.0503659896262543),
#  (('rob', 'schneider'), 1.0503659896262543),
#  (('ed', '<unk>'), 1.0503659896262543),
#  (('succeeds', 'in'), 1.0503659896262543),
#  (('derailed', 'by'), 1.0503659896262543),
#  (('deserving', 'of'), 1.0503659896262543),
#  (('knockaround', 'guys'), 1.0503659896262543),
#  (('sparks', ','), 1.0503659896262543),
#  (('deja', 'vu'), 1.0503659896262543),
#  (('lyne', "'s"), 1.0503659896262543),
#  (('moralizing', '.'), 1.0503659896262543),
#  (('hong', 'kong'), 1.0503659896262543),
#  (('smack', 'of'), 1.0503659896262543),
#  (('fail', 'to'), 1.0503659896262543),
#  (('red', '<unk>'), 1.0503659896262543),
#  (('ralph', 'fiennes'), 1.0503659896262543),
#  (('succumbs', 'to'), 1.0503659896262543),
#  (('owen', 'wilson'), 1.0503659896262543),
#  (('load', 'of'), 1.0503659896262543),
#  (('legged', 'freaks'), 1.0503659896262543),
#  (('el', '<unk>'), 1.0503659896262543),
#  (('connect', 'with'), 1.0503659896262543),
#  (('barrel', '.'), 1.0503659896262543),
#  (('hardened', '<unk>'), 1.0503659896262543),
#  (('sorority', 'boys'), 1.0503659896262543),
#  (('majority', 'of'), 1.0503659896262543),
#  (('prospect', 'of'), 1.0503659896262543),
#  (('trace', 'of'), 1.0503659896262543),
#  (('motivated', 'by'), 1.0503659896262543),
#  (('motion', 'picture'), 1.0503659896262543),
#  (('evokes', 'the'), 1.0503659896262543),
#  (('relying', 'on'), 1.0503659896262543),
#  (('undermining', 'the'), 1.0503659896262543),
#  (('dot', 'com'), 1.0503659896262543),
#  (('nonsensical', 'and'), 1.0503659896262543),
#  (('gratuitous', 'violence'), 1.0503659896262543),
#  (('verdict', ':'), 1.0503659896262543),
#  (('ballistic', ':'), 1.0503659896262543),
#  (('ecks', 'vs.'), 1.0503659896262543),
#  (('hal', 'hartley'), 1.0503659896262543),
#  (('dawson', "'s"), 1.0503659896262543),
#  (('84', 'minutes'), 1.0503659896262543),
#  (('escaped', 'the'), 1.0503659896262543),
#  (('gaps', 'in'), 1.0503659896262543),
#  (('lola', 'run'), 1.0503659896262543),
#  (('bogged', 'down'), 1.0503659896262543),
#  (('praise', 'of'), 1.0503659896262543),
#  (('asleep', '.'), 1.0503659896262543),
#  (('hawke', "'s"), 1.0503659896262543),
#  (('populated', 'by'), 1.0503659896262543),
#  (('untalented', 'artistes'), 1.0503659896262543),
#  (('flies', 'out'), 1.0503659896262543),
#  (('alfred', 'hitchcock'), 1.0503659896262543),
#  (('serving', 'sara'), 1.0503659896262543),
#  (('undone', 'by'), 1.0503659896262543),
#  (('embarrassment', '.'), 1.0503659896262543),
#  (('r.', 'nebrida'), 1.0503659896262543),
#  (('psyche', '.'), 1.0503659896262543),
#  (('bow', 'wow'), 1.0503659896262543),
#  (('resident', 'evil'), 1.0503659896262543),
#  (('tap', ','), 1.0503659896262543),
#  (('amount', 'of'), 1.0503659896262543),
#  (('appeals', 'to'), 1.0503659896262543),
#  (('costly', '<unk>'), 1.0503659896262543),
#  (('susan', '<unk>'), 1.0503659896262543),
#  (('opinion', ','), 1.0503659896262543),
#  (('shreve', "'s"), 1.0503659896262543),
#  (('quentin', 'tarantino'), 1.0503659896262543),
#  (('credited', 'to'), 1.0503659896262543),
#  (('bogs', 'down'), 1.0503659896262543),
#  (('roberto', 'benigni'), 1.0503659896262543),
#  (('group', 'of'), 1.0503659896262543),
#  (('pauly', 'shore'), 1.0503659896262543),
#  (('silliness', '.'), 1.0503659896262543),
#  (('similarly', '<unk>'), 1.0503659896262543),
#  (('86', 'minutes'), 1.0503659896262543),
#  (('joe', '<unk>'), 1.0503659896262543),
#  (('fallen', '.'), 1.0503659896262543),
#  (('self-satisfied', '<unk>'), 1.0503659896262543),
#  (('captain', '.'), 1.0503659896262543),
#  (('concert', '.'), 1.0503659896262543),
#  (('rap', 'and'), 1.0503659896262543),
#  (('fairy', 'tales'), 1.0503659896262543),
#  (('verges', 'on'), 1.0503659896262543),
#  (('squarely', 'on'), 1.0503659896262543),
#  (('tough', 'to'), 1.0503659896262543),
#  (('rocket', 'scientist'), 1.0503659896262543),
#  (('admirable', '<unk>'), 1.0503659896262543),
#  (('reign', 'of'), 1.0503659896262543),
#  (('ability', 'to'), 1.0503659896262543),
#  (('anthony', 'hopkins'), 1.0503659896262543),
#  (('richard', 'pryor'), 1.0503659896262543),
#  (('foul', 'up'), 1.0503659896262543),
#  (('sabotaged', 'by'), 1.0503659896262543),
#  (('exclamation', 'point'), 1.0503659896262543),
#  (('marquis', 'de'), 1.0503659896262543),
#  (('straining', 'to'), 1.0503659896262543),
#  (('ought', 'to'), 1.0503659896262543),
#  (('string', 'of'), 1.0503659896262543),
#  (('lan', 'yu'), 1.0503659896262543),
#  (('pitfalls', 'of'), 1.0503659896262543),
#  (('vat', 'of'), 1.0503659896262543),
#  (('laughing', 'at'), 1.0503659896262543),
#  (('exhilarating', '<unk>'), 1.0503659896262543),
#  (('scratching', 'your'), 1.0503659896262543),
#  (('improvement', '.'), 1.0503659896262543),
#  (('derive', 'from'), 1.0503659896262543),
#  (('grief', 'and'), 1.0503659896262543),
#  (('expiration', 'date'), 1.0503659896262543),
#  (('aspect', 'of'), 1.0503659896262543),
#  (('exception', 'of'), 1.0503659896262543),
#  (('behave', 'like'), 1.0503659896262543),
#  (('joel', '<unk>'), 1.0503659896262543),
#  (('aimed', 'at'), 1.0503659896262543),
#  (('celebration', 'of'), 1.0503659896262543),
#  (('scorpion', 'king'), 1.0503659896262543),
#  (('winds', 'up'), 1.0503659896262543),
#  (('aggressively', '<unk>'), 1.0503659896262543),
#  (('carpenter', "'s"), 1.0503659896262543),
#  (('wertmuller', "'s"), 1.0503659896262543),
#  (('roman', '<unk>'), 1.0503659896262543),
#  (('dullard', '.'), 1.0503659896262543),
#  (('author', "'s"), 1.0503659896262543),
#  (('grit', 'and'), 1.0503659896262543),
#  (('jim', '<unk>'), 1.0503659896262543),
#  (('trotting', 'out'), 1.0503659896262543),
#  (('loaded', 'with'), 1.0503659896262543),
#  (('dude', ','), 1.0503659896262543),
#  (('desperation', '.'), 1.0503659896262543),
#  (('pluto', 'nash'), 1.0503659896262543),
#  (('importance', 'of'), 1.0503659896262543),
#  (('mothman', 'prophecies'), 1.0503659896262543),
#  (('co-written', 'by'), 1.0503659896262543),
#  (('sweetest', 'thing'), 1.0503659896262543),
#  (('mental', '<unk>'), 1.0503659896262543),
#  (('atrocious', ','), 1.0503659896262543),
#  (('payoff', '.'), 1.0503659896262543),
#  (('chocolate', '<unk>'), 1.0503659896262543),
#  (('ladder', '.'), 1.0503659896262543),
#  (('cumulative', 'effect'), 1.0503659896262543),
#  (('knew', 'what'), 1.0503659896262543),
#  (('jimmy', "'s"), 1.0503659896262543),
#  (('reliance', 'on'), 1.0503659896262543),
#  (('carried', 'out'), 1.0503659896262543),
#  (('tasty', '<unk>'), 1.0503659896262543),
#  (('feardotcom', 'is'), 1.0503659896262543),
#  (('randall', 'wallace'), 1.0503659896262543),
#  (('front', 'of'), 1.0503659896262543),
#  (('van', 'wilder'), 1.0503659896262543),
#  (('antwone', 'fisher'), 1.0503659896262543),
#  (('mired', 'in'), 1.0503659896262543),
#  (('arbitrary', '.'), 1.0503659896262543),
#  (('insistent', 'and'), 1.0503659896262543),
#  (('capacity', 'to'), 1.0503659896262543),
#  (('inclination', 'to'), 1.0503659896262543),
#  (('unwatchable', '.'), 1.0503659896262543),
#  (('cry', 'for'), 1.0503659896262543),
#  (('tasteful', 'to'), 1.0503659896262543),
#  (('function', 'as'), 1.0503659896262543),
#  (('kieslowski', "'s"), 1.0503659896262543),
#  (('affection', 'for'), 1.0503659896262543),
#  (('meaningless', ','), 1.0503659896262543),
#  (('caring', 'about'), 1.0503659896262543),
#  (('akin', 'to'), 1.0503659896262543),
#  (('.', '</s>'), 1.0302632912602017),
#  (('kind', 'of'), 1.0056695645357754),
#  (('sort', 'of'), 0.9847181152746134),
#  (('trying', 'to'), 0.9753398475100934),
#  (('!', '</s>'), 0.9453293906636289),
#  (('lots', 'of'), 0.9453293906636289),
#  (('impossible', 'to'), 0.9453293906636289),
#  (('?', '</s>'), 0.9398011486129643),
#  (('collection', 'of'), 0.9003137053939323),
#  (('based', 'on'), 0.9003137053939323),
#  (('unfortunately', ','), 0.9003137053939323),
#  (('90', 'minutes'), 0.888771221991446),
#  (('kung', 'pow'), 0.875304991355212),
#  (('adventures', 'of'), 0.875304991355212),
#  (('pretends', 'to'), 0.875304991355212),
#  (('snow', 'dogs'), 0.875304991355212),
#  (('bunch', 'of'), 0.875304991355212),
#  (('easier', 'to'), 0.875304991355212),
#  (('none', 'of'), 0.8753049913552119),
#  (('fact', 'that'), 0.8593903551487534),
#  (('soap', 'opera'), 0.8534223665713316),
#  (('lack', 'of'), 0.8502962773164915),
#  (('results', 'are'), 0.8402927917010035),
#  (('garbage', '.'), 0.8402927917010035),
#  (('psychological', 'thriller'), 0.8402927917010035),
#  (('plenty', 'of'), 0.8402927917010035),
#  (('sitting', 'through'), 0.8402927917010035),
#  (('favor', 'of'), 0.8402927917010035),
#  (('suffers', 'from'), 0.8292363075996744),
#  (('manages', 'to'), 0.8169513252648645),
#  (('rest', 'of'), 0.8169513252648645),
#  (('want', 'to'), 0.8116464465293782),
#  (('cobbled', 'together'), 0.7877744922196908),
#  (('guns', ','), 0.7877744922196908),
#  (('invention', '.'), 0.7877744922196908),
#  (('hokum', '.'), 0.7877744922196908),
#  (('weight', 'of'), 0.7877744922196908),
#  (('cross', 'between'), 0.7877744922196908),
#  (('fluff', '.'), 0.7877744922196908),
#  (('showgirls', '.'), 0.7877744922196908),
#  (('well-intentioned', ','), 0.7877744922196908),
#  (('succeed', 'in'), 0.7877744922196908),
#  (('degree', 'of'), 0.7877744922196908),
#  (('makers', 'of'), 0.7877744922196908),
#  (('grey', 'zone'), 0.7877744922196908),
#  (('excesses', 'of'), 0.7877744922196908),
#  (('forgotten', '.'), 0.7877744922196908),
#  (('addition', 'to'), 0.7877744922196908),
#  (('dealing', 'with'), 0.7877744922196908),
#  (('lump', 'of'), 0.7877744922196908),
#  (('explosions', 'and'), 0.7877744922196908),
#  (('conclusion', '.'), 0.7877744922196908),
#  (('wind', 'up'), 0.7877744922196908),
#  (('misfire', '.'), 0.7877744922196908),
#  (('lucy', "'s"), 0.7877744922196908),
#  (('twice', 'as'), 0.7877744922196908),
#  (('soderbergh', "'s"), 0.7877744922196908),
#  (('doze', 'off'), 0.7877744922196908),
#  (('clause', '2'), 0.7877744922196908),
#  (('responsible', 'for'), 0.7877744922196908),
#  (('version', 'of'), 0.7702683923925865),
#  (('close', 'to'), 0.7639025379100031),
#  (('running', 'time'), 0.758597659174517),
#  (('across', 'as'), 0.7502614211616103),
#  (('10', 'minutes'), 0.7502614211616103),
#  (('rises', 'above'), 0.7502614211616103),
#  (('adam', 'sandler'), 0.7502614211616103),
#  (('interested', 'in'), 0.7502614211616103),
#  (('insight', 'into'), 0.7502614211616103),
#  (('romantic', 'comedy'), 0.7306893840878291),
#  (('episode', 'of'), 0.7271764543566376),
#  (('does', "n't"), 0.7052457358919136),
#  (('master', 'of'), 0.7002439930841696),
#  (('scenario', '.'), 0.7002439930841695),
#  (('hawaiian', '<unk>'), 0.7002439930841695),
#  (('example', 'of'), 0.7002439930841695),
#  (('including', 'the'), 0.7002439930841695),
#  (('robin', 'williams'), 0.7002439930841695),
#  (('guilty', 'pleasure'), 0.7002439930841695),
#  (('suggests', 'a'), 0.7002439930841695),
#  (('aspects', 'of'), 0.7002439930841695),
#  (('rumor', 'of'), 0.7002439930841695),
#  (('art-house', 'crowd'), 0.7002439930841695),
#  (('beautifully', 'shot'), 0.7002439930841695),
#  (('directing', '<unk>'), 0.7002439930841695),
#  (('loud', ','), 0.7002439930841695),
#  (('pain', '.'), 0.7002439930841695),
#  (('eager', 'to'), 0.7002439930841695),
#  (('infomercial', 'for'), 0.7002439930841695),
#  (('coming-of-age', 'movie'), 0.7002439930841695),
#  (('contemporary', ','), 0.7002439930841695),
#  (('crafted', 'but'), 0.7002439930841695),
#  (('cable', ','), 0.7002439930841695),
#  (('occasional', '<unk>'), 0.7002439930841695),
#  (('inconsistent', ','), 0.7002439930841695),
#  (('aside', ','), 0.7002439930841695),
#  (('jordan', '<unk>'), 0.7002439930841695),
#  (('safe', 'as'), 0.7002439930841695),
#  (('theaters', '.'), 0.7002439930841695),
#  (('patience', '.'), 0.7002439930841695),
#  (('\\*', '<unk>'), 0.7002439930841695),
#  (('philosophical', '<unk>'), 0.7002439930841695),
#  (('longest', 'yard'), 0.7002439930841695),
#  (('ya-ya', 'sisterhood'), 0.7002439930841695),
#  (('shamelessly', 'manipulative'), 0.7002439930841695),
#  (('whodunit', '.'), 0.7002439930841695),
#  (('credibility', '.'), 0.7002439930841695),
#  (('tricks', '.'), 0.7002439930841695),
#  (('puzzle', 'whose'), 0.7002439930841695),
#  (('theory', ','), 0.7002439930841695),
#  (('severe', 'case'), 0.7002439930841695),
#  (('jumble', 'of'), 0.7002439930841695),
#  (('rise', 'above'), 0.7002439930841695),
#  (('source', 'material'), 0.7002439930841695),
#  (('copy', 'of'), 0.7002439930841695),
#  (('reduces', 'the'), 0.7002439930841695),
#  (('dreadful', '.'), 0.7002439930841695),
#  (('sexy', 'and'), 0.7002439930841695),
#  (('quirks', 'and'), 0.7002439930841695),
#  (('levels', ','), 0.7002439930841695),
#  (('shake', 'the'), 0.7002439930841695),
#  (('did', "n't"), 0.7002439930841695),
#  (('exit', 'sign'), 0.7002439930841695),
#  (('hybrid', 'of'), 0.7002439930841695),
#  (('incredibly', '<unk>'), 0.7002439930841695),
#  (('parody', 'of'), 0.7002439930841695),
#  (('postcard', 'that'), 0.7002439930841695),
#  (('candy', '.'), 0.7002439930841695),
#  (('public', ','), 0.7002439930841695),
#  (('stephen', '<unk>'), 0.7002439930841695),
#  (('anyway', '.'), 0.7002439930841695),
#  (('eastwood', "'s"), 0.7002439930841695),
#  (('borrows', 'from'), 0.7002439930841695),
#  (('bread', ','), 0.7002439930841695),
#  (('skin', '.'), 0.7002439930841695),
#  (('essence', 'of'), 0.7002439930841695),
#  (('no.', '.'), 0.7002439930841695),
#  (('hook', 'is'), 0.7002439930841695),
#  (('shoulders', ','), 0.7002439930841695),
#  (('says', ','), 0.7002439930841695),
#  (('shrill', ','), 0.7002439930841695),
#  (('sake', 'of'), 0.7002439930841695),
#  (('edited', ','), 0.7002439930841695),
#  (('lifestyle', '.'), 0.7002439930841695),
#  (('substitute', 'for'), 0.7002439930841695),
#  (('creating', 'a'), 0.7002439930841695),
#  (('actresses', ','), 0.7002439930841695),
#  (('shadyac', "'s"), 0.7002439930841695),
#  (('touches', ','), 0.7002439930841695),
#  (('hype', '.'), 0.7002439930841695),
#  (('qualities', 'that'), 0.7002439930841695),
#  (('jay', 'russell'), 0.7002439930841695),
#  (('weighs', 'down'), 0.7002439930841695),
#  (('caught', 'up'), 0.7002439930841695),
#  (('jennifer', 'lopez'), 0.7002439930841695),
#  (('support', 'the'), 0.7002439930841695),
#  (('pg-13', 'rating'), 0.7002439930841695),
#  (('due', 'to'), 0.7002439930841695),
#  (('natural', '<unk>'), 0.7002439930841695),
#  (('excited', 'about'), 0.7002439930841695),
#  (('rehash', '.'), 0.7002439930841695),
#  (('repeated', 'at'), 0.7002439930841695),
#  (('ineptly', 'directed'), 0.7002439930841695),
#  (('motions', '.'), 0.7002439930841695),
#  (('putting', 'the'), 0.7002439930841695),
#  (('references', '.'), 0.7002439930841695),
#  (('player', ','), 0.7002439930841695),
#  (('sentence', '.'), 0.7002439930841695),
#  (('100', 'minutes'), 0.7002439930841695),
#  (('frida', 'is'), 0.7002439930841695),
#  (('opens', 'today'), 0.7002439930841695),
#  (('glimpses', 'of'), 0.7002439930841695),
#  (('resemble', 'the'), 0.7002439930841695),
#  (('goldmember', 'has'), 0.7002439930841695),
#  (('favors', 'to'), 0.7002439930841695),
#  (('woody', 'allen'), 0.7002439930841695),
#  (('shyamalan', "'s"), 0.7002439930841695),
#  (('thumbs', 'down'), 0.7002439930841695),
#  (('happening', ','), 0.7002439930841695),
#  (('vincent', 'r.'), 0.7002439930841695),
#  (('analyze', 'this'), 0.7002439930841695),
#  (('dysfunctional', 'family'), 0.7002439930841695),
#  (('outtakes', '<unk>'), 0.7002439930841695),
#  (('peter', "o'fallon"), 0.7002439930841695),
#  (('elaborate', '<unk>'), 0.7002439930841695),
#  (('grow', 'up'), 0.7002439930841695),
#  (('bright', ','), 0.7002439930841695),
#  (('park', ','), 0.7002439930841695),
#  (('ignore', 'the'), 0.7002439930841695),
#  (('climactic', '<unk>'), 0.7002439930841695),
#  (('writers', ','), 0.7002439930841695),
#  (('tuck', 'everlasting'), 0.7002439930841695),
#  (('saving', 'private'), 0.7002439930841695),
#  (('private', 'ryan'), 0.7002439930841695),
#  (('games', ','), 0.7002439930841695),
#  (('rooting', 'for'), 0.7002439930841695),
#  (('combined', 'with'), 0.7002439930841695),
#  (('stretched', 'out'), 0.7002439930841695),
#  (('beautiful', ','), 0.7002439930841695),
#  (('fate', '.'), 0.7002439930841695),
#  (('hampered', 'by'), 0.7002439930841695),
#  (('taylor', "'s"), 0.7002439930841695),
#  (('cannes', 'film'), 0.7002439930841695),
#  (('atmosphere', '.'), 0.7002439930841695),
#  (('juvenile', '<unk>'), 0.7002439930841695),
#  (('realize', 'that'), 0.7002439930841695),
#  (('elizabeth', 'hurley'), 0.7002439930841695),
#  (('graceless', 'and'), 0.7002439930841695),
#  (('conviction', '.'), 0.7002439930841695),
#  (('wilde', "'s"), 0.7002439930841695),
#  (('pastiche', '.'), 0.7002439930841695),
#  (('wearing', 'a'), 0.7002439930841695),
#  (('bogus', '<unk>'), 0.7002439930841695),
#  (('kicks', 'off'), 0.7002439930841695),
#  (('haunted', 'house'), 0.7002439930841695),
#  (('promisingly', 'but'), 0.7002439930841695),
#  (('fizz', '.'), 0.7002439930841695),
#  (('jaglom', "'s"), 0.7002439930841695),
#  (('buzz', ','), 0.7002439930841695),
#  (('spiritual', 'quest'), 0.7002439930841695),
#  (('kiddie', 'flick'), 0.7002439930841695),
#  (('strike', 'against'), 0.7002439930841695),
#  (('controversy', ','), 0.7002439930841695),
#  (('partly', 'a'), 0.7002439930841695),
#  (('intellectual', '<unk>'), 0.7002439930841695),
#  (('ridiculousness', '.'), 0.7002439930841695),
#  (('brian', 'de'), 0.7002439930841695),
#  (('swallow', 'than'), 0.7002439930841695),
#  (('pink', 'slip'), 0.7002439930841695),
#  (('delivered', 'by'), 0.7002439930841695),
#  (('difference', 'between'), 0.7002439930841695),
#  (('snipes', 'is'), 0.7002439930841695),
#  (('morally', 'bankrupt'), 0.7002439930841695),
#  (('tragedy', '.'), 0.7002439930841695),
#  (('wet', '<unk>'), 0.7002439930841695),
#  (('slightly', '<unk>'), 0.7002439930841695),
#  (('suspend', 'your'), 0.7002439930841695),
#  (('irish', '<unk>'), 0.7002439930841695),
#  (('insult', 'to'), 0.7002439930841695),
#  (('saturday', 'night'), 0.7002439930841695),
#  (('piano', 'teacher'), 0.7002439930841695),
#  (('rules', 'of'), 0.7002439930841695),
#  (('tension', ','), 0.7002439930841695),
#  (('closer', 'to'), 0.7002439930841695),
#  (('hallmark', 'card'), 0.7002439930841695),
#  (('limitations', 'of'), 0.7002439930841695),
#  (('rude', 'and'), 0.7002439930841695),
#  (('disappointingly', 'generic'), 0.7002439930841695),
#  (('medical', '<unk>'), 0.7002439930841695),
#  (('brand', 'of'), 0.7002439930841695),
#  (('scorsese', "'s"), 0.7002439930841695),
#  (('failing', 'to'), 0.7002439930841695),
#  (('hole', 'in'), 0.7002439930841695),
#  (('spring', 'break'), 0.7002439930841695),
#  (('whatsoever', '.'), 0.7002439930841695),
#  (('clothes', 'and'), 0.7002439930841695),
#  (('artifice', 'and'), 0.7002439930841695),
#  (('friendship', 'is'), 0.7002439930841695),
#  (('elsewhere', '.'), 0.7002439930841695),
#  (('reputation', '.'), 0.7002439930841695),
#  (('ethnic', '<unk>'), 0.7002439930841695),
#  (('competent', ','), 0.7002439930841695),
#  (('sense', 'of'), 0.691030256333062),
#  (('exercise', 'in'), 0.6776554771782287),
#  (('tries', 'to'), 0.6684147206712527),
#  (('attempts', 'to'), 0.6684147206712527),
#  (('add', 'up'), 0.6684147206712527),
#  (('difficult', 'to'), 0.6684147206712527),
#  (('surprises', '.'), 0.656478743516409),
#  (('approach', 'to'), 0.656478743516409),
#  (('thinks', 'it'), 0.656478743516409),
#  (('david', '<unk>'), 0.656478743516409),
#  (('fatal', 'attraction'), 0.656478743516409),
#  (('designed', 'to'), 0.656478743516409),
#  (('length', '.'), 0.656478743516409),
#  (('fails', 'to'), 0.6564787435164089),
#  (('hard', 'to'), 0.6535610602118915),
#  (('plays', 'like'), 0.6519513039059509),
#  (('instead', 'of'), 0.6463790705392334),
#  (('waste', 'of'), 0.6463790705392334),
#  (('case', 'of'), 0.6463790705392334),
#  (('ends', 'up'), 0.6418903269938221),
#  (('onscreen', '.'), 0.6302195937757527),
#  (('price', 'of'), 0.6302195937757527),
#  (('built', 'on'), 0.6302195937757527),
#  (('ride', '.'), 0.6302195937757527),
#  (('jason', 'x'), 0.6302195937757527),
#  (('crowd', ','), 0.6302195937757527),
#  (('homage', 'to'), 0.6302195937757527),
#  (('ground', '.'), 0.6302195937757527),
#  (('suited', 'to'), 0.6302195937757527),
#  (('secrets', 'of'), 0.6302195937757527),
#  (('preposterous', ','), 0.6302195937757527),
#  (('commercial', 'for'), 0.6302195937757527),
#  (('empathy', '.'), 0.6302195937757527),
#  (('adaptation', 'of'), 0.6302195937757527),
#  (('acted', ','), 0.6302195937757527),
#  (('elements', 'of'), 0.6302195937757527),
#  (('stilted', 'and'), 0.6302195937757527),
#  (('personal', '<unk>'), 0.6302195937757527),
#  (('martin', 'lawrence'), 0.6302195937757527),
#  (('number', 'of'), 0.6302195937757527),
#  (('intrigue', '.'), 0.6302195937757527),
#  (('follows', 'the'), 0.6302195937757527),
#  (('trappings', 'of'), 0.6302195937757527),
#  (('impostor', 'is'), 0.6302195937757527),
#  (('sentimentality', 'and'), 0.6302195937757527),
#  (('fashion', ','), 0.6302195937757527),
#  (('plotted', 'and'), 0.6302195937757527),
#  (('release', '.'), 0.6302195937757527),
#  (('eight', 'legged'), 0.6302195937757527),
#  (('bottom', 'of'), 0.6302195937757527),
#  (('dvd', '.'), 0.6302195937757527),
#  (('account', 'of'), 0.6302195937757527),
#  (('turned', 'out'), 0.6302195937757527),
#  (('halfway', 'through'), 0.6302195937757527),
#  (('walked', 'out'), 0.6302195937757527),
#  (('williams', ','), 0.6302195937757527),
#  (('kevin', '<unk>'), 0.6302195937757527),
#  (('comparison', '.'), 0.6302195937757527),
#  (('settles', 'into'), 0.6302195937757527),
#  (('carvey', "'s"), 0.6302195937757527),
#  (('sit', 'through'), 0.6302195937757525),
#  (('needs', 'to'), 0.6127134939486484),
#  (('mr.', '<unk>'), 0.6127134939486484),
#  (('looking', 'for'), 0.6081066255730946),
#  (('act', ','), 0.6002091369292882),
#  (('behind', 'the'), 0.6002091369292882),
#  (('overcome', 'the'), 0.6002091369292882),
#  (('rip-off', 'of'), 0.6002091369292882),
#  (('vs.', 'sever'), 0.6002091369292882),
#  (('friday', 'after'), 0.6002091369292882),
#  (('buy', 'the'), 0.6002091369292882),
#  (('apart', '.'), 0.6002091369292882),
#  (('ridiculous', '<unk>'), 0.6002091369292882),
#  (('necessary', 'to'), 0.6002091369292882),
#  (('year', '.'), 0.590830869164768),
#  (('problem', 'with'), 0.5882049541907024),
#  (('level', 'of'), 0.5835366609034747),
#  (('excuse', 'for'), 0.5835366609034747),
#  (('terms', 'of'), 0.5835366609034747),
#  (('appears', 'to'), 0.5835366609034747),
#  (('result', 'is'), 0.5835366609034747),
#  (('target', 'audience'), 0.5835366609034747),
#  (('bore', '.'), 0.5729269034325023),
#  (('figure', 'out'), 0.5729269034325023),
#  (('queen', 'of'), 0.5729269034325023),
#  (('each', 'other'), 0.5655816867218293),
#  (('years', 'ago'), 0.5601951944673356),
#  (('likely', 'to'), 0.5560761121550757),
#  (('lot', 'of'), 0.5461903146056523),
#  (('de', 'niro'), 0.5251829948131272),
#  (('opportunity', 'to'), 0.5251829948131272),
#  (('begins', 'to'), 0.5251829948131272),
#  (('monster', 'movie'), 0.5251829948131272),
#  (('trouble', 'every'), 0.5251829948131272),
#  (('action-comedy', '.'), 0.5251829948131271),
#  (('banderas', 'and'), 0.5251829948131271),
#  (('allegedly', '``'), 0.5251829948131271),
#  (('disintegrating', '<unk>'), 0.5251829948131271),
#  (('ridicule', 'factor'), 0.5251829948131271),
#  (('ten', 'minutes'), 0.5251829948131271),
#  (('piece', 'of'), 0.5251829948131271),
#  (('plotline', 'that'), 0.5251829948131271),
#  (('porridge', '...'), 0.5251829948131271),
#  (('airless', ','), 0.5251829948131271),
#  (('wonder', 'if'), 0.5251829948131271),
#  (('share', 'screenwriting'), 0.5251829948131271),
#  (('inoffensive', ','), 0.5251829948131271),
#  (('awry', '.'), 0.5251829948131271),
#  (('middle-class', '<unk>'), 0.5251829948131271),
#  (('insightful', '.'), 0.5251829948131271),
#  (('decidedly', '<unk>'), 0.5251829948131271),
#  (('predecessor', '--'), 0.5251829948131271),
#  (('childlike', 'and'), 0.5251829948131271),
#  (('begin', 'with'), 0.5251829948131271),
#  (('pile', 'of'), 0.5251829948131271),
#  (('clown', "''"), 0.5251829948131271),
#  (('soul-searching', 'garbage'), 0.5251829948131271),
#  (('defeated', 'the'), 0.5251829948131271),
#  (('incongruous', ','), 0.5251829948131271),
#  (('solemn', 'pretension'), 0.5251829948131271),
#  (('prevents', 'us'), 0.5251829948131271),
#  (('holds', 'itself'), 0.5251829948131271),
#  (('population', "'s"), 0.5251829948131271),
#  (('questionable', 'satirical'), 0.5251829948131271),
#  (('resurrection', 'too'), 0.5251829948131271),
#  (('pays', 'tribute'), 0.5251829948131271),
#  (('tribute', 'to'), 0.5251829948131271),
#  (('phony', '<unk>'), 0.5251829948131271),
#  (('grotesque', 'narcissism'), 0.5251829948131271),
#  (('narcissism', '.'), 0.5251829948131271),
#  (('pitiful', ','), 0.5251829948131271),
#  (('tacky', 'and'), 0.5251829948131271),
#  (('collective', 'fear'), 0.5251829948131271),
#  (('outrage', 'come'), 0.5251829948131271),
#  (('portrays', 'their'), 0.5251829948131271),
#  (('eat', 'enough'), 0.5251829948131271),
#  (('efforts', 'of'), 0.5251829948131271),
#  (('kline', ','), 0.5251829948131271),
#  (('dignity', 'to'), 0.5251829948131271),
#  (('thoughtful', 'for'), 0.5251829948131271),
#  (('conditioning', '.'), 0.5251829948131271),
#  (('unfolds', 'suggests'), 0.5251829948131271),
#  (('enterprise', '.'), 0.5251829948131271),
#  (('scarier', ','), 0.5251829948131271),
#  (('naturally', 'charming'), 0.5251829948131271),
#  (('uninteresting', ','), 0.5251829948131271),
#  (('flatly', 'delivered'), 0.5251829948131271),
#  (('heroine', 'who'), 0.5251829948131271),
#  (('update', 'of'), 0.5251829948131271),
#  (('texture', ','), 0.5251829948131271),
#  (('anywhere', '.'), 0.5251829948131271),
#  (('tanks', '.'), 0.5251829948131271),
#  (('realizing', 'that'), 0.5251829948131271),
#  (('waiting', 'for'), 0.5251829948131271),
#  (('gunplay', ','), 0.5251829948131271),
#  (('resembling', 'humor'), 0.5251829948131271),
#  (('legendary', 'wit'), 0.5251829948131271),
#  (('passable', 'performances'), 0.5251829948131271),
#  (('doa', 'dud'), 0.5251829948131271),
#  (('burning', '<unk>'), 0.5251829948131271),
#  (('nature', 'of'), 0.5251829948131271),
#  (('cows', 'falls'), 0.5251829948131271),
#  (('bard', "'s"), 0.5251829948131271),
#  (('alternative', '.'), 0.5251829948131271),
#  (('matinee', '.'), 0.5251829948131271),
#  (('epic', '.'), 0.5251829948131271),
#  (('pitiful', 'directing'), 0.5251829948131271),
#  (('studios', 'and'), 0.5251829948131271),
#  (('uses', 'a'), 0.5251829948131271),
#  (('19th-century', 'crime'), 0.5251829948131271),
#  (('masquerade', 'ball'), 0.5251829948131271),
#  (('folly', 'of'), 0.5251829948131271),
#  (('endlessly', 'superficial'), 0.5251829948131271),
#  (('ladies', 'and'), 0.5251829948131271),
#  (('crossroads', 'is'), 0.5251829948131271),
#  (('revolution', 'studios'), 0.5251829948131271),
#  (('surrender', '$'), 0.5251829948131271),
#  (('chiller', 'resolutely'), 0.5251829948131271),
#  (('remote', ','), 0.5251829948131271),
#  (('tagline', 'should'), 0.5251829948131271),
#  (('hear', 'you'), 0.5251829948131271),
#  (('snore', '.'), 0.5251829948131271),
#  (('clash', 'between'), 0.5251829948131271),
#  (('naturalistic', 'tone'), 0.5251829948131271),
#  (('manipulation', 'and'), 0.5251829948131271),
#  (('wayne', '<unk>'), 0.5251829948131271),
#  (('clash', 'comedy'), 0.5251829948131271),
#  (('veers', 'into'), 0.5251829948131271),
#  (('shock', 'treatment'), 0.5251829948131271),
#  (('treatment', '.'), 0.5251829948131271),
#  (('decided', 'lack'), 0.5251829948131271),
#  (('spontaneity', 'in'), 0.5251829948131271),
#  (('depressingly', '<unk>'), 0.5251829948131271),
#  (('post-feminist', "'"), 0.5251829948131271),
#  (('astonishingly', '<unk>'), 0.5251829948131271),
#  (('determined', ','), 0.5251829948131271),
#  (('slog', 'that'), 0.5251829948131271),
#  (('news', 'flash'), 0.5251829948131271),
#  (('devastating', '<unk>'), 0.5251829948131271),
#  (('planet', 'documentary'), 0.5251829948131271),
#  (('hunter', 'is'), 0.5251829948131271),
#  (('saved', 'only'), 0.5251829948131271),
#  (('minor', 'effort'), 0.5251829948131271),
#  (('domestic', 'melodrama'), 0.5251829948131271),
#  (('biopic', 'cliches'), 0.5251829948131271),
#  (('small-town', 'pretension'), 0.5251829948131271),
#  (('stereotypical', 'tale'), 0.5251829948131271),
#  (('drugs', ','), 0.5251829948131271),
#  (('indifference', 'on'), 0.5251829948131271),
#  (('streets', '.'), 0.5251829948131271),
#  (('pervasive', 'quiet'), 0.5251829948131271),
#  (('noise', '.'), 0.5251829948131271),
#  (('harmless', 'but'), 0.5251829948131271),
#  (('feeble', 'tootsie'), 0.5251829948131271),
#  (('tootsie', '<unk>'), 0.5251829948131271),
#  (('feel-good', 'movie'), 0.5251829948131271),
#  (('pileup', 'of'), 0.5251829948131271),
#  (('blown', 'up'), 0.5251829948131271),
#  (('service', 'of'), 0.5251829948131271),
#  (('comfort', 'and'), 0.5251829948131271),
#  (('framework', 'upon'), 0.5251829948131271),
#  (('fleshed-out', 'characters'), 0.5251829948131271),
#  (('filming', '.'), 0.5251829948131271),
#  (('unbearable', 'when'), 0.5251829948131271),
#  (('international', 'version'), 0.5251829948131271),
#  (('fart', 'coming'), 0.5251829948131271),
#  (('beginning', 'to'), 0.5251829948131271),
#  (('gratingly', 'unfunny'), 0.5251829948131271),
#  (('threadbare', 'comic'), 0.5251829948131271),
#  (('setups', '.'), 0.5251829948131271),
#  (('evening', 'on'), 0.5251829948131271),
#  (('outrageous', 'or'), 0.5251829948131271),
#  (('imaginative', 'as'), 0.5251829948131271),
#  (('post-production', 'stages'), 0.5251829948131271),
#  (('stages', '.'), 0.5251829948131271),
#  (('fumbles', 'away'), 0.5251829948131271),
#  (('japanese', 'and'), 0.5251829948131271),
#  (('embarrassed', 'to'), 0.5251829948131271),
#  (('futuristic', 'sets'), 0.5251829948131271),
#  (('saved', 'this'), 0.5251829948131271),
#  (('incisive', 'enough'), 0.5251829948131271),
#  (('wedding', 'serves'), 0.5251829948131271),
#  (('despair', ','), 0.5251829948131271),
#  (('minimalist', '<unk>'), 0.5251829948131271),
#  (('business', '.'), 0.5251829948131271),
#  (('onto', 'the'), 0.5251829948131271),
#  (('violent', 'and'), 0.5251829948131271),
#  (('crass', ','), 0.5251829948131271),
#  (('endeavor', '.'), 0.5251829948131271),
#  (('arrives', '<unk>'), 0.5251829948131271),
#  (('blurry', ','), 0.5251829948131271),
#  (('low-rent', 'retread'), 0.5251829948131271),
#  (('empowerment', 'tale'), 0.5251829948131271),
#  (('thinly', 'posing'), 0.5251829948131271),
#  (('self-parody', 'that'), 0.5251829948131271),
#  (('seeming', 'purpose'), 0.5251829948131271),
#  (('younger', 'audiences'), 0.5251829948131271),
#  (('butt', 'of'), 0.5251829948131271),
#  (('engaged', 'in'), 0.5251829948131271),
#  (('dentist', "'s"), 0.5251829948131271),
#  (('rhythms', '.'), 0.5251829948131271),
#  (('includes', '<unk>'), 0.5251829948131271),
#  (('depicts', '.'), 0.5251829948131271),
#  (('held', '<unk>'), 0.5251829948131271),
#  (('mediocrity', '.'), 0.5251829948131271),
#  (('lolita', '.'), 0.5251829948131271),
#  (('afterthought', '<unk>'), 0.5251829948131271),
#  (('enter', 'into'), 0.5251829948131271),
#  (('muddy', 'psychological'), 0.5251829948131271),
#  (('muted', '<unk>'), 0.5251829948131271),
#  (('noble', 'failure'), 0.5251829948131271),
#  (('survive', 'a'), 0.5251829948131271),
#  (('after-school', 'special'), 0.5251829948131271),
#  (('sisterhood', 'with'), 0.5251829948131271),
#  (('pathetically', 'inane'), 0.5251829948131271),
#  (('limit', '.'), 0.5251829948131271),
#  (('tunney', 'ca'), 0.5251829948131271),
#  (('catholic', 'boy'), 0.5251829948131271),
#  (('falling', 'short'), 0.5251829948131271),
#  (('sham', 'actor'), 0.5251829948131271),
#  (('malaise', '.'), 0.5251829948131271),
#  (('portrait', 'of'), 0.5251829948131271),
#  (('alienating', 'most'), 0.5251829948131271),
#  (('stinker', '.'), 0.5251829948131271),
#  (('prurient', 'whodunit'), 0.5251829948131271),
#  (('processed', 'comedy'), 0.5251829948131271),
#  (('cardboard', 'characters'), 0.5251829948131271),
#  (('prolonged', '<unk>'), 0.5251829948131271),
#  (('perform', 'entertaining'), 0.5251829948131271),
#  (('connected', 'characters'), 0.5251829948131271),
#  (('gel', '.'), 0.5251829948131271),
#  (('middle-of-the-road', 'blandness'), 0.5251829948131271),
#  (('relative', 'letdown'), 0.5251829948131271),
#  (('reworking', 'of'), 0.5251829948131271),
#  (('near', 'as'), 0.5251829948131271),
#  (('rote', 'exercise'), 0.5251829948131271),
#  (('sloppily', 'written'), 0.5251829948131271),
#  (('rings', 'true'), 0.5251829948131271),
#  (('series', 'of'), 0.5251829948131271),
#  (('demonstrating', 'the'), 0.5251829948131271),
#  (('goose', 'is'), 0.5251829948131271),
#  (('composed', 'shots'), 0.5251829948131271),
#  (('patch', 'adams'), 0.5251829948131271),
#  (('sham', 'construct'), 0.5251829948131271),
#  (('construct', 'based'), 0.5251829948131271),
#  (('harvard', 'is'), 0.5251829948131271),
#  (('expensive', 'cars'), 0.5251829948131271),
#  (('naked', 'women'), 0.5251829948131271),
#  (('off-putting', 'romantic'), 0.5251829948131271),
#  (('anomie', 'that'), 0.5251829948131271),
#  (('twist', 'that'), 0.5251829948131271),
#  (('overly-familiar', 'set'), 0.5251829948131271),
#  (('throwback', 'to'), 0.5251829948131271),
#  (('chicken', '.'), 0.5251829948131271),
#  (('independent', 'film'), 0.5251829948131271),
#  (('reminding', 'audiences'), 0.5251829948131271),
#  (('so-so', ','), 0.5251829948131271),
#  (('incisive', 'and'), 0.5251829948131271),
#  (('portrait', 'that'), 0.5251829948131271),
#  (('spooky', 'yarn'), 0.5251829948131271),
#  (('yarn', 'of'), 0.5251829948131271),
#  (('doings', 'on'), 0.5251829948131271),
#  (('seas', 'that'), 0.5251829948131271),
#  (('engaged', '.'), 0.5251829948131271),
#  (('wound', 'up'), 0.5251829948131271),
#  (('gore', 'for'), 0.5251829948131271),
#  (('seasonal', '<unk>'), 0.5251829948131271),
#  (('justice', 'to'), 0.5251829948131271),
#  (('shown', 'up'), 0.5251829948131271),
#  (('enthusiasm', 'is'), 0.5251829948131271),
#  (('suspenseful', 'horror'), 0.5251829948131271),
#  (('setups', 'and'), 0.5251829948131271),
#  (('self-congratulation', 'between'), 0.5251829948131271),
#  (('technical', 'triumph'), 0.5251829948131271),
#  (('scream', '.'), 0.5251829948131271),
#  (('opportunities', '.'), 0.5251829948131271),
#  (('uneventful', 'ride'), 0.5251829948131271),
#  (('vile', ','), 0.5251829948131271),
#  (('prep-school', 'kid'), 0.5251829948131271),
#  (('potboiler', 'that'), 0.5251829948131271),
#  (('attractive', 'young'), 0.5251829948131271),
#  (('offbeat', 'sensibilities'), 0.5251829948131271),
#  (('sensibilities', 'for'), 0.5251829948131271),
#  (('emerge', 'with'), 0.5251829948131271),
#  (('wishy-washy', 'melodramatic'), 0.5251829948131271),
#  (('explains', 'its'), 0.5251829948131271),
#  (('equal', 'laughs'), 0.5251829948131271),
#  (('pulse', '.'), 0.5251829948131271),
#  (('scripts', ','), 0.5251829948131271),
#  (('after-school', 'tv'), 0.5251829948131271),
#  (('zombie', 'movie'), 0.5251829948131271),
#  (('killed', '.'), 0.5251829948131271),
#  (('searching', 'for'), 0.5251829948131271),
#  (('quarter', 'in'), 0.5251829948131271),
#  (('feces', '...'), 0.5251829948131271),
#  (('decidedly', 'unoriginal'), 0.5251829948131271),
#  (('intermittently', 'wise'), 0.5251829948131271),
#  (('padding', 'unashamedly'), 0.5251829948131271),
#  (('bravado', '--'), 0.5251829948131271),
#  (('nights', 'is'), 0.5251829948131271),
#  (('butt', '</s>'), 0.5251829948131271),
#  (('adrift', ','), 0.5251829948131271),
#  (('prove', 'that'), 0.5251829948131271),
#  (('hair', '<unk>'), 0.5251829948131271),
#  (('mad', 'love'), 0.5251829948131271),
#  (('outrage', 'the'), 0.5251829948131271),
#  (('hoffman', "'s"), 0.5251829948131271),
#  (('reasonably', 'intelligent'), 0.5251829948131271),
#  (('ponder', 'how'), 0.5251829948131271),
#  (('sticky', '.'), 0.5251829948131271),
#  (('took', 'three'), 0.5251829948131271),
#  (('strenuously', '<unk>'), 0.5251829948131271),
#  (('answer', 'is'), 0.5251829948131271),
#  (('remembering', 'it'), 0.5251829948131271),
#  (('tacky', 'nonsense'), 0.5251829948131271),
#  (('nonsense', ','), 0.5251829948131271),
#  (('wal-mart', 'budget'), 0.5251829948131271),
#  (('hates', 'criticism'), 0.5251829948131271),
#  (('noir', ','), 0.5251829948131271),
#  (('upbeat', '.'), 0.5251829948131271),
#  (('brown', 'sugar'), 0.5251829948131271),
#  (('sugar', 'from'), 0.5251829948131271),
#  (('throwback', 'war'), 0.5251829948131271),
#  (('slim', 'hopes'), 0.5251829948131271),
#  (('inauthentic', 'at'), 0.5251829948131271),
#  (('sensuality', ','), 0.5251829948131271),
#  (('flashbacks', 'do'), 0.5251829948131271),
#  (('condition', '.'), 0.5251829948131271),
#  (('besotted', 'and'), 0.5251829948131271),
#  (('basically', 'the'), 0.5251829948131271),
#  (('faces', "'"), 0.5251829948131271),
#  (('chekhov', ','), 0.5251829948131271),
#  (('cacoyannis', '<unk>'), 0.5251829948131271),
#  (('earnestness', 'in'), 0.5251829948131271),
#  (('unsettling', '.'), 0.5251829948131271),
#  (('raw', 'emotion'), 0.5251829948131271),
#  (('alternative', 'medicine'), 0.5251829948131271),
#  (('medicine', 'obviously'), 0.5251829948131271),
#  (('striking', 'and'), 0.5251829948131271),
#  (('heritage', ','), 0.5251829948131271),
#  (('growing', 'up'), 0.5251829948131271),
#  (('catholic', 'or'), 0.5251829948131271),
#  (('america', '.'), 0.5251829948131271),
#  (('rowdy', '<unk>'), 0.5251829948131271),
#  (('weighty', '<unk>'), 0.5251829948131271),
#  (('nostalgia', 'for'), 0.5251829948131271),
#  (('amazingly', 'lame'), 0.5251829948131271),
#  (('holocaust', '<unk>'), 0.5251829948131271),
#  (('challenging', 'or'), 0.5251829948131271),
#  (('shock', 'and'), 0.5251829948131271),
#  (('spider', '<unk>'), 0.5251829948131271),
#  (('ages', '<unk>'), 0.5251829948131271),
#  (('let', 'alone'), 0.5251829948131271),
#  (('achingly', '<unk>'), 0.5251829948131271),
#  (('admitted', '<unk>'), 0.5251829948131271),
#  (('villain', ','), 0.5251829948131271),
#  (('morbid', 'love'), 0.5251829948131271),
#  (('orgy', 'of'), 0.5251829948131271),
#  (('purposeless', ','), 0.5251829948131271),
#  (('average', 'b-movie'), 0.5251829948131271),
#  (('filmgoers', '.'), 0.5251829948131271),
#  (('genres', 'that'), 0.5251829948131271),
#  (('purposeless', 'exercise'), 0.5251829948131271),
#  (('florid', 'but'), 0.5251829948131271),
#  (('surface', 'flash'), 0.5251829948131271),
#  ...]

# %%
unigram_training_corpus = add_corpus([], pos_corpus_with_unknown)
unigram_training_corpus = add_corpus(unigram_training_corpus, neg_corpus_with_unknown)
unigram_training_corpus = list(set(unigram_pos_training_corpus))
unigram_training_corpus.sort()
print(len(unigram_training_corpus))




#bigram_training_corpus = add_corpus([], pos_bigram_corpus_with_unknown)
#bigram_training_corpus = add_corpus(bigram_training_corpus, neg_bigram_corpus_with_unknown)
bigram_training_corpus = [w[0] for w in pos_bigrams_selected]
bigram_training_corpus = bigram_training_corpus + [w[0] for w in neg_bigrams_selected]
bigram_training_corpus = list(set(bigram_training_corpus))
bigram_training_corpus.sort()
print(len(bigram_training_corpus))

#mixed_training_corpus = horizontal_concat(unigram_training_corpus, bigram_training_corpus)
mixed_training_corpus = unigram_training_corpus + bigram_training_corpus
mixed_training_corpusID = dict(zip(mixed_training_corpus, range(len(mixed_training_corpus))))
print(len(mixed_training_corpus))
print(mixed_training_corpusID[('surface', 'flash')])

def feature_mixed(original_corpus, training_corpus, training_corpusID):
    training_corpus_set = set(training_corpus)
    X = []
    for line in original_corpus:
        #print(line)
        feat = [0] * len(training_corpusID)
        for w in line:
            if w in training_corpus:
                #print(w, ' ', training_corpusID[w])
                feat[training_corpusID[w]] += 1
            else:
                feat[training_corpusID['<unk>']] += 1
        
        for i in range(len(line) - 1):
            bi = (line[i].lower(), line[i + 1].lower())
            if bi in training_corpus:
                feat[training_corpusID[bi]] += 1      
        feat.append(1)
        X.append(feat)
    return X
# Out:
# 4315
# 3840
# 8155
# 7678

# %%
X_pos = feature(pos_corpus, training_corpus, training_corpusID)
y_pos = [0 for l in pos_corpus]
X_neg = feature(neg_corpus, training_corpus, training_corpusID)
y_neg = [1 for l in neg_corpus]

# %%
'''X_pos = feature_mixed(pos_corpus, mixed_training_corpus, mixed_training_corpusID)
y_pos = [0 for l in pos_corpus]
X_neg = feature(neg_corpus, mixed_training_corpus, mixed_training_corpusID)
y_neg = [1 for l in neg_corpus]'''
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-210-09c0ff8e53dc> in <module>()
# ----> 1 X_pos = feature_mixed(pos_corpus, mixed_training_corpus, mixed_training_corpusID)
#       2 y_pos = [0 for l in pos_corpus]
#       3 X_neg = feature(neg_corpus, mixed_training_corpus, mixed_training_corpusID)
#       4 y_neg = [1 for l in neg_corpus]
#
# <ipython-input-132-44ec776e177c> in feature_mixed(original_corpus, training_corpus, training_corpusID)
#      37         for i in range(len(line) - 1):
#      38             bi = (line[i].lower(), line[i + 1].lower())
# ---> 39             if bi in training_corpus:
#      40                 feat[training_corpusID[bi]] += 1
#      41         feat.append(1)
#
# KeyboardInterrupt:

# %%
X = X_pos + X_neg
y = y_pos + y_neg

# %%
len(X[0])
# Out:
# 5946

# %%
import scipy.optimize
import nltk
from nltk.stem.porter import *
from sklearn import linear_model
'''
clf = linear_model.Ridge(1.0, fit_intercept=False)
clf.fit(X, y)
theta = clf.coef_
predictions = clf.predict(X)'''
# Out:
# '\nclf = linear_model.Ridge(1.0, fit_intercept=False)\nclf.fit(X, y)\ntheta = clf.coef_\npredictions = clf.predict(X)'

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(12, 10), random_state=1)
clf.fit(X, y)
# Out:
# MLPClassifier(activation='relu', alpha=1e-05, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(12, 10), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=1, shuffle=True,
#        solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
stats = defaultdict()
for w in range(10, 20):
    for d in range(10, 20):
        clf = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(w, d), random_state=1)
        clf.fit(X, y)
        dev_pos_corpus_original = get_corpus('SentimentDataset/Dev/pos.txt')
        dev_neg_corpus_original = get_corpus('SentimentDataset/Dev/neg.txt')
        X_dev = feature(dev_pos_corpus_original + dev_neg_corpus_original, training_corpus, training_corpusID)
        y_dev = [0 for i in range(len(dev_pos_corpus_original))] + [1 for i in range(len(dev_neg_corpus_original))]
        pred_dev_res = clf.predict(X_dev)
        print('size: ', w, ' x ',d , ' with accuracy: ', accuracy(pred_dev_res, y_dev))
        stats[(w, d)] = accuracy(pred_dev_res, y_dev)
# 12 X 10
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-217-d3599d9d7a6c> in <module>()
#       3     for d in range(10, 20):
#       4         clf = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(w, d), random_state=1)
# ----> 5         clf.fit(X, y)
#       6         dev_pos_corpus_original = get_corpus('SentimentDataset/Dev/pos.txt')
#       7         dev_neg_corpus_original = get_corpus('SentimentDataset/Dev/neg.txt')
#
# /Users/shuohuang/anaconda/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py in fit(self, X, y)
#     616         self : returns a trained MLP model.
#     617         """
# --> 618         return self._fit(X, y, incremental=False)
#     619
#     620     @property
#
# /Users/shuohuang/anaconda/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py in _fit(self, X, y, incremental)
#     380         elif self.solver == 'lbfgs':
#     381             self._fit_lbfgs(X, y, activations, deltas, coef_grads,
# --> 382                             intercept_grads, layer_units)
#     383         return self
#     384
#
# /Users/shuohuang/anaconda/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py in _fit_lbfgs(self, X, y, activations, deltas, coef_grads, intercept_grads, layer_units)
#     467             iprint=iprint,
#     468             pgtol=self.tol,
# --> 469             args=(X, y, activations, deltas, coef_grads, intercept_grads))
#     470
#     471         self._unpack(optimal_parameters)
#
# /Users/shuohuang/anaconda/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     191
#     192     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 193                            **opts)
#     194     d = {'grad': res['jac'],
#     195          'task': res['message'],
#
# /Users/shuohuang/anaconda/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     326             # until the completion of the current minimization iteration.
#     327             # Overwrite f and g:
# --> 328             f, g = func_and_grad(x)
#     329         elif task_str.startswith(b'NEW_X'):
#     330             # new iteration
#
# /Users/shuohuang/anaconda/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in func_and_grad(x)
#     276     else:
#     277         def func_and_grad(x):
# --> 278             f = fun(x, *args)
#     279             g = jac(x, *args)
#     280             return f, g
#
# /Users/shuohuang/anaconda/lib/python3.6/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     290     def function_wrapper(*wrapper_args):
#     291         ncalls[0] += 1
# --> 292         return function(*(wrapper_args + args))
#     293
#     294     return ncalls, function_wrapper
#
# /Users/shuohuang/anaconda/lib/python3.6/site-packages/scipy/optimize/optimize.py in __call__(self, x, *args)
#      61     def __call__(self, x, *args):
#      62         self.x = numpy.asarray(x).copy()
# ---> 63         fg = self.fun(x, *args)
#      64         self.jac = fg[1]
#      65         return fg[0]
#
# /Users/shuohuang/anaconda/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py in _loss_grad_lbfgs(self, packed_coef_inter, X, y, activations, deltas, coef_grads, intercept_grads)
#     176         self._unpack(packed_coef_inter)
#     177         loss, coef_grads, intercept_grads = self._backprop(
# --> 178             X, y, activations, deltas, coef_grads, intercept_grads)
#     179         self.n_iter_ += 1
#     180         grad = _pack(coef_grads, intercept_grads)
#
# /Users/shuohuang/anaconda/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py in _backprop(self, X, y, activations, deltas, coef_grads, intercept_grads)
#     221
#     222         # Forward propagate
# --> 223         activations = self._forward_pass(activations)
#     224
#     225         # Get loss
#
# /Users/shuohuang/anaconda/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py in _forward_pass(self, activations)
#     102         for i in range(self.n_layers_ - 1):
#     103             activations[i + 1] = safe_sparse_dot(activations[i],
# --> 104                                                  self.coefs_[i])
#     105             activations[i + 1] += self.intercepts_[i]
#     106
#
# /Users/shuohuang/anaconda/lib/python3.6/site-packages/sklearn/utils/extmath.py in safe_sparse_dot(a, b, dense_output)
#     187         return ret
#     188     else:
# --> 189         return fast_dot(a, b)
#     190
#     191
#
# KeyboardInterrupt:

# %%
pred_res = []
for p in predictions:
    if p >= 0.5:
        pred_res.append(1)
    else:
        pred_res.append(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-2462446f61fe> in <module>()
#       1 pred_res = []
# ----> 2 for p in predictions:
#       3     if p >= 0.5:
#       4         pred_res.append(1)
#       5     else:
#
# NameError: name 'predictions' is not defined

# %%
pred_res = clf.predict(X)

# %%
pred_res
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
error = sum([1 for i in range(len(pred_res)) if pred_res[i] != y[i]])

# %%
error
# Out:
# 0

# %%
# Use development set to validate our training model
#dev_pos_corpus_original = get_corpus('SentimentDataset/Dev/pos.txt')
#dev_neg_corpus_original = get_corpus('SentimentDataset/Dev/neg.txt')
#X_dev = feature(dev_pos_corpus_original + dev_neg_corpus_original, training_corpus, training_corpusID)
#y_dev = [0 for i in range(len(dev_pos_corpus_original))] + [1 for i in range(len(dev_neg_corpus_original))]

# %%
# Use development set to validate our training model
dev_pos_corpus_original = get_corpus('SentimentDataset/Dev/pos.txt')
dev_neg_corpus_original = get_corpus('SentimentDataset/Dev/neg.txt')
X_dev = feature(dev_pos_corpus_original + dev_neg_corpus_original, training_corpus, training_corpusID)
y_dev = [0 for i in range(len(dev_pos_corpus_original))] + [1 for i in range(len(dev_neg_corpus_original))]

# %%
pred_dev_res = clf.predict(X_dev)

print(accuracy(pred_dev_res, y_dev))
# Out:
# 0.7709090909090909

# %%
len(X_dev[0])
# Out:
# 6202

# %%
test_corpus_original = get_corpus('SentimentDataset/Test/test.txt')

# %%
test_corpus_original = get_corpus('SentimentDataset/Test/section8_test.txt')

# %%
X_test = feature(test_corpus_original, training_corpus, training_corpusID)

# %%
predictions = clf.predict(X_test)
pred_res = []
for p in predictions:
    if p >= 0.5:
        pred_res.append(1)
    else:
        pred_res.append(0)

# %%
pred_res = clf.predict(X_test)

# %%
pred_res
# Out:
# array([0, 0, 1, ..., 0, 0, 1])

# %%
pred_file = open('section8.csv', 'w')
pred_file.write('Id,Prediction\n')
for i in range(len(pred_res)):
    pred_file.write(str(i + 1) + ',' + str(pred_res[i]) + '\n')
pred_file.close()
